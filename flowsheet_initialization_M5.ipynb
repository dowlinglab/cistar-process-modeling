# %% [markdown]
# # Flowsheet initialization
# ## ROK model = M5

# %%
# simulation case specifications
model_code = 5
case_name = 'Bakken'

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                define_models, \
                                define_arcs, \
                                set_unit_model_variables, \
                                initialize_flowsheet, \
                                set_scaling_factors,\
                                update_model_after_initialization,\
                                vapor_only_to_vapor_liquid_reformulate,\
                                H106_inlet_vapor_reformulate

# %% [markdown]
# ## Define flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188,
#                      'ibutane':0.5188,
                    }

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Sequence for initialization

# %%
from pyomo.network import SequentialDecomposition
seq = SequentialDecomposition()
seq.options.select_tear_method = "heuristic"
seq.options.tear_method = "Wegstein"
seq.options.iterLim = 5

# Using the SD tool
G = seq.create_graph(m)
heuristic_tear_set = seq.tear_set_arcs(G, method="heuristic")
order = seq.calculation_order(G)

for o in heuristic_tear_set:
    print(o.name)
print("Order of initialization")
for o in order:
    print(o[0].name)    
    
def function(unit):
    unit.initialize(outlvl=idaeslog.INFO_HIGH)
# Out:
# fs.s01
# Order of initialization
# fs.H101
# fs.R101
# fs.H102
# fs.S101
# fs.H103
# fs.R102
# fs.H104
# fs.T102
# fs.H105
# fs.F101
# fs.H106
# fs.F102
# fs.T104
# fs.C101
# fs.T105
# fs.M102
# fs.S102
# fs.C102
# fs.M101

# %% [markdown]
# ## Initialize Flowsheet

# %%
inlet_flow_guess = inlet_flow_rate
tear_guesses = {"flow_mol": inlet_flow_guess,
        "temperature": 308.0,
        "pressure": 700000.0,
        "mole_frac_comp": inlet_composition_dict,
        }

# %%
initialize_flowsheet(m,tear_guesses = tear_guesses)
# Out:
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_out: State released.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume: Initialization Complete
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101: Initialization Step 1 Complete.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101.control_volume.properties_in: State released.
# 2023-05-22 21:54:12 [INFO] idaes.init.fs.H101: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 4.9011e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     481.39     481.39
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction methane   dimensionless   0.081100   0.081099
#     Total Mole Fraction ethane    dimensionless    0.46920    0.46920
#     Total Mole Fraction propane   dimensionless    0.30920    0.30920
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.078399
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.026500
#     Total Mole Fraction pentane   dimensionless   0.025800   0.025800
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0060999
#     Total Mole Fraction heptane   dimensionless  0.0025000  0.0025000
#     Total Mole Fraction octane    dimensionless  0.0012000  0.0012000
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction propene   dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction butene    dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction pentene   dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction hexene    dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction heptene   dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction octene    dimensionless 1.0000e-06 9.9989e-07
#     Total Mole Fraction nonene    dimensionless 1.0000e-06 9.9989e-07
#     Temperature                          kelvin     308.00     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.reactions: Initialization Complete.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_out: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume: Initialization Complete
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101: Initialization Step 1 Complete.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101.control_volume.properties_in: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.R101: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 4.9057e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     80.544 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     98.714 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     19.580 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     481.39     680.23
#     Total Mole Fraction hydrogen  dimensionless 9.9989e-07    0.29231
#     Total Mole Fraction methane   dimensionless   0.081099   0.057393
#     Total Mole Fraction ethane    dimensionless    0.46920    0.21364
#     Total Mole Fraction propane   dimensionless    0.30920   0.073697
#     Total Mole Fraction nbutane   dimensionless   0.078399   0.026698
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.018754
#     Total Mole Fraction pentane   dimensionless   0.025800   0.018258
#     Total Mole Fraction hexane    dimensionless  0.0060999  0.0043169
#     Total Mole Fraction heptane   dimensionless  0.0025000  0.0017692
#     Total Mole Fraction octane    dimensionless  0.0012000 0.00084922
#     Total Mole Fraction ethylene  dimensionless 9.9989e-07    0.11841
#     Total Mole Fraction propene   dimensionless 9.9989e-07    0.14512
#     Total Mole Fraction butene    dimensionless 9.9989e-07   0.028785
#     Total Mole Fraction pentene   dimensionless 9.9989e-07 7.0762e-07
#     Total Mole Fraction hexene    dimensionless 9.9989e-07 7.0762e-07
#     Total Mole Fraction heptene   dimensionless 9.9989e-07 7.0762e-07
#     Total Mole Fraction octene    dimensionless 9.9989e-07 7.0762e-07
#     Total Mole Fraction nonene    dimensionless 9.9989e-07 7.0762e-07
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_out: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume: Initialization Complete
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102: Initialization Step 1 Complete.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102.control_volume.properties_in: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.H102: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -4.0660e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     680.23     680.23
#     Total Mole Fraction hydrogen  dimensionless    0.29231    0.29231
#     Total Mole Fraction methane   dimensionless   0.057393   0.057393
#     Total Mole Fraction ethane    dimensionless    0.21364    0.21364
#     Total Mole Fraction propane   dimensionless   0.073697   0.073697
#     Total Mole Fraction nbutane   dimensionless   0.026698   0.026698
#     Total Mole Fraction ibutane   dimensionless   0.018754   0.018754
#     Total Mole Fraction pentane   dimensionless   0.018258   0.018258
#     Total Mole Fraction hexane    dimensionless  0.0043169  0.0043169
#     Total Mole Fraction heptane   dimensionless  0.0017692  0.0017692
#     Total Mole Fraction octane    dimensionless 0.00084922 0.00084922
#     Total Mole Fraction ethylene  dimensionless    0.11841    0.11841
#     Total Mole Fraction propene   dimensionless    0.14512    0.14512
#     Total Mole Fraction butene    dimensionless   0.028785   0.028785
#     Total Mole Fraction pentene   dimensionless 7.0762e-07 7.0762e-07
#     Total Mole Fraction hexene    dimensionless 7.0762e-07 7.0762e-07
#     Total Mole Fraction heptene   dimensionless 7.0762e-07 7.0762e-07
#     Total Mole Fraction octene    dimensionless 7.0762e-07 7.0762e-07
#     Total Mole Fraction nonene    dimensionless 7.0762e-07 7.0762e-07
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.mixed_state: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.mixed_state: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.H2_purge_state: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.H2_purge_state: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.H2_purge_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.H2_purge_state: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.H2_purge_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.outlet_state: Starting initialization
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.outlet_state: State variable initialization completed.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.outlet_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.outlet_state: State released.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.outlet_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2023-05-22 21:54:13 [INFO] idaes.init.fs.S101.mixed_state: State released.
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     680.23     134.79     545.44
#     Total Mole Fraction hydrogen  dimensionless    0.29231    0.84916    0.15470
#     Total Mole Fraction methane   dimensionless   0.057393   0.022230   0.066083
#     Total Mole Fraction ethane    dimensionless    0.21364   0.082749    0.24598
#     Total Mole Fraction propane   dimensionless   0.073697 3.7191e-09   0.091910
#     Total Mole Fraction nbutane   dimensionless   0.026698 1.3473e-09   0.033296
#     Total Mole Fraction ibutane   dimensionless   0.018754 9.4639e-10   0.023388
#     Total Mole Fraction pentane   dimensionless   0.018258 9.2139e-10   0.022770
#     Total Mole Fraction hexane    dimensionless  0.0043169 2.1785e-10  0.0053837
#     Total Mole Fraction heptane   dimensionless  0.0017692 8.9282e-11  0.0022064
#     Total Mole Fraction octane    dimensionless 0.00084922 4.2855e-11  0.0010591
#     Total Mole Fraction ethylene  dimensionless    0.11841   0.045863    0.13634
#     Total Mole Fraction propene   dimensionless    0.14512 7.3234e-09    0.18098
#     Total Mole Fraction butene    dimensionless   0.028785 1.4526e-09   0.035899
#     Total Mole Fraction pentene   dimensionless 7.0762e-07 3.5737e-14 8.8249e-07
#     Total Mole Fraction hexene    dimensionless 7.0762e-07 3.5737e-14 8.8249e-07
#     Total Mole Fraction heptene   dimensionless 7.0762e-07 3.5737e-14 8.8249e-07
#     Total Mole Fraction octene    dimensionless 7.0762e-07 3.5737e-14 8.8249e-07
#     Total Mole Fraction nonene    dimensionless 7.0762e-07 3.5737e-14 8.8249e-07
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_in: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_in: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_out: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_out: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_out: State released.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101: Initialization Complete optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.T101.properties_in: State released.
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     134.79     134.79
#     Total Mole Fraction hydrogen  dimensionless    0.84916    0.84916
#     Total Mole Fraction methane   dimensionless   0.022230   0.022230
#     Total Mole Fraction ethane    dimensionless   0.082749   0.082749
#     Total Mole Fraction propane   dimensionless 3.7191e-09          -
#     Total Mole Fraction nbutane   dimensionless 1.3473e-09          -
#     Total Mole Fraction ibutane   dimensionless 9.4639e-10          -
#     Total Mole Fraction pentane   dimensionless 9.2139e-10          -
#     Total Mole Fraction hexane    dimensionless 2.1785e-10          -
#     Total Mole Fraction heptane   dimensionless 8.9282e-11          -
#     Total Mole Fraction octane    dimensionless 4.2855e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.045863   0.045863
#     Total Mole Fraction propene   dimensionless 7.3234e-09          -
#     Total Mole Fraction butene    dimensionless 1.4526e-09          -
#     Total Mole Fraction pentene   dimensionless 3.5737e-14          -
#     Total Mole Fraction hexene    dimensionless 3.5737e-14          -
#     Total Mole Fraction heptene   dimensionless 3.5737e-14          -
#     Total Mole Fraction octene    dimensionless 3.5737e-14          -
#     Total Mole Fraction nonene    dimensionless 3.5737e-14          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_out: State released.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101: Initialization Step 1 Complete.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.properties_isentropic: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.properties_isentropic: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.properties_isentropic: State released.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101: Initialization Step 2 Complete.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101: Initialization Step 3 optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101: Initialization Step 4 optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101.control_volume.properties_in: State released.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.E101: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -6.5130e+05 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     134.79     134.79
#     Total Mole Fraction hydrogen  dimensionless    0.84916    0.84916
#     Total Mole Fraction methane   dimensionless   0.022230   0.022230
#     Total Mole Fraction ethane    dimensionless   0.082749   0.082749
#     Total Mole Fraction ethylene  dimensionless   0.045863   0.045863
#     Temperature                          kelvin     473.00     327.45
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_out: State released.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume: Initialization Complete
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103: Initialization Step 1 Complete.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:14 [INFO] idaes.init.fs.H103.control_volume.properties_in: State released.
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.H103: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 4.6761e+06 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     545.44     545.44
#     Total Mole Fraction hydrogen  dimensionless    0.15470    0.15470
#     Total Mole Fraction methane   dimensionless   0.066083   0.066083
#     Total Mole Fraction ethane    dimensionless    0.24598    0.24598
#     Total Mole Fraction propane   dimensionless   0.091910   0.091910
#     Total Mole Fraction nbutane   dimensionless   0.033296   0.033296
#     Total Mole Fraction ibutane   dimensionless   0.023388   0.023388
#     Total Mole Fraction pentane   dimensionless   0.022770   0.022770
#     Total Mole Fraction hexane    dimensionless  0.0053837  0.0053837
#     Total Mole Fraction heptane   dimensionless  0.0022064  0.0022064
#     Total Mole Fraction octane    dimensionless  0.0010591  0.0010591
#     Total Mole Fraction ethylene  dimensionless    0.13634    0.13634
#     Total Mole Fraction propene   dimensionless    0.18098    0.18098
#     Total Mole Fraction butene    dimensionless   0.035899   0.035899
#     Total Mole Fraction pentene   dimensionless 8.8249e-07 8.8249e-07
#     Total Mole Fraction hexene    dimensionless 8.8249e-07 8.8249e-07
#     Total Mole Fraction heptene   dimensionless 8.8249e-07 8.8249e-07
#     Total Mole Fraction octene    dimensionless 8.8249e-07 8.8249e-07
#     Total Mole Fraction nonene    dimensionless 8.8249e-07 8.8249e-07
#     Temperature                          kelvin     473.00     573.00
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume.properties: Starting initialization
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume.properties: State variable initialization completed.
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume.properties: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume.reactions: Initialization Complete.
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume: Initialization Complete
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102.control_volume.properties: State released.
# 2023-05-22 21:54:15 [INFO] idaes.init.fs.R102: Initialization Step 1 Complete.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.R102: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.R102: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     545.44     473.34
#     Total Mole Fraction hydrogen  dimensionless    0.15470    0.17826
#     Total Mole Fraction methane   dimensionless   0.066083   0.076148
#     Total Mole Fraction ethane    dimensionless    0.24598    0.28345
#     Total Mole Fraction propane   dimensionless   0.091910    0.10591
#     Total Mole Fraction nbutane   dimensionless   0.033296   0.038367
#     Total Mole Fraction ibutane   dimensionless   0.023388   0.026951
#     Total Mole Fraction pentane   dimensionless   0.022770   0.026239
#     Total Mole Fraction hexane    dimensionless  0.0053837  0.0062037
#     Total Mole Fraction heptane   dimensionless  0.0022064  0.0025425
#     Total Mole Fraction octane    dimensionless  0.0010591  0.0012204
#     Total Mole Fraction ethylene  dimensionless    0.13634   0.059658
#     Total Mole Fraction propene   dimensionless    0.18098   0.071787
#     Total Mole Fraction butene    dimensionless   0.035899   0.026211
#     Total Mole Fraction pentene   dimensionless 8.8249e-07   0.023739
#     Total Mole Fraction hexene    dimensionless 8.8249e-07   0.019901
#     Total Mole Fraction heptene   dimensionless 8.8249e-07   0.016683
#     Total Mole Fraction octene    dimensionless 8.8249e-07   0.019620
#     Total Mole Fraction nonene    dimensionless 8.8249e-07   0.017110
#     Temperature                          kelvin     573.00     573.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_out: Starting initialization
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_out: State released.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume: Initialization Complete
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104: Initialization Step 1 Complete.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104.control_volume.properties_in: State released.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H104: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.0913e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     473.34     473.34
#     Total Mole Fraction hydrogen  dimensionless    0.17826    0.17826
#     Total Mole Fraction methane   dimensionless   0.076148   0.076148
#     Total Mole Fraction ethane    dimensionless    0.28345    0.28345
#     Total Mole Fraction propane   dimensionless    0.10591    0.10591
#     Total Mole Fraction nbutane   dimensionless   0.038367   0.038367
#     Total Mole Fraction ibutane   dimensionless   0.026951   0.026951
#     Total Mole Fraction pentane   dimensionless   0.026239   0.026239
#     Total Mole Fraction hexane    dimensionless  0.0062037  0.0062037
#     Total Mole Fraction heptane   dimensionless  0.0025425  0.0025425
#     Total Mole Fraction octane    dimensionless  0.0012204  0.0012204
#     Total Mole Fraction ethylene  dimensionless   0.059658   0.059658
#     Total Mole Fraction propene   dimensionless   0.071787   0.071787
#     Total Mole Fraction butene    dimensionless   0.026211   0.026211
#     Total Mole Fraction pentene   dimensionless   0.023739   0.023739
#     Total Mole Fraction hexene    dimensionless   0.019901   0.019901
#     Total Mole Fraction heptene   dimensionless   0.016683   0.016683
#     Total Mole Fraction octene    dimensionless   0.019620   0.019620
#     Total Mole Fraction nonene    dimensionless   0.017110   0.017110
#     Temperature                          kelvin     573.00     308.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_in: Starting initialization
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_in: State variable initialization completed.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_out: Starting initialization
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_out: State variable initialization completed.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_out: State released.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102: Initialization Complete optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.T102.properties_in: State released.
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     473.34          -
#     Total Mole Fraction hydrogen        dimensionless    0.17826          -
#     Total Mole Fraction methane         dimensionless   0.076148          -
#     Total Mole Fraction ethane          dimensionless    0.28345          -
#     Total Mole Fraction propane         dimensionless    0.10591          -
#     Total Mole Fraction nbutane         dimensionless   0.038367          -
#     Total Mole Fraction ibutane         dimensionless   0.026951          -
#     Total Mole Fraction pentane         dimensionless   0.026239          -
#     Total Mole Fraction hexane          dimensionless  0.0062037          -
#     Total Mole Fraction heptane         dimensionless  0.0025425          -
#     Total Mole Fraction octane          dimensionless  0.0012204          -
#     Total Mole Fraction ethylene        dimensionless   0.059658          -
#     Total Mole Fraction propene         dimensionless   0.071787          -
#     Total Mole Fraction butene          dimensionless   0.026211          -
#     Total Mole Fraction pentene         dimensionless   0.023739          -
#     Total Mole Fraction hexene          dimensionless   0.019901          -
#     Total Mole Fraction heptene         dimensionless   0.016683          -
#     Total Mole Fraction octene          dimensionless   0.019620          -
#     Total Mole Fraction nonene          dimensionless   0.017110          -
#     Temperature                                kelvin     308.00     308.00
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
#     Molar Flowrate ('Liq', 'ethane')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'propane')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nbutane')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'ibutane')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'pentane')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'hexane')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'heptane')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'octane')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'ethylene')  mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'propene')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'butene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'pentene')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'hexene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'heptene')   mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     84.377
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     36.044
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     134.17
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     50.131
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     18.161
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     12.757
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     12.420
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     2.9365
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.2035
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.57767
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     28.239
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     33.980
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     12.407
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     11.237
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     9.4200
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     7.8967
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     9.2869
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     8.0988
# ====================================================================================
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H105.control_volume.properties_in: Starting initialization
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H105.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H105.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:54:16 [INFO] idaes.init.fs.H105.control_volume.properties_out: Starting initialization
# 2023-05-22 21:58:01 [INFO] idaes.init.fs.H105.control_volume.properties_out: Dew and bubble point initialization: optimal - Optimal Solution Found.
# 2023-05-22 21:58:01 [INFO] idaes.init.fs.H105.control_volume.properties_out: Equilibrium temperature initialization completed.
# 2023-05-22 21:58:01 [INFO] idaes.init.fs.H105.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 22:01:37 [INFO] idaes.init.fs.H105.control_volume.properties_out: Phase equilibrium initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:02:32 [INFO] idaes.init.fs.H105.control_volume.properties_out: State released.
# 2023-05-22 22:02:32 [INFO] idaes.init.fs.H105.control_volume: Initialization Complete
# 2023-05-22 22:02:32 [INFO] idaes.init.fs.H105: Initialization Step 1 Complete.
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.H105: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.H105.control_volume.properties_in: State released.
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.H105: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.5063e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     2.2692
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     2.6626
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     2.8234
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     1.4939
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     4.5345
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     1.8487
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.0051
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.54035
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08    0.33001
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     1.5744
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     1.6594
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     3.2441
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     5.5387
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     6.6047
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     8.5816
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     7.4838
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     84.377     84.377
#     Molar Flowrate ('Vap', 'methane')   mole / second     36.044     36.044
#     Molar Flowrate ('Vap', 'ethane')    mole / second     134.17     131.90
#     Molar Flowrate ('Vap', 'propane')   mole / second     50.131     47.469
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     18.161     15.338
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     12.757     11.263
#     Molar Flowrate ('Vap', 'pentane')   mole / second     12.420     7.8854
#     Molar Flowrate ('Vap', 'hexane')    mole / second     2.9365     1.0877
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.2035    0.19835
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.57767   0.037317
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     28.239     27.909
#     Molar Flowrate ('Vap', 'propene')   mole / second     33.980     32.405
#     Molar Flowrate ('Vap', 'butene')    mole / second     12.407     10.747
#     Molar Flowrate ('Vap', 'pentene')   mole / second     11.237     7.9927
#     Molar Flowrate ('Vap', 'hexene')    mole / second     9.4200     3.8813
#     Molar Flowrate ('Vap', 'heptene')   mole / second     7.8967     1.2921
#     Molar Flowrate ('Vap', 'octene')    mole / second     9.2869    0.70524
#     Molar Flowrate ('Vap', 'nonene')    mole / second     8.0988    0.61502
#     Temperature                                kelvin     308.00     307.93
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.F101.control_volume.properties_in: Starting initialization
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.F101.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.F101.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:12:29 [INFO] idaes.init.fs.F101.control_volume.properties_out: Starting initialization
# 2023-05-22 22:15:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: Dew and bubble point initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:15:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: Equilibrium temperature initialization completed.
# 2023-05-22 22:15:21 [INFO] idaes.init.fs.F101.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 22:18:14 [INFO] idaes.init.fs.F101.control_volume.properties_out: Phase equilibrium initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:18:52 [INFO] idaes.init.fs.F101.control_volume.properties_out: State released.
# 2023-05-22 22:18:52 [INFO] idaes.init.fs.F101.control_volume: Initialization Complete
# 2023-05-22 22:18:52 [INFO] idaes.init.fs.F101: Initialization Step 1 Complete.
# 2023-05-22 22:23:59 [INFO] idaes.init.fs.F101: Initialization Step 2 optimal - Optimal Solution Found.
# 2023-05-22 22:23:59 [INFO] idaes.init.fs.F101.control_volume.properties_in: State released.
# 2023-05-22 22:23:59 [INFO] idaes.init.fs.F101: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -62883. : pascal : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     2.2692            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.6626            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     2.8234            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     1.4939            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     4.5345            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     1.8487            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.0051            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.54035            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second    0.33001            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     1.5744            -             -
# ...
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F101_state: Starting initialization
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F101_state: State variable initialization completed.
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F101_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F102_state: Starting initialization
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F102_state: State variable initialization completed.
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.vapor_recycle_F102_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.mixed_state: Starting initialization
# 2023-05-22 22:52:49 [INFO] idaes.init.fs.M102.mixed_state: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102.mixed_state: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102: Initialization Complete: optimal - Optimal Solution Found
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102.vapor_recycle_F101_state: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.M102.vapor_recycle_F102_state: State released.
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          423.68              5.8666         429.55
#     Total Mole Fraction hydrogen  dimensionless         0.19915          1.0000e-08        0.19643
#     Total Mole Fraction methane   dimensionless        0.085074          1.0000e-08       0.083912
#     Total Mole Fraction ethane    dimensionless         0.31209             0.26075        0.31139
#     Total Mole Fraction propane   dimensionless         0.11282             0.19944        0.11401
#     Total Mole Fraction nbutane   dimensionless        0.036866            0.092801       0.037630
#     Total Mole Fraction ibutane   dimensionless        0.026964            0.063953       0.027469
#     Total Mole Fraction pentane   dimensionless        0.019327            0.052011       0.019773
#     Total Mole Fraction hexane    dimensionless       0.0027162           0.0070006      0.0027747
#     Total Mole Fraction heptane   dimensionless      0.00049822           0.0011851     0.00050760
#     Total Mole Fraction octane    dimensionless      9.3105e-05          0.00020270     9.4602e-05
#     Total Mole Fraction ethylene  dimensionless        0.065988            0.040612       0.065641
#     Total Mole Fraction propene   dimensionless        0.076959             0.12672       0.077638
#     Total Mole Fraction butene    dimensionless        0.025775            0.062968       0.026283
#     Total Mole Fraction pentene   dimensionless        0.019458            0.052133       0.019905
#     Total Mole Fraction hexene    dimensionless       0.0096702            0.025217      0.0098825
#     Total Mole Fraction heptene   dimensionless       0.0032456           0.0077170      0.0033067
#     Total Mole Fraction octene    dimensionless       0.0017626           0.0038963      0.0017917
#     Total Mole Fraction nonene    dimensionless       0.0015371           0.0033978      0.0015625
#     Temperature                          kelvin          305.95              345.72         306.72
#     Pressure                             pascal      4.3712e+05          4.0000e+05     4.0000e+05
# ====================================================================================
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.mixed_state: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.mixed_state: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.purge_state: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.purge_state: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.purge_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.purge_state: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.purge_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.recycle_state: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.recycle_state: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.recycle_state: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.recycle_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.S102.mixed_state: State released.
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     429.55     4.2955     425.25
#     Total Mole Fraction hydrogen  dimensionless    0.19643    0.19643    0.19643
#     Total Mole Fraction methane   dimensionless   0.083912   0.083912   0.083912
#     Total Mole Fraction ethane    dimensionless    0.31139    0.31139    0.31139
#     Total Mole Fraction propane   dimensionless    0.11401    0.11401    0.11401
#     Total Mole Fraction nbutane   dimensionless   0.037630   0.037630   0.037630
#     Total Mole Fraction ibutane   dimensionless   0.027469   0.027469   0.027469
#     Total Mole Fraction pentane   dimensionless   0.019773   0.019773   0.019773
#     Total Mole Fraction hexane    dimensionless  0.0027747  0.0027747  0.0027747
#     Total Mole Fraction heptane   dimensionless 0.00050760 0.00050760 0.00050760
#     Total Mole Fraction octane    dimensionless 9.4602e-05 9.4602e-05 9.4602e-05
#     Total Mole Fraction ethylene  dimensionless   0.065641   0.065641   0.065641
#     Total Mole Fraction propene   dimensionless   0.077638   0.077638   0.077638
#     Total Mole Fraction butene    dimensionless   0.026283   0.026283   0.026283
#     Total Mole Fraction pentene   dimensionless   0.019905   0.019905   0.019905
#     Total Mole Fraction hexene    dimensionless  0.0098825  0.0098825  0.0098825
#     Total Mole Fraction heptene   dimensionless  0.0033067  0.0033067  0.0033067
#     Total Mole Fraction octene    dimensionless  0.0017917  0.0017917  0.0017917
#     Total Mole Fraction nonene    dimensionless  0.0015625  0.0015625  0.0015625
#     Temperature                          kelvin     306.72     306.72     306.72
#     Pressure                             pascal 4.0000e+05 4.0000e+05 4.0000e+05
# ====================================================================================
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_in: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_in: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_out: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_out: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_out: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.control_volume.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102: Initialization Step 1 Complete.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.properties_isentropic: Starting initialization
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.properties_isentropic: State variable initialization completed.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.properties_isentropic: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.properties_isentropic: State released.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102.properties_isentropic: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:50 [INFO] idaes.init.fs.C102: Initialization Step 2 Complete.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.C102: Initialization Step 3 optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.C102: Initialization Step 4 optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.C102.control_volume.properties_in: State released.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.C102: Initialization Complete: optimal - Optimal Solution Found
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 7.4255e+05 :          watt : False : (None, None)
#           Pressure Change : 3.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.7500 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     425.25     425.25
#     Total Mole Fraction hydrogen  dimensionless    0.19643    0.19643
#     Total Mole Fraction methane   dimensionless   0.083912   0.083912
#     Total Mole Fraction ethane    dimensionless    0.31139    0.31139
#     Total Mole Fraction propane   dimensionless    0.11401    0.11401
#     Total Mole Fraction nbutane   dimensionless   0.037630   0.037630
#     Total Mole Fraction ibutane   dimensionless   0.027469   0.027469
#     Total Mole Fraction pentane   dimensionless   0.019773   0.019773
#     Total Mole Fraction hexane    dimensionless  0.0027747  0.0027747
#     Total Mole Fraction heptane   dimensionless 0.00050760 0.00050760
#     Total Mole Fraction octane    dimensionless 9.4602e-05 9.4602e-05
#     Total Mole Fraction ethylene  dimensionless   0.065641   0.065641
#     Total Mole Fraction propene   dimensionless   0.077638   0.077638
#     Total Mole Fraction butene    dimensionless   0.026283   0.026283
#     Total Mole Fraction pentene   dimensionless   0.019905   0.019905
#     Total Mole Fraction hexene    dimensionless  0.0098825  0.0098825
#     Total Mole Fraction heptene   dimensionless  0.0033067  0.0033067
#     Total Mole Fraction octene    dimensionless  0.0017917  0.0017917
#     Total Mole Fraction nonene    dimensionless  0.0015625  0.0015625
#     Temperature                          kelvin     306.72     335.54
#     Pressure                             pascal 4.0000e+05 7.0000e+05
# ====================================================================================
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.feed_state: Starting initialization
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.feed_state: State variable initialization completed.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.feed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.recycle_state: Starting initialization
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.recycle_state: State variable initialization completed.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.recycle_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.mixed_state: Starting initialization
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.mixed_state: State variable initialization completed.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.mixed_state: State released.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101: Initialization Complete: optimal - Optimal Solution Found
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.feed_state: State released.
# 2023-05-22 22:52:51 [INFO] idaes.init.fs.M101.recycle_state: State released.
#
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     425.25     906.64
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.19643   0.092135
#     Total Mole Fraction methane   dimensionless   0.081100   0.083912   0.082419
#     Total Mole Fraction ethane    dimensionless    0.46920    0.31139    0.39518
#     Total Mole Fraction propane   dimensionless    0.30920    0.11401    0.21765
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.037630   0.059277
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.027469   0.026955
#     Total Mole Fraction pentane   dimensionless   0.025800   0.019773   0.022973
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0027747  0.0045403
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00050760  0.0015655
#     Total Mole Fraction octane    dimensionless  0.0012000 9.4602e-05 0.00068152
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06   0.065641   0.030789
#     Total Mole Fraction propene   dimensionless 1.0000e-06   0.077638   0.036416
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.026283   0.012328
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.019905  0.0093366
#     Total Mole Fraction hexene    dimensionless 1.0000e-06  0.0098825  0.0046358
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0033067  0.0015515
#     Total Mole Fraction octene    dimensionless 1.0000e-06  0.0017917 0.00084092
#     Total Mole Fraction nonene    dimensionless 1.0000e-06  0.0015625 0.00073340
#     Temperature                          kelvin     308.00     335.54     320.23
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================

# %%
# Fix H105 DoFs: outlet T
m.fs.H105.outlet.temperature.fix()

# Fix F101 DoF: pressure drop
m.fs.F101.deltaP.fix()

# Fix H106 DoFs: outlet T and P
m.fs.H106.outlet.pressure.fix()
# m.fs.H106.outlet.temperature.fix()

# Fix F102 DoF: pressure drop
m.fs.F102.deltaP.fix()

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))
# Out:
# The final DOF of initialized flowsheet is 0

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code))

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %% [markdown]
# # Flowsheet convergence

# %% [markdown]
# ## Unfix purge fraction for optimization

# %%
m.fs.C102.inlet.flow_mol.unfix()
m.fs.M101.recycle.flow_mol.unfix()

for k,v in inlet_composition_dict.items():
    m.fs.C102.inlet.mole_frac_comp[0, k].unfix()
    m.fs.M101.recycle.mole_frac_comp[0, k].unfix()
m.fs.S102.split_fraction[0, "purge"].unfix()
def recycle_converge(blk):
    return blk.M101.recycle.flow_mol[0] - blk.S102.inlet.flow_mol[0]*0.99 == 0.0

m.fs.recycle_converge_constraint = Constraint(rule=recycle_converge)

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':100
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32673
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16873
#
# Total number of variables............................:     5473
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5473
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.71e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.05e+04 3.07e+09  -1.0 3.33e+08    -  3.21e-06 1.79e-01h  1
#    2  0.0000000e+00 2.58e+04 2.87e+09  -1.0 1.81e+08    -  1.98e-01 1.52e-01h  1
#    3  0.0000000e+00 2.57e+04 2.86e+09  -1.0 1.15e+08    -  2.66e-01 3.74e-03h  1
#    4  0.0000000e+00 2.57e+04 2.86e+09  -1.0 1.14e+08    -  3.73e-01 3.91e-05h  1
#    5  0.0000000e+00 2.47e+04 6.94e+11  -1.0 1.14e+08    -  4.14e-01 4.08e-02h  1
#    6  0.0000000e+00 2.45e+04 1.79e+12  -1.0 1.00e+08    -  5.29e-01 6.97e-03h  1
#    7  0.0000000e+00 2.45e+04 1.82e+12  -1.0 4.36e-04  16.0 2.65e-01 4.18e-01h  1
#    8  0.0000000e+00 6.32e+03 1.43e+16  -1.0 1.01e+08    -  2.55e-01 7.42e-01h  1
#    9  0.0000000e+00 3.62e+00 3.50e+15  -1.0 3.97e+07    -  2.03e-03 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 2.41e+01 2.22e+15  -1.0 1.27e+08    -  4.18e-05 8.24e-01F  1
#   11  0.0000000e+00 1.64e+01 1.22e+16  -1.0 2.23e+07    -  1.54e-03 1.00e+00h  1
#   12  0.0000000e+00 2.77e+00 8.91e+14  -1.0 1.08e+07    -  8.02e-01 1.00e+00h  1
#   13  0.0000000e+00 2.64e-02 3.43e+12  -1.0 1.07e+06    -  9.84e-01 1.00e+00h  1
#   14  0.0000000e+00 5.23e-05 8.26e+08  -1.0 5.55e+04    -  9.90e-01 1.00e+00h  1
#   15  0.0000000e+00 1.22e-10 1.23e+02  -1.0 5.76e+01    -  9.90e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   9.9999999999990016e+06    9.9999999999990016e+06
# Constraint violation....:   1.6722487163254750e-11    1.2232703738845885e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.6722487163254750e-11    9.9999999999990016e+06
#
#
# Number of objective function evaluations             = 18
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 18
# Number of inequality constraint evaluations          = 18
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =     36.342
# Total CPU secs in NLP function evaluations           =    488.559
#
# EXIT: Optimal Solution Found.

# %%
# for i in large_residuals_set(m):
#     print(i,'\t',i())

# %% [markdown]
# ## Fix purge fraction to 0.01 and re-solve

# %%
m.fs.S102.split_fraction[0, "purge"].unfix()
m.fs.S102.split_fraction[0, "purge"].fix(0.01)
m.fs.del_component(m.fs.recycle_converge_constraint)

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':500
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32652
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16854
#
# Total number of variables............................:     5472
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5472
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.22e-10 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   1.3350209826512582e-11    1.2232703738845885e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.3350209826512582e-11    1.2232703738845885e-10
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =     40.116
# Total CPU secs in NLP function evaluations           =      2.030
#
# EXIT: Optimal Solution Found.

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     2204.2     2685.6
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.12383    0.10163
#     Total Mole Fraction methane   dimensionless   0.081100    0.18827    0.16906
#     Total Mole Fraction ethane    dimensionless    0.46920    0.14554    0.20355
#     Total Mole Fraction propane   dimensionless    0.30920   0.032971   0.082484
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.013400   0.025051
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.086905   0.076078
#     Total Mole Fraction pentane   dimensionless   0.025800   0.017018   0.018592
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0013007  0.0021609
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00017417 0.00059106
#     Total Mole Fraction octane    dimensionless  0.0012000 2.8704e-05 0.00023865
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06    0.16687    0.13696
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.13664    0.11215
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.043427   0.035643
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.025971   0.021316
#     Total Mole Fraction hexene    dimensionless 1.0000e-06   0.010918  0.0089610
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0034824  0.0028584
#     Total Mole Fraction octene    dimensionless 1.0000e-06  0.0017743  0.0014564
#     Total Mole Fraction nonene    dimensionless 1.0000e-06  0.0014912  0.0012241
#     Temperature                          kelvin     308.00     330.72     326.27
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.2029e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2685.6     2685.6
#     Total Mole Fraction hydrogen  dimensionless    0.10163    0.10163
#     Total Mole Fraction methane   dimensionless    0.16906    0.16906
#     Total Mole Fraction ethane    dimensionless    0.20355    0.20355
#     Total Mole Fraction propane   dimensionless   0.082484   0.082484
#     Total Mole Fraction nbutane   dimensionless   0.025051   0.025051
#     Total Mole Fraction ibutane   dimensionless   0.076078   0.076078
#     Total Mole Fraction pentane   dimensionless   0.018592   0.018592
#     Total Mole Fraction hexane    dimensionless  0.0021609  0.0021609
#     Total Mole Fraction heptane   dimensionless 0.00059106 0.00059106
#     Total Mole Fraction octane    dimensionless 0.00023865 0.00023865
#     Total Mole Fraction ethylene  dimensionless    0.13696    0.13696
#     Total Mole Fraction propene   dimensionless    0.11215    0.11215
#     Total Mole Fraction butene    dimensionless   0.035643   0.035643
#     Total Mole Fraction pentene   dimensionless   0.021316   0.021316
#     Total Mole Fraction hexene    dimensionless  0.0089610  0.0089610
#     Total Mole Fraction heptene   dimensionless  0.0028584  0.0028584
#     Total Mole Fraction octene    dimensionless  0.0014564  0.0014564
#     Total Mole Fraction nonene    dimensionless  0.0012241  0.0012241
#     Temperature                          kelvin     326.27     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.2434e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     194.94 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     146.91 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     34.903 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2685.6     3062.4
#     Total Mole Fraction hydrogen  dimensionless    0.10163    0.21215
#     Total Mole Fraction methane   dimensionless    0.16906    0.14826
#     Total Mole Fraction ethane    dimensionless    0.20355    0.11485
#     Total Mole Fraction propane   dimensionless   0.082484   0.024363
#     Total Mole Fraction nbutane   dimensionless   0.025051   0.010571
#     Total Mole Fraction ibutane   dimensionless   0.076078   0.066718
#     Total Mole Fraction pentane   dimensionless   0.018592   0.016305
#     Total Mole Fraction hexane    dimensionless  0.0021609  0.0018951
#     Total Mole Fraction heptane   dimensionless 0.00059106 0.00051835
#     Total Mole Fraction octane    dimensionless 0.00023865 0.00020929
#     Total Mole Fraction ethylene  dimensionless    0.13696    0.18376
#     Total Mole Fraction propene   dimensionless    0.11215    0.14632
#     Total Mole Fraction butene    dimensionless   0.035643   0.042655
#     Total Mole Fraction pentene   dimensionless   0.021316   0.018693
#     Total Mole Fraction hexene    dimensionless  0.0089610  0.0078586
#     Total Mole Fraction heptene   dimensionless  0.0028584  0.0025067
#     Total Mole Fraction octene    dimensionless  0.0014564  0.0012772
#     Total Mole Fraction nonene    dimensionless  0.0012241  0.0010735
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.8694e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     3062.4     3062.4
#     Total Mole Fraction hydrogen  dimensionless    0.21215    0.21215
#     Total Mole Fraction methane   dimensionless    0.14826    0.14826
#     Total Mole Fraction ethane    dimensionless    0.11485    0.11485
#     Total Mole Fraction propane   dimensionless   0.024363   0.024363
#     Total Mole Fraction nbutane   dimensionless   0.010571   0.010571
#     Total Mole Fraction ibutane   dimensionless   0.066718   0.066718
#     Total Mole Fraction pentane   dimensionless   0.016305   0.016305
#     Total Mole Fraction hexane    dimensionless  0.0018951  0.0018951
#     Total Mole Fraction heptane   dimensionless 0.00051835 0.00051835
#     Total Mole Fraction octane    dimensionless 0.00020929 0.00020929
#     Total Mole Fraction ethylene  dimensionless    0.18376    0.18376
#     Total Mole Fraction propene   dimensionless    0.14632    0.14632
#     Total Mole Fraction butene    dimensionless   0.042655   0.042655
#     Total Mole Fraction pentene   dimensionless   0.018693   0.018693
#     Total Mole Fraction hexene    dimensionless  0.0078586  0.0078586
#     Total Mole Fraction heptene   dimensionless  0.0025067  0.0025067
#     Total Mole Fraction octene    dimensionless  0.0012772  0.0012772
#     Total Mole Fraction nonene    dimensionless  0.0010735  0.0010735
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     3062.4     479.04     2583.4
#     Total Mole Fraction hydrogen  dimensionless    0.21215    0.78073    0.10672
#     Total Mole Fraction methane   dimensionless    0.14826   0.072747    0.16226
#     Total Mole Fraction ethane    dimensionless    0.11485   0.056355    0.12570
#     Total Mole Fraction propane   dimensionless   0.024363 1.5575e-09   0.028880
#     Total Mole Fraction nbutane   dimensionless   0.010571 6.7580e-10   0.012532
#     Total Mole Fraction ibutane   dimensionless   0.066718 4.2652e-09   0.079090
#     Total Mole Fraction pentane   dimensionless   0.016305 1.0423e-09   0.019328
#     Total Mole Fraction hexane    dimensionless  0.0018951 1.2115e-10  0.0022465
#     Total Mole Fraction heptane   dimensionless 0.00051835 3.3137e-11 0.00061446
#     Total Mole Fraction octane    dimensionless 0.00020929 1.3380e-11 0.00024810
#     Total Mole Fraction ethylene  dimensionless    0.18376   0.090167    0.20112
#     Total Mole Fraction propene   dimensionless    0.14632 9.3541e-09    0.17346
#     Total Mole Fraction butene    dimensionless   0.042655 2.7269e-09   0.050565
#     Total Mole Fraction pentene   dimensionless   0.018693 1.1950e-09   0.022160
#     Total Mole Fraction hexene    dimensionless  0.0078586 5.0238e-10  0.0093158
#     Total Mole Fraction heptene   dimensionless  0.0025067 1.6025e-10  0.0029716
#     Total Mole Fraction octene    dimensionless  0.0012772 8.1651e-11  0.0015141
#     Total Mole Fraction nonene    dimensionless  0.0010735 6.8626e-11  0.0012726
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.3249e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     479.04     479.04
#     Total Mole Fraction hydrogen  dimensionless    0.78073    0.78073
#     Total Mole Fraction methane   dimensionless   0.072747   0.072747
#     Total Mole Fraction ethane    dimensionless   0.056355   0.056355
#     Total Mole Fraction ethylene  dimensionless   0.090167   0.090167
#     Temperature                          kelvin     473.00     329.84
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.2525e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2583.4     2583.4
#     Total Mole Fraction hydrogen  dimensionless    0.10672    0.10672
#     Total Mole Fraction methane   dimensionless    0.16226    0.16226
#     Total Mole Fraction ethane    dimensionless    0.12570    0.12570
#     Total Mole Fraction propane   dimensionless   0.028880   0.028880
#     Total Mole Fraction nbutane   dimensionless   0.012532   0.012532
#     Total Mole Fraction ibutane   dimensionless   0.079090   0.079090
#     Total Mole Fraction pentane   dimensionless   0.019328   0.019328
#     Total Mole Fraction hexane    dimensionless  0.0022465  0.0022465
#     Total Mole Fraction heptane   dimensionless 0.00061446 0.00061446
#     Total Mole Fraction octane    dimensionless 0.00024810 0.00024810
#     Total Mole Fraction ethylene  dimensionless    0.20112    0.20112
#     Total Mole Fraction propene   dimensionless    0.17346    0.17346
#     Total Mole Fraction butene    dimensionless   0.050565   0.050565
#     Total Mole Fraction pentene   dimensionless   0.022160   0.022160
#     Total Mole Fraction hexene    dimensionless  0.0093158  0.0093158
#     Total Mole Fraction heptene   dimensionless  0.0029716  0.0029716
#     Total Mole Fraction octene    dimensionless  0.0015141  0.0015141
#     Total Mole Fraction nonene    dimensionless  0.0012726  0.0012726
#     Temperature                          kelvin     473.00     573.00
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2583.4     2381.4
#     Total Mole Fraction hydrogen  dimensionless    0.10672    0.11577
#     Total Mole Fraction methane   dimensionless    0.16226    0.17602
#     Total Mole Fraction ethane    dimensionless    0.12570    0.13636
#     Total Mole Fraction propane   dimensionless   0.028880   0.031329
#     Total Mole Fraction nbutane   dimensionless   0.012532   0.013594
#     Total Mole Fraction ibutane   dimensionless   0.079090   0.085795
#     Total Mole Fraction pentane   dimensionless   0.019328   0.020967
#     Total Mole Fraction hexane    dimensionless  0.0022465  0.0024370
#     Total Mole Fraction heptane   dimensionless 0.00061446 0.00066656
#     Total Mole Fraction octane    dimensionless 0.00024810 0.00026914
#     Total Mole Fraction ethylene  dimensionless    0.20112    0.15617
#     Total Mole Fraction propene   dimensionless    0.17346    0.12941
#     Total Mole Fraction butene    dimensionless   0.050565   0.043371
#     Total Mole Fraction pentene   dimensionless   0.022160   0.029530
#     Total Mole Fraction hexene    dimensionless  0.0093158   0.018746
#     Total Mole Fraction heptene   dimensionless  0.0029716   0.013417
#     Total Mole Fraction octene    dimensionless  0.0015141   0.014204
#     Total Mole Fraction nonene    dimensionless  0.0012726   0.011938
#     Temperature                          kelvin     573.00     573.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.2649e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2381.4     2381.4
#     Total Mole Fraction hydrogen  dimensionless    0.11577    0.11577
#     Total Mole Fraction methane   dimensionless    0.17602    0.17602
#     Total Mole Fraction ethane    dimensionless    0.13636    0.13636
#     Total Mole Fraction propane   dimensionless   0.031329   0.031329
#     Total Mole Fraction nbutane   dimensionless   0.013594   0.013594
#     Total Mole Fraction ibutane   dimensionless   0.085795   0.085795
#     Total Mole Fraction pentane   dimensionless   0.020967   0.020967
#     Total Mole Fraction hexane    dimensionless  0.0024370  0.0024370
#     Total Mole Fraction heptane   dimensionless 0.00066656 0.00066656
#     Total Mole Fraction octane    dimensionless 0.00026914 0.00026914
#     Total Mole Fraction ethylene  dimensionless    0.15617    0.15617
#     Total Mole Fraction propene   dimensionless    0.12941    0.12941
#     Total Mole Fraction butene    dimensionless   0.043371   0.043371
#     Total Mole Fraction pentene   dimensionless   0.029530   0.029530
#     Total Mole Fraction hexene    dimensionless   0.018746   0.018746
#     Total Mole Fraction heptene   dimensionless   0.013417   0.013417
#     Total Mole Fraction octene    dimensionless   0.014204   0.014204
#     Total Mole Fraction nonene    dimensionless   0.011938   0.011938
#     Temperature                          kelvin     573.00     308.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     479.04     479.04
#     Total Mole Fraction hydrogen  dimensionless    0.78073    0.78073
#     Total Mole Fraction methane   dimensionless   0.072747   0.072747
#     Total Mole Fraction ethane    dimensionless   0.056355   0.056355
#     Total Mole Fraction propane   dimensionless 1.5575e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.7580e-10          -
#     Total Mole Fraction ibutane   dimensionless 4.2652e-09          -
#     Total Mole Fraction pentane   dimensionless 1.0423e-09          -
#     Total Mole Fraction hexane    dimensionless 1.2115e-10          -
#     Total Mole Fraction heptane   dimensionless 3.3137e-11          -
#     Total Mole Fraction octane    dimensionless 1.3380e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.090167   0.090167
#     Total Mole Fraction propene   dimensionless 9.3541e-09          -
#     Total Mole Fraction butene    dimensionless 2.7269e-09          -
#     Total Mole Fraction pentene   dimensionless 1.1950e-09          -
#     Total Mole Fraction hexene    dimensionless 5.0238e-10          -
#     Total Mole Fraction heptene   dimensionless 1.6025e-10          -
#     Total Mole Fraction octene    dimensionless 8.1651e-11          -
#     Total Mole Fraction nonene    dimensionless 6.8626e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.3251e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     3.7995
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     2.7692
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     3.6311
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     17.052
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     14.116
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     3.1210
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2318
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.58207
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     3.0032
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     9.9594
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     9.8977
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     15.310
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     22.062
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     24.843
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     30.194
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     25.377
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.70     275.70
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     324.73     320.93
#     Molar Flowrate ('Vap', 'propane')   mole / second     74.608     71.839
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     32.374     28.743
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     204.32     187.27
#     Molar Flowrate ('Vap', 'pentane')   mole / second     49.932     35.816
#     Molar Flowrate ('Vap', 'hexane')    mole / second     5.8035     2.6825
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.5874    0.35555
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.64094   0.058867
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     371.92     368.91
#     Molar Flowrate ('Vap', 'propene')   mole / second     308.19     298.23
#     Molar Flowrate ('Vap', 'butene')    mole / second     103.28     93.387
#     Molar Flowrate ('Vap', 'pentene')   mole / second     70.324     55.014
#     Molar Flowrate ('Vap', 'hexene')    mole / second     44.642     22.580
#     Molar Flowrate ('Vap', 'heptene')   mole / second     31.952     7.1087
#     Molar Flowrate ('Vap', 'octene')    mole / second     33.827     3.6331
#     Molar Flowrate ('Vap', 'nonene')    mole / second     28.430     3.0535
#     Temperature                                kelvin     308.00     307.93
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -62883. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     3.7995            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.7692            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     3.6311            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     17.052            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     14.116            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     3.1210            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2318            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.58207            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     3.0032            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     9.9594            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     9.8977            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     15.310            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     22.062            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     24.843            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     30.194            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     25.377            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     275.70            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     320.93            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     71.839            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     28.743            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     187.27            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     35.816            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     2.6825            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.35555            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.058867            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     368.91            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     298.23            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     93.387            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     55.014            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     22.580            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     7.1087            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     3.6331            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second     3.0535            -             -
#     Temperature                                     kelvin     307.93            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        3.2154
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.3918
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        3.2203
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        14.997
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.959
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9745
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2079
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57827
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.5268
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        8.5813
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        8.7398
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        13.897
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        20.902
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        24.363
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        29.955
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        25.176
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       275.70    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       321.51    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       72.217    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       29.153    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       189.32    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       36.974    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       2.8291    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.37953    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.062667    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       369.39    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       299.61    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       94.545    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       56.427    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       23.740    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       7.5887    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       3.8724    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -       3.2546    1.0000e-08
#     temperature                                     kelvin          -       305.93        305.93
#     pressure                                        pascal          -   4.3712e+05    4.3712e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units : Fixed : Bounds
#     Heat Duty : -10562. :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     3.2154     1.1535
#     Molar Flowrate ('Liq', 'propane')   mole / second     2.3918     1.5904
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     3.2203     2.8231
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     14.997     12.495
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.959     12.444
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9745     2.9365
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2079     1.2030
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57827    0.57752
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.5268    0.68858
#     Molar Flowrate ('Liq', 'propene')   mole / second     8.5813     5.4072
#     Molar Flowrate ('Liq', 'butene')    mole / second     8.7398     7.4707
#     Molar Flowrate ('Liq', 'pentene')   mole / second     13.897     13.108
#     Molar Flowrate ('Liq', 'hexene')    mole / second     20.902     20.581
#     Molar Flowrate ('Liq', 'heptene')   mole / second     24.363     24.267
#     Molar Flowrate ('Liq', 'octene')    mole / second     29.955     29.908
#     Molar Flowrate ('Liq', 'nonene')    mole / second     25.176     25.137
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     2.0619
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.80140
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.39724
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     2.5020
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.51519
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.037958
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0048057
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00074579
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.8382
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     3.1741
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08     1.2692
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.78844
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.32139
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.095995
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.046593
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.039160
#     Temperature                                kelvin     305.93     298.00
#     Pressure                                   pascal 4.3712e+05 1.4420e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -42236. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     1.1535            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     1.5904            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     2.8231            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     12.495            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.444            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9365            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2030            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57752            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second    0.68858            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     5.4072            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     7.4707            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     13.108            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     20.581            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     24.267            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     29.908            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     25.137            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     2.0619            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.80140            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.39724            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     2.5020            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.51519            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.037958            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0048057            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00074579            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.8382            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     3.1741            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     1.2692            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.78844            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.32139            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.095995            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.046593            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.039160            -             -
#     Temperature                                     kelvin     298.00            -             -
#     Pressure                                        pascal 1.4420e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08       0.69044
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        1.1984
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        2.5393
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        10.822
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.041
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9075
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.1996
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57703
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.38752
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        3.9659
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        6.5940
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        12.500
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        20.333
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        24.198
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        29.877
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        25.110
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       2.5249    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       1.1934    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.68107    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       4.1755    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.91792    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.066958    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0082562    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -    0.0012430    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       2.1393    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       4.6154    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       2.1459    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       1.3971    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.56893    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -      0.16499    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.078040    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.065590    1.0000e-08
#     temperature                                     kelvin          -       293.51        293.51
#     pressure                                        pascal          -   1.0197e+05    1.0197e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2381.4          -
#     Total Mole Fraction hydrogen        dimensionless    0.11577          -
#     Total Mole Fraction methane         dimensionless    0.17602          -
#     Total Mole Fraction ethane          dimensionless    0.13636          -
#     Total Mole Fraction propane         dimensionless   0.031329          -
#     Total Mole Fraction nbutane         dimensionless   0.013594          -
#     Total Mole Fraction ibutane         dimensionless   0.085795          -
#     Total Mole Fraction pentane         dimensionless   0.020967          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     275.70
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     324.73
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     74.608
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     32.374
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     204.32
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     49.932
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     5.8035
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.5874
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.64094
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     371.92
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     308.19
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     103.28
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     70.324
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     44.642
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     31.952
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     33.827
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     28.430
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.70          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     321.51          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     72.217          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     29.153          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     189.32          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     36.974          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     2.8291          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.37953          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.062667          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     369.39          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     299.61          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     94.545          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     56.427          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     23.740          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     7.5887          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     3.8724          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second     3.2546          -
#     Temperature                                kelvin     305.93     305.93
#     Pressure                                   pascal 4.3712e+05 4.3712e+05
#     Total Molar Flowrate                mole / second          -     2205.8
#     Total Mole Fraction hydrogen        dimensionless          -    0.12499
#     Total Mole Fraction methane         dimensionless          -    0.19004
#     Total Mole Fraction ethane          dimensionless          -    0.14576
#     Total Mole Fraction propane         dimensionless          -   0.032740
#     Total Mole Fraction nbutane         dimensionless          -   0.013217
#     Total Mole Fraction ibutane         dimensionless          -   0.085830
#     Total Mole Fraction pentane         dimensionless          -   0.016762
#     Total Mole Fraction hexane          dimensionless          -  0.0012826
#     Total Mole Fraction heptane         dimensionless          - 0.00017206
#     Total Mole Fraction octane          dimensionless          - 2.8411e-05
#     Total Mole Fraction ethylene        dimensionless          -    0.16747
#     Total Mole Fraction propene         dimensionless          -    0.13583
#     Total Mole Fraction butene          dimensionless          -   0.042863
#     Total Mole Fraction pentene         dimensionless          -   0.025582
#     Total Mole Fraction hexene          dimensionless          -   0.010763
#     Total Mole Fraction heptene         dimensionless          -  0.0034404
#     Total Mole Fraction octene          dimensionless          -  0.0017556
#     Total Mole Fraction nonene          dimensionless          -  0.0014755
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     93428. :          watt : False : (None, None)
#           Pressure Change : 3.3515e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     4.2869 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     20.744     20.744
#     Total Mole Fraction ethane    dimensionless    0.12172    0.12172
#     Total Mole Fraction propane   dimensionless   0.057527   0.057527
#     Total Mole Fraction nbutane   dimensionless   0.032832   0.032832
#     Total Mole Fraction ibutane   dimensionless    0.20128    0.20128
#     Total Mole Fraction pentane   dimensionless   0.044249   0.044249
#     Total Mole Fraction hexane    dimensionless  0.0032277  0.0032277
#     Total Mole Fraction heptane   dimensionless 0.00039800 0.00039800
#     Total Mole Fraction octane    dimensionless 5.9918e-05 5.9918e-05
#     Total Mole Fraction ethylene  dimensionless    0.10313    0.10313
#     Total Mole Fraction propene   dimensionless    0.22249    0.22249
#     Total Mole Fraction butene    dimensionless    0.10344    0.10344
#     Total Mole Fraction pentene   dimensionless   0.067347   0.067347
#     Total Mole Fraction hexene    dimensionless   0.027426   0.027426
#     Total Mole Fraction heptene   dimensionless  0.0079533  0.0079533
#     Total Mole Fraction octene    dimensionless  0.0037620  0.0037620
#     Total Mole Fraction nonene    dimensionless  0.0031618  0.0031618
#     Temperature                          kelvin     293.51     346.88
#     Pressure                             pascal 1.0197e+05 4.3712e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          2205.8              20.744         2226.5
#     Total Mole Fraction hydrogen  dimensionless         0.12499          1.0000e-08        0.12383
#     Total Mole Fraction methane   dimensionless         0.19004          1.0000e-08        0.18827
#     Total Mole Fraction ethane    dimensionless         0.14576             0.12172        0.14554
#     Total Mole Fraction propane   dimensionless        0.032740            0.057527       0.032971
#     Total Mole Fraction nbutane   dimensionless        0.013217            0.032832       0.013400
#     Total Mole Fraction ibutane   dimensionless        0.085830             0.20128       0.086905
#     Total Mole Fraction pentane   dimensionless        0.016762            0.044249       0.017018
#     Total Mole Fraction hexane    dimensionless       0.0012826           0.0032277      0.0013007
#     Total Mole Fraction heptane   dimensionless      0.00017206          0.00039800     0.00017417
#     Total Mole Fraction octane    dimensionless      2.8411e-05          5.9918e-05     2.8704e-05
#     Total Mole Fraction ethylene  dimensionless         0.16747             0.10313        0.16687
#     Total Mole Fraction propene   dimensionless         0.13583             0.22249        0.13664
#     Total Mole Fraction butene    dimensionless        0.042863             0.10344       0.043427
#     Total Mole Fraction pentene   dimensionless        0.025582            0.067347       0.025971
#     Total Mole Fraction hexene    dimensionless        0.010763            0.027426       0.010918
#     Total Mole Fraction heptene   dimensionless       0.0034404           0.0079533      0.0034824
#     Total Mole Fraction octene    dimensionless       0.0017556           0.0037620      0.0017743
#     Total Mole Fraction nonene    dimensionless       0.0014755           0.0031618      0.0014912
#     Temperature                          kelvin          305.93              346.88         306.49
#     Pressure                             pascal      4.3712e+05          4.3712e+05     4.3712e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     2226.5     22.265     2204.2
#     Total Mole Fraction hydrogen  dimensionless    0.12383    0.12383    0.12383
#     Total Mole Fraction methane   dimensionless    0.18827    0.18827    0.18827
#     Total Mole Fraction ethane    dimensionless    0.14554    0.14554    0.14554
#     Total Mole Fraction propane   dimensionless   0.032971   0.032971   0.032971
#     Total Mole Fraction nbutane   dimensionless   0.013400   0.013400   0.013400
#     Total Mole Fraction ibutane   dimensionless   0.086905   0.086905   0.086905
#     Total Mole Fraction pentane   dimensionless   0.017018   0.017018   0.017018
#     Total Mole Fraction hexane    dimensionless  0.0013007  0.0013007  0.0013007
#     Total Mole Fraction heptane   dimensionless 0.00017417 0.00017417 0.00017417
#     Total Mole Fraction octane    dimensionless 2.8704e-05 2.8704e-05 2.8704e-05
#     Total Mole Fraction ethylene  dimensionless    0.16687    0.16687    0.16687
#     Total Mole Fraction propene   dimensionless    0.13664    0.13664    0.13664
#     Total Mole Fraction butene    dimensionless   0.043427   0.043427   0.043427
#     Total Mole Fraction pentene   dimensionless   0.025971   0.025971   0.025971
#     Total Mole Fraction hexene    dimensionless   0.010918   0.010918   0.010918
#     Total Mole Fraction heptene   dimensionless  0.0034824  0.0034824  0.0034824
#     Total Mole Fraction octene    dimensionless  0.0017743  0.0017743  0.0017743
#     Total Mole Fraction nonene    dimensionless  0.0014912  0.0014912  0.0014912
#     Temperature                          kelvin     306.49     306.49     306.49
#     Pressure                             pascal 4.3712e+05 4.3712e+05 4.3712e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 3.2164e+06 :          watt : False : (None, None)
#           Pressure Change : 2.6288e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.6014 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2204.2     2204.2
#     Total Mole Fraction hydrogen  dimensionless    0.12383    0.12383
#     Total Mole Fraction methane   dimensionless    0.18827    0.18827
#     Total Mole Fraction ethane    dimensionless    0.14554    0.14554
#     Total Mole Fraction propane   dimensionless   0.032971   0.032971
#     Total Mole Fraction nbutane   dimensionless   0.013400   0.013400
#     Total Mole Fraction ibutane   dimensionless   0.086905   0.086905
#     Total Mole Fraction pentane   dimensionless   0.017018   0.017018
#     Total Mole Fraction hexane    dimensionless  0.0013007  0.0013007
#     Total Mole Fraction heptane   dimensionless 0.00017417 0.00017417
#     Total Mole Fraction octane    dimensionless 2.8704e-05 2.8704e-05
#     Total Mole Fraction ethylene  dimensionless    0.16687    0.16687
#     Total Mole Fraction propene   dimensionless    0.13664    0.13664
#     Total Mole Fraction butene    dimensionless   0.043427   0.043427
#     Total Mole Fraction pentene   dimensionless   0.025971   0.025971
#     Total Mole Fraction hexene    dimensionless   0.010918   0.010918
#     Total Mole Fraction heptene   dimensionless  0.0034824  0.0034824
#     Total Mole Fraction octene    dimensionless  0.0017743  0.0017743
#     Total Mole Fraction nonene    dimensionless  0.0014912  0.0014912
#     Temperature                          kelvin     306.49     330.72
#     Pressure                             pascal 4.3712e+05 7.0000e+05
# ====================================================================================
