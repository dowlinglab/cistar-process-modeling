# %% [markdown]
# # Add costing and emissions calculations to process model

# %% [markdown]
# ## ROK model code = M3

# %%
# simulation case specifications
model_code = 3
case_name = 'Bakken'
c_tax_rate = 4.5e-2 # $/kg CO2e

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                    define_models, \
                                    define_arcs, \
                                    set_unit_model_variables, \
                                    initialize_flowsheet, \
                                    set_scaling_factors,\
                                    update_model_after_initialization,\
                                    vapor_only_to_vapor_liquid_reformulate,\
                                    update_model_for_optimization, \
                                    unfix_DOFs_pre_optimization, \
                                    fix_DOFs_post_optimization

# %% [markdown]
# ## Create flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188}

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Sequence for initialization

# %%
init_file_name = "./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code)
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.04844784736633301,
#  'etime_read_dict': 0.26514196395874023,
#  'etime_read_suffixes': 0.008994817733764648}

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %%
init_file_name = "./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3))
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.06937265396118164,
#  'etime_read_dict': 0.2621908187866211,
#  'etime_read_suffixes': 0.0062732696533203125}

# %% [markdown]
# # Costing

# %%
from src.emissions_calculations import calc_lhv_values, calculate_stream_energies, calculate_emissions, create_ghg_objective
from src.costing_function import add_costing,calculate_costs_for_objective
from src.utility_minimization_1d import (
    min_utility,
    PinchDataClass,
    heat_ex_data,
    gen_curves,
    print_HX_results,
    generate_curves,
    heat_data,
    pinch_calc,
    return_data
)

# %% [markdown]
# ## Equipment costing

# %%
add_costing(m)

# %% [markdown]
# ## Heat integration

# %%
### Heat Exchangers and reactors
min_utility(
    m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102], 10.0
)
m.fs.Qs.fix()

# %% [markdown]
# ## Emissions calculations

# %%
calc_lhv_values(m,case_name,'./LHV.xlsx','NGL_compositions.csv','NGL_fraction.csv')
calculate_stream_energies(m)
calculate_emissions(m,case_name,'emissions_factor_by_region.csv')
create_ghg_objective(m)
calculate_costs_for_objective(m,c_tax_flag=True, c_tax_val = c_tax_rate)

# %%
DOF_initial = degrees_of_freedom(m)
print("The initial DOF is {0}".format(DOF_initial))
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                      'max_iter': 500,
#                   'halt_on_ampl_error':'yes'
                 }
# solve_status = solver.solve(m, tee=True)
solve_status = solver.solve(m, tee=True)

# Save and display results
ms.to_json(m, fname="./initialization_files/CISTAR_solve_with_costing_{}_C_tax_{}_M{}_purge_{}.json.gz".format(case_name,m.fs.c_tax_rate(), model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))
# Out:
# The initial DOF is 0
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    33102
# Number of nonzeros in inequality constraint Jacobian.:      165
# Number of nonzeros in Lagrangian Hessian.............:    17125
#
# Total number of variables............................:     5527
#                      variables with only lower bounds:      188
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5527
# Total number of inequality constraints...............:       70
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       50
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.87e+07 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.07e+06 9.83e+09  -1.0 1.04e+07    -  5.38e-04 1.00e+00h  1
#    2  0.0000000e+00 4.37e-04 5.19e+05  -1.0 1.07e+06    -  9.48e-01 1.00e+00h  1
#    3  0.0000000e+00 5.96e-08 5.19e+03  -1.0 1.13e+00    -  9.90e-01 1.00e+00f  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   1.0000000000011593e+07    1.0000000000011593e+07
# Constraint violation....:   1.4901161193847656e-08    5.9604644775390625e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.4901161193847656e-08    1.0000000000011593e+07
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 4
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 4
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =     37.735
# Total CPU secs in NLP function evaluations           =     82.173
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# ## Save and display results

# %%
CDs = heat_ex_data(m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102])
generate_curves(CDs)

# %%
print_HX_results(m.fs, [m.fs.H101, m.fs.R101, m.fs.H102, m.fs.H103, m.fs.R102, m.fs.H104, m.fs.H105, m.fs.H106])
# Out:
# Heat Exchanger Summary:
# Heat exchanger:  fs.H101
# Inlet T:      324.448 K
# Outlet T:     1073.000 K
# Q :            247668300.781 kg*m**2/s**3
# Heat exchanger:  fs.R101
# Inlet T:      1073.000 K
# Outlet T:     1073.000 K
# Q :            92417983.505 kg*m**2/s**3
# Heat exchanger:  fs.H102
# Inlet T:      1073.000 K
# Outlet T:     473.000 K
# Q :           -210270750.584 kg*m**2/s**3
# Heat exchanger:  fs.H103
# Inlet T:      473.000 K
# Outlet T:     573.000 K
# Q :            25561558.914 kg*m**2/s**3
# Heat exchanger:  fs.R102
# Inlet T:      573.000 K
# Outlet T:     573.000 K
# Q :           -16615467.907 (kg*m/s**3)*m
# Heat exchanger:  fs.H104
# Inlet T:      573.000 K
# Outlet T:     308.000 K
# Q :           -59749844.702 kg*m**2/s**3
# Heat exchanger:  fs.H105
# Inlet T:      308.000 K
# Outlet T:     306.334 K
# Q :           -5584750.109 kg*m**2/s**3
# Heat exchanger:  fs.H106
# Inlet T:      304.426 K
# Outlet T:     298.000 K
# Q :           -38627.189 kg*m**2/s**3

# %%
m.fs.Qs()
# Out:
# 344.5992899395669

# %%
m.fs.Qw()
# Out:
# 80.40104018728475

# %%
m.fs.downstream_emissions() # kg CO2e/GJ fuel
# Out:
# 9.265248258085288

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     2503.6     2984.9
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.10900   0.091424
#     Total Mole Fraction methane   dimensionless   0.081100    0.16576    0.15211
#     Total Mole Fraction ethane    dimensionless    0.46920    0.12809    0.18310
#     Total Mole Fraction propane   dimensionless    0.30920   0.029006   0.074193
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.011807   0.022546
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.076237   0.068215
#     Total Mole Fraction pentane   dimensionless   0.025800   0.015323   0.017012
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0011751  0.0019694
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00015691 0.00053478
#     Total Mole Fraction octane    dimensionless  0.0012000 2.5726e-05 0.00021510
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06    0.17939    0.15046
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.16556    0.13886
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.076740   0.064364
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.024825   0.020821
#     Total Mole Fraction hexene    dimensionless 1.0000e-06   0.010497  0.0088039
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0042626  0.0035754
#     Total Mole Fraction octene    dimensionless 1.0000e-06  0.0011528 0.00096708
#     Total Mole Fraction nonene    dimensionless 1.0000e-06 0.00098047 0.00082251
#     Temperature                          kelvin     308.00     327.91     324.45
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.4767e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2984.9     2984.9
#     Total Mole Fraction hydrogen  dimensionless   0.091424   0.091424
#     Total Mole Fraction methane   dimensionless    0.15211    0.15211
#     Total Mole Fraction ethane    dimensionless    0.18310    0.18310
#     Total Mole Fraction propane   dimensionless   0.074193   0.074193
#     Total Mole Fraction nbutane   dimensionless   0.022546   0.022546
#     Total Mole Fraction ibutane   dimensionless   0.068215   0.068215
#     Total Mole Fraction pentane   dimensionless   0.017012   0.017012
#     Total Mole Fraction hexane    dimensionless  0.0019694  0.0019694
#     Total Mole Fraction heptane   dimensionless 0.00053478 0.00053478
#     Total Mole Fraction octane    dimensionless 0.00021510 0.00021510
#     Total Mole Fraction ethylene  dimensionless    0.15046    0.15046
#     Total Mole Fraction propene   dimensionless    0.13886    0.13886
#     Total Mole Fraction butene    dimensionless   0.064364   0.064364
#     Total Mole Fraction pentene   dimensionless   0.020821   0.020821
#     Total Mole Fraction hexene    dimensionless  0.0088039  0.0088039
#     Total Mole Fraction heptene   dimensionless  0.0035754  0.0035754
#     Total Mole Fraction octene    dimensionless 0.00096708 0.00096708
#     Total Mole Fraction nonene    dimensionless 0.00082251 0.00082251
#     Temperature                          kelvin     324.45     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.2418e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     194.90 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     146.87 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     34.915 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2984.9     3361.6
#     Total Mole Fraction hydrogen  dimensionless   0.091424    0.19324
#     Total Mole Fraction methane   dimensionless    0.15211    0.13506
#     Total Mole Fraction ethane    dimensionless    0.18310    0.10461
#     Total Mole Fraction propane   dimensionless   0.074193   0.022188
#     Total Mole Fraction nbutane   dimensionless   0.022546  0.0096336
#     Total Mole Fraction ibutane   dimensionless   0.068215   0.060571
#     Total Mole Fraction pentane   dimensionless   0.017012   0.015106
#     Total Mole Fraction hexane    dimensionless  0.0019694  0.0017487
#     Total Mole Fraction heptane   dimensionless 0.00053478 0.00047486
#     Total Mole Fraction octane    dimensionless 0.00021510 0.00019100
#     Total Mole Fraction ethylene  dimensionless    0.15046    0.19158
#     Total Mole Fraction propene   dimensionless    0.13886    0.16699
#     Total Mole Fraction butene    dimensionless   0.064364   0.067538
#     Total Mole Fraction pentene   dimensionless   0.020821   0.018488
#     Total Mole Fraction hexene    dimensionless  0.0088039  0.0078173
#     Total Mole Fraction heptene   dimensionless  0.0035754  0.0031747
#     Total Mole Fraction octene    dimensionless 0.00096708 0.00085872
#     Total Mole Fraction nonene    dimensionless 0.00082251 0.00073034
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -2.1027e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     3361.6     3361.6
#     Total Mole Fraction hydrogen  dimensionless    0.19324    0.19324
#     Total Mole Fraction methane   dimensionless    0.13506    0.13506
#     Total Mole Fraction ethane    dimensionless    0.10461    0.10461
#     Total Mole Fraction propane   dimensionless   0.022188   0.022188
#     Total Mole Fraction nbutane   dimensionless  0.0096336  0.0096336
#     Total Mole Fraction ibutane   dimensionless   0.060571   0.060571
#     Total Mole Fraction pentane   dimensionless   0.015106   0.015106
#     Total Mole Fraction hexane    dimensionless  0.0017487  0.0017487
#     Total Mole Fraction heptane   dimensionless 0.00047486 0.00047486
#     Total Mole Fraction octane    dimensionless 0.00019100 0.00019100
#     Total Mole Fraction ethylene  dimensionless    0.19158    0.19158
#     Total Mole Fraction propene   dimensionless    0.16699    0.16699
#     Total Mole Fraction butene    dimensionless   0.067538   0.067538
#     Total Mole Fraction pentene   dimensionless   0.018488   0.018488
#     Total Mole Fraction hexene    dimensionless  0.0078173  0.0078173
#     Total Mole Fraction heptene   dimensionless  0.0031747  0.0031747
#     Total Mole Fraction octene    dimensionless 0.00085872 0.00085872
#     Total Mole Fraction nonene    dimensionless 0.00073034 0.00073034
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     3361.6     485.20     2876.4
#     Total Mole Fraction hydrogen  dimensionless    0.19324    0.77067   0.095831
#     Total Mole Fraction methane   dimensionless    0.13506   0.071823    0.14573
#     Total Mole Fraction ethane    dimensionless    0.10461   0.055627    0.11287
#     Total Mole Fraction propane   dimensionless   0.022188 1.5373e-09   0.025931
#     Total Mole Fraction nbutane   dimensionless  0.0096336 6.6745e-10   0.011259
#     Total Mole Fraction ibutane   dimensionless   0.060571 4.1966e-09   0.070789
#     Total Mole Fraction pentane   dimensionless   0.015106 1.0466e-09   0.017654
#     Total Mole Fraction hexane    dimensionless  0.0017487 1.2116e-10  0.0020437
#     Total Mole Fraction heptane   dimensionless 0.00047486 3.2899e-11 0.00055496
#     Total Mole Fraction octane    dimensionless 0.00019100 1.3233e-11 0.00022322
#     Total Mole Fraction ethylene  dimensionless    0.19158    0.10188    0.20671
#     Total Mole Fraction propene   dimensionless    0.16699 1.1570e-08    0.19516
#     Total Mole Fraction butene    dimensionless   0.067538 4.6793e-09   0.078931
#     Total Mole Fraction pentene   dimensionless   0.018488 1.2809e-09   0.021607
#     Total Mole Fraction hexene    dimensionless  0.0078173 5.4161e-10  0.0091360
#     Total Mole Fraction heptene   dimensionless  0.0031747 2.1995e-10  0.0037102
#     Total Mole Fraction octene    dimensionless 0.00085872 5.9494e-11  0.0010036
#     Total Mole Fraction nonene    dimensionless 0.00073034 5.0600e-11 0.00085354
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.3588e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     485.20     485.20
#     Total Mole Fraction hydrogen  dimensionless    0.77067    0.77067
#     Total Mole Fraction methane   dimensionless   0.071823   0.071823
#     Total Mole Fraction ethane    dimensionless   0.055627   0.055627
#     Total Mole Fraction ethylene  dimensionless    0.10188    0.10188
#     Temperature                          kelvin     473.00     330.74
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.5562e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2876.4     2876.4
#     Total Mole Fraction hydrogen  dimensionless   0.095831   0.095831
#     Total Mole Fraction methane   dimensionless    0.14573    0.14573
#     Total Mole Fraction ethane    dimensionless    0.11287    0.11287
#     Total Mole Fraction propane   dimensionless   0.025931   0.025931
#     Total Mole Fraction nbutane   dimensionless   0.011259   0.011259
#     Total Mole Fraction ibutane   dimensionless   0.070789   0.070789
#     Total Mole Fraction pentane   dimensionless   0.017654   0.017654
#     Total Mole Fraction hexane    dimensionless  0.0020437  0.0020437
#     Total Mole Fraction heptane   dimensionless 0.00055496 0.00055496
#     Total Mole Fraction octane    dimensionless 0.00022322 0.00022322
#     Total Mole Fraction ethylene  dimensionless    0.20671    0.20671
#     Total Mole Fraction propene   dimensionless    0.19516    0.19516
#     Total Mole Fraction butene    dimensionless   0.078931   0.078931
#     Total Mole Fraction pentene   dimensionless   0.021607   0.021607
#     Total Mole Fraction hexene    dimensionless  0.0091360  0.0091360
#     Total Mole Fraction heptene   dimensionless  0.0037102  0.0037102
#     Total Mole Fraction octene    dimensionless  0.0010036  0.0010036
#     Total Mole Fraction nonene    dimensionless 0.00085354 0.00085354
#     Temperature                          kelvin     473.00     573.00
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2876.4     2688.1
#     Total Mole Fraction hydrogen  dimensionless   0.095831    0.10255
#     Total Mole Fraction methane   dimensionless    0.14573    0.15594
#     Total Mole Fraction ethane    dimensionless    0.11287    0.12078
#     Total Mole Fraction propane   dimensionless   0.025931   0.027748
#     Total Mole Fraction nbutane   dimensionless   0.011259   0.012047
#     Total Mole Fraction ibutane   dimensionless   0.070789   0.075748
#     Total Mole Fraction pentane   dimensionless   0.017654   0.018891
#     Total Mole Fraction hexane    dimensionless  0.0020437  0.0021869
#     Total Mole Fraction heptane   dimensionless 0.00055496 0.00059384
#     Total Mole Fraction octane    dimensionless 0.00022322 0.00023886
#     Total Mole Fraction ethylene  dimensionless    0.20671    0.16895
#     Total Mole Fraction propene   dimensionless    0.19516    0.15786
#     Total Mole Fraction butene    dimensionless   0.078931   0.077110
#     Total Mole Fraction pentene   dimensionless   0.021607   0.028293
#     Total Mole Fraction hexene    dimensionless  0.0091360   0.017916
#     Total Mole Fraction heptene   dimensionless  0.0037102   0.016262
#     Total Mole Fraction octene    dimensionless  0.0010036  0.0091266
#     Total Mole Fraction nonene    dimensionless 0.00085354  0.0077620
#     Temperature                          kelvin     573.00     573.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.9750e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2688.1     2688.1
#     Total Mole Fraction hydrogen  dimensionless    0.10255    0.10255
#     Total Mole Fraction methane   dimensionless    0.15594    0.15594
#     Total Mole Fraction ethane    dimensionless    0.12078    0.12078
#     Total Mole Fraction propane   dimensionless   0.027748   0.027748
#     Total Mole Fraction nbutane   dimensionless   0.012047   0.012047
#     Total Mole Fraction ibutane   dimensionless   0.075748   0.075748
#     Total Mole Fraction pentane   dimensionless   0.018891   0.018891
#     Total Mole Fraction hexane    dimensionless  0.0021869  0.0021869
#     Total Mole Fraction heptane   dimensionless 0.00059384 0.00059384
#     Total Mole Fraction octane    dimensionless 0.00023886 0.00023886
#     Total Mole Fraction ethylene  dimensionless    0.16895    0.16895
#     Total Mole Fraction propene   dimensionless    0.15786    0.15786
#     Total Mole Fraction butene    dimensionless   0.077110   0.077110
#     Total Mole Fraction pentene   dimensionless   0.028293   0.028293
#     Total Mole Fraction hexene    dimensionless   0.017916   0.017916
#     Total Mole Fraction heptene   dimensionless   0.016262   0.016262
#     Total Mole Fraction octene    dimensionless  0.0091266  0.0091266
#     Total Mole Fraction nonene    dimensionless  0.0077620  0.0077620
#     Temperature                          kelvin     573.00     308.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     485.20     485.20
#     Total Mole Fraction hydrogen  dimensionless    0.77067    0.77067
#     Total Mole Fraction methane   dimensionless   0.071823   0.071823
#     Total Mole Fraction ethane    dimensionless   0.055627   0.055627
#     Total Mole Fraction propane   dimensionless 1.5373e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.6745e-10          -
#     Total Mole Fraction ibutane   dimensionless 4.1966e-09          -
#     Total Mole Fraction pentane   dimensionless 1.0466e-09          -
#     Total Mole Fraction hexane    dimensionless 1.2116e-10          -
#     Total Mole Fraction heptane   dimensionless 3.2899e-11          -
#     Total Mole Fraction octane    dimensionless 1.3233e-11          -
#     Total Mole Fraction ethylene  dimensionless    0.10188    0.10188
#     Total Mole Fraction propene   dimensionless 1.1570e-08          -
#     Total Mole Fraction butene    dimensionless 4.6793e-09          -
#     Total Mole Fraction pentene   dimensionless 1.2809e-09          -
#     Total Mole Fraction hexene    dimensionless 5.4161e-10          -
#     Total Mole Fraction heptene   dimensionless 2.1995e-10          -
#     Total Mole Fraction octene    dimensionless 5.9494e-11          -
#     Total Mole Fraction nonene    dimensionless 5.0600e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.5848e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     3.5496
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     2.6061
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     3.4544
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     16.120
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     13.849
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     3.0979
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2285
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.58151
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     3.4204
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     12.890
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     18.850
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     15.873
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     23.258
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     33.724
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     21.823
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     18.560
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.65     275.65
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     324.66     321.11
#     Molar Flowrate ('Vap', 'propane')   mole / second     74.589     71.983
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     32.385     28.930
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     203.62     187.50
#     Molar Flowrate ('Vap', 'pentane')   mole / second     50.781     36.932
#     Molar Flowrate ('Vap', 'hexane')    mole / second     5.8785     2.7806
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.5963    0.36774
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.64207   0.060562
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     454.16     450.74
#     Molar Flowrate ('Vap', 'propene')   mole / second     424.35     411.46
#     Molar Flowrate ('Vap', 'butene')    mole / second     207.28     188.43
#     Molar Flowrate ('Vap', 'pentene')   mole / second     76.055     60.182
#     Molar Flowrate ('Vap', 'hexene')    mole / second     48.160     24.901
#     Molar Flowrate ('Vap', 'heptene')   mole / second     43.714     9.9900
#     Molar Flowrate ('Vap', 'octene')    mole / second     24.533     2.7099
#     Molar Flowrate ('Vap', 'nonene')    mole / second     20.865     2.3047
#     Temperature                                kelvin     308.00     306.33
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -57142. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     3.5496            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.6061            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     3.4544            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     16.120            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     13.849            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     3.0979            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2285            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.58151            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     3.4204            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     12.890            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     18.850            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     15.873            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     23.258            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     33.724            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     21.823            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     18.560            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     275.65            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     321.11            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     71.983            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     28.930            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     187.50            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     36.932            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     2.7806            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.36774            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.060562            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     450.74            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     411.46            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     188.43            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     60.182            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     24.901            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     9.9900            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     2.7099            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second     2.3047            -             -
#     Temperature                                     kelvin     306.33            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        3.0324
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.2700
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        3.0849
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        14.283
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.774
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9600
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2060
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57797
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.9058
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        11.202
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        16.765
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        14.485
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        22.098
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        33.110
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        21.662
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        18.423
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       275.65    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       321.63    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       72.319    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       29.300    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       189.34    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       38.007    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       2.9185    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.39034    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.064103    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       451.25    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       413.15    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       190.51    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       61.570    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       26.062    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       10.604    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       2.8719    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -       2.4425    1.0000e-08
#     temperature                                     kelvin          -       304.43        304.43
#     pressure                                        pascal          -   4.4286e+05    4.4286e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units : Fixed : Bounds
#     Heat Duty : -38627. :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     3.0324     1.6125
#     Molar Flowrate ('Liq', 'propane')   mole / second     2.2700     1.8159
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     3.0849     2.8821
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     14.283     12.987
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.774     12.513
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9600     2.9407
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2060     1.2035
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57797    0.57759
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.9058     1.2570
#     Molar Flowrate ('Liq', 'propene')   mole / second     11.202     8.6757
#     Molar Flowrate ('Liq', 'butene')    mole / second     16.765     15.453
#     Molar Flowrate ('Liq', 'pentene')   mole / second     14.485     14.060
#     Molar Flowrate ('Liq', 'hexene')    mole / second     22.098     21.925
#     Molar Flowrate ('Liq', 'heptene')   mole / second     33.110     33.043
#     Molar Flowrate ('Liq', 'octene')    mole / second     21.662     21.644
#     Molar Flowrate ('Liq', 'nonene')    mole / second     18.423     18.408
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     1.4199
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.45408
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.20274
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     1.2962
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.26069
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.019243
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0024479
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00038179
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.6489
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     2.5267
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08     1.3117
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.42564
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.17325
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.066436
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.017262
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.014681
#     Temperature                                kelvin     304.43     298.00
#     Pressure                                   pascal 4.4286e+05 1.9585e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -81043. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     1.6125            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     1.8159            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     2.8821            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     12.987            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.513            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9407            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2035            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57759            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     1.2570            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     8.6757            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     15.453            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     14.060            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     21.925            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     33.043            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     21.644            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     18.408            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     1.4199            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.45408            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.20274            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     1.2962            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.26069            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.019243            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0024479            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00038179            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.6489            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     2.5267            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     1.3117            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.42564            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.17325            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.066436            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.017262            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.014681            -             -
#     Temperature                                     kelvin     298.00            -             -
#     Pressure                                        pascal 1.9585e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08       0.73664
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        1.2375
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        2.5270
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        10.829
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.032
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9068
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.1995
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57702
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.50727
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        5.6656
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        13.215
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        13.277
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        21.616
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        32.935
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        21.618
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        18.386
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       2.2957    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       1.0325    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.55787    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       3.4546    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.74170    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.053212    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0064474    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -   0.00095389    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       2.3986    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       5.5367    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       3.5500    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       1.2083    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.48251    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -      0.17507    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.043503    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.036999    1.0000e-08
#     temperature                                     kelvin          -       290.57        290.57
#     pressure                                        pascal          -   1.1480e+05    1.1480e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2688.1          -
#     Total Mole Fraction hydrogen        dimensionless    0.10255          -
#     Total Mole Fraction methane         dimensionless    0.15594          -
#     Total Mole Fraction ethane          dimensionless    0.12078          -
#     Total Mole Fraction propane         dimensionless   0.027748          -
#     Total Mole Fraction nbutane         dimensionless   0.012047          -
#     Total Mole Fraction ibutane         dimensionless   0.075748          -
#     Total Mole Fraction pentane         dimensionless   0.018891          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     275.65
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     324.66
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     74.589
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     32.385
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     203.62
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     50.781
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     5.8785
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.5963
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.64207
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     454.16
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     424.35
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     207.28
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     76.055
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     48.160
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     43.714
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     24.533
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     20.865
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.65          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     321.63          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     72.319          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     29.300          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     189.34          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     38.007          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     2.9185          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.39034          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.064103          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     451.25          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     413.15          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     190.51          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     61.570          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     26.062          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     10.604          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     2.8719          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second     2.4425          -
#     Temperature                                kelvin     304.43     304.43
#     Pressure                                   pascal 4.4286e+05 4.4286e+05
#     Total Molar Flowrate                mole / second          -     2507.3
#     Total Mole Fraction hydrogen        dimensionless          -    0.10994
#     Total Mole Fraction methane         dimensionless          -    0.16719
#     Total Mole Fraction ethane          dimensionless          -    0.12828
#     Total Mole Fraction propane         dimensionless          -   0.028844
#     Total Mole Fraction nbutane         dimensionless          -   0.011686
#     Total Mole Fraction ibutane         dimensionless          -   0.075515
#     Total Mole Fraction pentane         dimensionless          -   0.015159
#     Total Mole Fraction hexane          dimensionless          -  0.0011640
#     Total Mole Fraction heptane         dimensionless          - 0.00015568
#     Total Mole Fraction octane          dimensionless          - 2.5567e-05
#     Total Mole Fraction ethylene        dimensionless          -    0.17998
#     Total Mole Fraction propene         dimensionless          -    0.16478
#     Total Mole Fraction butene          dimensionless          -   0.075985
#     Total Mole Fraction pentene         dimensionless          -   0.024557
#     Total Mole Fraction hexene          dimensionless          -   0.010394
#     Total Mole Fraction heptene         dimensionless          -  0.0042295
#     Total Mole Fraction octene          dimensionless          -  0.0011454
#     Total Mole Fraction nonene          dimensionless          - 0.00097415
# ====================================================================================
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     88957. :          watt : False : (None, None)
#           Pressure Change : 3.2806e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     3.8576 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     21.575     21.575
#     Total Mole Fraction ethane    dimensionless    0.10641    0.10641
#     Total Mole Fraction propane   dimensionless   0.047857   0.047857
#     Total Mole Fraction nbutane   dimensionless   0.025858   0.025858
#     Total Mole Fraction ibutane   dimensionless    0.16012    0.16012
#     Total Mole Fraction pentane   dimensionless   0.034378   0.034378
#     Total Mole Fraction hexane    dimensionless  0.0024664  0.0024664
#     Total Mole Fraction heptane   dimensionless 0.00029884 0.00029884
#     Total Mole Fraction octane    dimensionless 4.4213e-05 4.4213e-05
#     Total Mole Fraction ethylene  dimensionless    0.11118    0.11118
#     Total Mole Fraction propene   dimensionless    0.25663    0.25663
#     Total Mole Fraction butene    dimensionless    0.16454    0.16454
#     Total Mole Fraction pentene   dimensionless   0.056005   0.056005
#     Total Mole Fraction hexene    dimensionless   0.022365   0.022365
#     Total Mole Fraction heptene   dimensionless  0.0081146  0.0081146
#     Total Mole Fraction octene    dimensionless  0.0020164  0.0020164
#     Total Mole Fraction nonene    dimensionless  0.0017149  0.0017149
#     Temperature                          kelvin     290.57     341.25
#     Pressure                             pascal 1.1480e+05 4.4286e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          2507.3              21.575         2528.8
#     Total Mole Fraction hydrogen  dimensionless         0.10994          1.0000e-08        0.10900
#     Total Mole Fraction methane   dimensionless         0.16719          1.0000e-08        0.16576
#     Total Mole Fraction ethane    dimensionless         0.12828             0.10641        0.12809
#     Total Mole Fraction propane   dimensionless        0.028844            0.047857       0.029006
#     Total Mole Fraction nbutane   dimensionless        0.011686            0.025858       0.011807
#     Total Mole Fraction ibutane   dimensionless        0.075515             0.16012       0.076237
#     Total Mole Fraction pentane   dimensionless        0.015159            0.034378       0.015323
#     Total Mole Fraction hexane    dimensionless       0.0011640           0.0024664      0.0011751
#     Total Mole Fraction heptane   dimensionless      0.00015568          0.00029884     0.00015691
#     Total Mole Fraction octane    dimensionless      2.5567e-05          4.4213e-05     2.5726e-05
#     Total Mole Fraction ethylene  dimensionless         0.17998             0.11118        0.17939
#     Total Mole Fraction propene   dimensionless         0.16478             0.25663        0.16556
#     Total Mole Fraction butene    dimensionless        0.075985             0.16454       0.076740
#     Total Mole Fraction pentene   dimensionless        0.024557            0.056005       0.024825
#     Total Mole Fraction hexene    dimensionless        0.010394            0.022365       0.010497
#     Total Mole Fraction heptene   dimensionless       0.0042295           0.0081146      0.0042626
#     Total Mole Fraction octene    dimensionless       0.0011454           0.0020164      0.0011528
#     Total Mole Fraction nonene    dimensionless      0.00097415           0.0017149     0.00098047
#     Temperature                          kelvin          304.43              341.25         304.86
#     Pressure                             pascal      4.4286e+05          4.4286e+05     4.4286e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     2528.8     25.288     2503.6
#     Total Mole Fraction hydrogen  dimensionless    0.10900    0.10900    0.10900
#     Total Mole Fraction methane   dimensionless    0.16576    0.16576    0.16576
#     Total Mole Fraction ethane    dimensionless    0.12809    0.12809    0.12809
#     Total Mole Fraction propane   dimensionless   0.029006   0.029006   0.029006
#     Total Mole Fraction nbutane   dimensionless   0.011807   0.011807   0.011807
#     Total Mole Fraction ibutane   dimensionless   0.076237   0.076237   0.076237
#     Total Mole Fraction pentane   dimensionless   0.015323   0.015323   0.015323
#     Total Mole Fraction hexane    dimensionless  0.0011751  0.0011751  0.0011751
#     Total Mole Fraction heptane   dimensionless 0.00015691 0.00015691 0.00015691
#     Total Mole Fraction octane    dimensionless 2.5726e-05 2.5726e-05 2.5726e-05
#     Total Mole Fraction ethylene  dimensionless    0.17939    0.17939    0.17939
#     Total Mole Fraction propene   dimensionless    0.16556    0.16556    0.16556
#     Total Mole Fraction butene    dimensionless   0.076740   0.076740   0.076740
#     Total Mole Fraction pentene   dimensionless   0.024825   0.024825   0.024825
#     Total Mole Fraction hexene    dimensionless   0.010497   0.010497   0.010497
#     Total Mole Fraction heptene   dimensionless  0.0042626  0.0042626  0.0042626
#     Total Mole Fraction octene    dimensionless  0.0011528  0.0011528  0.0011528
#     Total Mole Fraction nonene    dimensionless 0.00098047 0.00098047 0.00098047
#     Temperature                          kelvin     304.86     304.86     304.86
#     Pressure                             pascal 4.4286e+05 4.4286e+05 4.4286e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 3.5281e+06 :          watt : False : (None, None)
#           Pressure Change : 2.5714e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.5806 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2503.6     2503.6
#     Total Mole Fraction hydrogen  dimensionless    0.10900    0.10900
#     Total Mole Fraction methane   dimensionless    0.16576    0.16576
#     Total Mole Fraction ethane    dimensionless    0.12809    0.12809
#     Total Mole Fraction propane   dimensionless   0.029006   0.029006
#     Total Mole Fraction nbutane   dimensionless   0.011807   0.011807
#     Total Mole Fraction ibutane   dimensionless   0.076237   0.076237
#     Total Mole Fraction pentane   dimensionless   0.015323   0.015323
#     Total Mole Fraction hexane    dimensionless  0.0011751  0.0011751
#     Total Mole Fraction heptane   dimensionless 0.00015691 0.00015691
#     Total Mole Fraction octane    dimensionless 2.5726e-05 2.5726e-05
#     Total Mole Fraction ethylene  dimensionless    0.17939    0.17939
#     Total Mole Fraction propene   dimensionless    0.16556    0.16556
#     Total Mole Fraction butene    dimensionless   0.076740   0.076740
#     Total Mole Fraction pentene   dimensionless   0.024825   0.024825
#     Total Mole Fraction hexene    dimensionless   0.010497   0.010497
#     Total Mole Fraction heptene   dimensionless  0.0042626  0.0042626
#     Total Mole Fraction octene    dimensionless  0.0011528  0.0011528
#     Total Mole Fraction nonene    dimensionless 0.00098047 0.00098047
#     Temperature                          kelvin     304.86     327.91
#     Pressure                             pascal 4.4286e+05 7.0000e+05
# ====================================================================================
