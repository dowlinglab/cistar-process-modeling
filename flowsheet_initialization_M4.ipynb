# %% [markdown]
# # Flowsheet initialization
# ## ROK model = M4

# %%
# simulation case specifications
model_code = 4
case_name = 'Bakken'

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                define_models, \
                                define_arcs, \
                                set_unit_model_variables, \
                                initialize_flowsheet, \
                                set_scaling_factors,\
                                update_model_after_initialization,\
                                vapor_only_to_vapor_liquid_reformulate,\
                                H106_inlet_vapor_reformulate

# %% [markdown]
# ## Define flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188,
#                      'ibutane':0.5188,
                    }

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Sequence for initialization

# %%
from pyomo.network import SequentialDecomposition
seq = SequentialDecomposition()
seq.options.select_tear_method = "heuristic"
seq.options.tear_method = "Wegstein"
seq.options.iterLim = 5

# Using the SD tool
G = seq.create_graph(m)
heuristic_tear_set = seq.tear_set_arcs(G, method="heuristic")
order = seq.calculation_order(G)

for o in heuristic_tear_set:
    print(o.name)
print("Order of initialization")
for o in order:
    print(o[0].name)    
    
def function(unit):
    unit.initialize(outlvl=idaeslog.INFO_HIGH)
# Out:
# fs.s01
# Order of initialization
# fs.H101
# fs.R101
# fs.H102
# fs.S101
# fs.H103
# fs.R102
# fs.H104
# fs.T102
# fs.H105
# fs.F101
# fs.H106
# fs.F102
# fs.T104
# fs.C101
# fs.T105
# fs.M102
# fs.S102
# fs.C102
# fs.M101

# %% [markdown]
# ## Initialize Flowsheet

# %%
inlet_flow_guess = inlet_flow_rate
tear_guesses = {"flow_mol": inlet_flow_guess,
        "temperature": 308.0,
        "pressure": 700000.0,
        "mole_frac_comp": inlet_composition_dict,
        }

# %%
initialize_flowsheet(m,tear_guesses = tear_guesses)

# %%
# Fix H105 DoFs: outlet T
m.fs.H105.outlet.temperature.fix()

# Fix F101 DoF: pressure drop
m.fs.F101.deltaP.fix()

# Fix H106 DoFs: outlet T and P
m.fs.H106.outlet.pressure.fix()
# m.fs.H106.outlet.temperature.fix()

# Fix F102 DoF: pressure drop
m.fs.F102.deltaP.fix()

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))
# Out:
# The final DOF of initialized flowsheet is 4

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code))
# Out:
# {'etime_load_file': 0.10660743713378906,
#  'etime_read_dict': 0.27869129180908203,
#  'etime_read_suffixes': 0.015567541122436523}

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %% [markdown]
# # Flowsheet convergence

# %% [markdown]
# ## Unfix purge fraction for optimization

# %%
m.fs.C102.inlet.flow_mol.unfix()
m.fs.M101.recycle.flow_mol.unfix()

for k,v in inlet_composition_dict.items():
    m.fs.C102.inlet.mole_frac_comp[0, k].unfix()
    m.fs.M101.recycle.mole_frac_comp[0, k].unfix()
m.fs.S102.split_fraction[0, "purge"].unfix()
def recycle_converge(blk):
    return blk.M101.recycle.flow_mol[0] - blk.S102.inlet.flow_mol[0]*0.99 == 0.0

m.fs.recycle_converge_constraint = Constraint(rule=recycle_converge)
## Special case: added DOF for flowsheet convergence
m.fs.H106.outlet.pressure.unfix()

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':100
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32708
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16962
#
# Total number of variables............................:     5474
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3142
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5473
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.73e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.46e+04 4.53e+08  -1.0 3.14e+08    -  3.37e-06 7.21e-02f  1
#    2  0.0000000e+00 3.46e+04 4.53e+08  -1.0 2.66e+08    -  8.28e-02 2.48e-03h  1
#    3  0.0000000e+00 3.06e+04 7.81e+08  -1.0 2.73e+08    -  1.20e-01 1.14e-01h  1
#    4  0.0000000e+00 1.11e+04 1.63e+09  -1.0 1.89e+08    -  2.32e-01 6.37e-01h  1
#    5  0.0000000e+00 1.48e+01 1.04e+09  -1.0 6.97e+07    -  5.86e-01 1.00e+00h  1
#    6  0.0000000e+00 4.67e+00 8.47e+07  -1.0 1.66e+07    -  8.25e-01 1.00e+00h  1
#    7  0.0000000e+00 4.73e-03 3.91e+05  -1.0 3.33e+05    -  9.88e-01 1.00e+00f  1
#    8  0.0000000e+00 3.21e-06 1.63e+02  -1.0 3.27e+03    -  9.69e-01 1.00e+00f  1
#    9  0.0000000e+00 3.34e-02 1.77e+04  -1.0 3.39e+05    -  4.09e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 4.32e-01 4.41e+05  -1.0 1.24e+06    -  9.33e-01 1.00e+00f  1
#   11  0.0000000e+00 2.13e-04 7.98e+04  -1.7 2.13e+04    -  9.90e-01 1.00e+00h  1
#   12  0.0000000e+00 3.36e-03 1.41e+03  -1.7 1.19e+05    -  9.93e-01 1.00e+00h  1
#   13  0.0000000e+00 2.93e-08 5.24e+01  -3.8 1.37e+02    -  1.00e+00 1.00e+00h  1
#   14  0.0000000e+00 4.06e-05 1.05e-01  -3.8 1.30e+04    -  1.00e+00 1.00e+00h  1
#   15  0.0000000e+00 3.87e-11 4.12e-03  -5.7 1.71e+00    -  1.00e+00 1.00e+00h  1
#   16  0.0000000e+00 1.02e-09 4.77e-08  -5.7 6.50e+01    -  1.00e+00 1.00e+00h  1
#   17  0.0000000e+00 2.23e-11 1.20e-06  -7.0 4.86e-02    -  1.00e+00 1.00e+00h  1
#   18  0.0000000e+00 3.50e-11 7.74e-11  -7.0 7.74e-07  -4.0 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 18
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   7.7385959286455661e-11    7.7385959286455661e-11
# Constraint violation....:   4.5474735088646412e-13    3.5015546018257737e-11
# Complementarity.........:   9.0909090909091140e-08    9.0909090909091140e-08
# Overall NLP error.......:   9.0909090909091140e-08    9.0909090909091140e-08
#
#
# Number of objective function evaluations             = 19
# Number of objective gradient evaluations             = 19
# Number of equality constraint evaluations            = 19
# Number of inequality constraint evaluations          = 19
# Number of equality constraint Jacobian evaluations   = 19
# Number of inequality constraint Jacobian evaluations = 19
# Number of Lagrangian Hessian evaluations             = 18
# Total CPU secs in IPOPT (w/o function evaluations)   =     39.719
# Total CPU secs in NLP function evaluations           =    644.725
#
# EXIT: Optimal Solution Found.

# %%
# for i in large_residuals_set(m):
#     print(i,'\t',i())

# %% [markdown]
# ## Fix purge fraction to 0.01 and re-solve

# %%
m.fs.H106.outlet.pressure.fix()
m.fs.S102.split_fraction[0, "purge"].unfix()
m.fs.S102.split_fraction[0, "purge"].fix(0.01)
m.fs.del_component(m.fs.recycle_converge_constraint)

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':500
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32652
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16854
#
# Total number of variables............................:     5472
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5472
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.50e-11 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   4.5474735088646412e-13    3.5015546018257737e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   4.5474735088646412e-13    3.5015546018257737e-11
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =     38.390
# Total CPU secs in NLP function evaluations           =      1.997
#
# EXIT: Optimal Solution Found.

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     2179.7     2661.1
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.12486    0.10227
#     Total Mole Fraction methane   dimensionless   0.081100    0.19039    0.17062
#     Total Mole Fraction ethane    dimensionless    0.46920    0.14661    0.20497
#     Total Mole Fraction propane   dimensionless    0.30920   0.033061   0.083014
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.013338   0.025108
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.077294   0.068105
#     Total Mole Fraction pentane   dimensionless   0.025800   0.016797   0.018425
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0013185  0.0021834
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00017823 0.00059824
#     Total Mole Fraction octane    dimensionless  0.0012000 2.9480e-05 0.00024122
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06    0.17091    0.13999
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.13829    0.11327
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.043282   0.035453
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.025930   0.021239
#     Total Mole Fraction hexene    dimensionless 1.0000e-06   0.010933  0.0089558
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0034934  0.0028616
#     Total Mole Fraction octene    dimensionless 1.0000e-06  0.0017819  0.0014597
#     Total Mole Fraction nonene    dimensionless 1.0000e-06  0.0015003  0.0012291
#     Temperature                          kelvin     308.00     330.65     326.14
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.1676e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2661.1     2661.1
#     Total Mole Fraction hydrogen  dimensionless    0.10227    0.10227
#     Total Mole Fraction methane   dimensionless    0.17062    0.17062
#     Total Mole Fraction ethane    dimensionless    0.20497    0.20497
#     Total Mole Fraction propane   dimensionless   0.083014   0.083014
#     Total Mole Fraction nbutane   dimensionless   0.025108   0.025108
#     Total Mole Fraction ibutane   dimensionless   0.068105   0.068105
#     Total Mole Fraction pentane   dimensionless   0.018425   0.018425
#     Total Mole Fraction hexane    dimensionless  0.0021834  0.0021834
#     Total Mole Fraction heptane   dimensionless 0.00059824 0.00059824
#     Total Mole Fraction octane    dimensionless 0.00024122 0.00024122
#     Total Mole Fraction ethylene  dimensionless    0.13999    0.13999
#     Total Mole Fraction propene   dimensionless    0.11327    0.11327
#     Total Mole Fraction butene    dimensionless   0.035453   0.035453
#     Total Mole Fraction pentene   dimensionless   0.021239   0.021239
#     Total Mole Fraction hexene    dimensionless  0.0089558  0.0089558
#     Total Mole Fraction heptene   dimensionless  0.0028616  0.0028616
#     Total Mole Fraction octene    dimensionless  0.0014597  0.0014597
#     Total Mole Fraction nonene    dimensionless  0.0012291  0.0012291
#     Temperature                          kelvin     326.14     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.2167e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     194.50 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     146.51 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     34.663 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2661.1     3036.8
#     Total Mole Fraction hydrogen  dimensionless    0.10227    0.21333
#     Total Mole Fraction methane   dimensionless    0.17062    0.14951
#     Total Mole Fraction ethane    dimensionless    0.20497    0.11556
#     Total Mole Fraction propane   dimensionless   0.083014   0.024500
#     Total Mole Fraction nbutane   dimensionless   0.025108   0.010587
#     Total Mole Fraction ibutane   dimensionless   0.068105   0.059680
#     Total Mole Fraction pentane   dimensionless   0.018425   0.016146
#     Total Mole Fraction hexane    dimensionless  0.0021834  0.0019133
#     Total Mole Fraction heptane   dimensionless 0.00059824 0.00052423
#     Total Mole Fraction octane    dimensionless 0.00024122 0.00021138
#     Total Mole Fraction ethylene  dimensionless    0.13999    0.18672
#     Total Mole Fraction propene   dimensionless    0.11327    0.14751
#     Total Mole Fraction butene    dimensionless   0.035453   0.042481
#     Total Mole Fraction pentene   dimensionless   0.021239   0.018612
#     Total Mole Fraction hexene    dimensionless  0.0089558  0.0078479
#     Total Mole Fraction heptene   dimensionless  0.0028616  0.0025076
#     Total Mole Fraction octene    dimensionless  0.0014597  0.0012792
#     Total Mole Fraction nonene    dimensionless  0.0012291  0.0010770
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.8387e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     3036.8     3036.8
#     Total Mole Fraction hydrogen  dimensionless    0.21333    0.21333
#     Total Mole Fraction methane   dimensionless    0.14951    0.14951
#     Total Mole Fraction ethane    dimensionless    0.11556    0.11556
#     Total Mole Fraction propane   dimensionless   0.024500   0.024500
#     Total Mole Fraction nbutane   dimensionless   0.010587   0.010587
#     Total Mole Fraction ibutane   dimensionless   0.059680   0.059680
#     Total Mole Fraction pentane   dimensionless   0.016146   0.016146
#     Total Mole Fraction hexane    dimensionless  0.0019133  0.0019133
#     Total Mole Fraction heptane   dimensionless 0.00052423 0.00052423
#     Total Mole Fraction octane    dimensionless 0.00021138 0.00021138
#     Total Mole Fraction ethylene  dimensionless    0.18672    0.18672
#     Total Mole Fraction propene   dimensionless    0.14751    0.14751
#     Total Mole Fraction butene    dimensionless   0.042481   0.042481
#     Total Mole Fraction pentene   dimensionless   0.018612   0.018612
#     Total Mole Fraction hexene    dimensionless  0.0078479  0.0078479
#     Total Mole Fraction heptene   dimensionless  0.0025076  0.0025076
#     Total Mole Fraction octene    dimensionless  0.0012792  0.0012792
#     Total Mole Fraction nonene    dimensionless  0.0010770  0.0010770
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     3036.8     478.23     2558.6
#     Total Mole Fraction hydrogen  dimensionless    0.21333    0.77980    0.10745
#     Total Mole Fraction methane   dimensionless    0.14951   0.072870    0.16384
#     Total Mole Fraction ethane    dimensionless    0.11556   0.056323    0.12663
#     Total Mole Fraction propane   dimensionless   0.024500 1.5558e-09   0.029080
#     Total Mole Fraction nbutane   dimensionless   0.010587 6.7229e-10   0.012566
#     Total Mole Fraction ibutane   dimensionless   0.059680 3.7897e-09   0.070835
#     Total Mole Fraction pentane   dimensionless   0.016146 1.0253e-09   0.019164
#     Total Mole Fraction hexane    dimensionless  0.0019133 1.2150e-10  0.0022709
#     Total Mole Fraction heptane   dimensionless 0.00052423 3.3289e-11 0.00062222
#     Total Mole Fraction octane    dimensionless 0.00021138 1.3423e-11 0.00025089
#     Total Mole Fraction ethylene  dimensionless    0.18672   0.091007    0.20462
#     Total Mole Fraction propene   dimensionless    0.14751 9.3667e-09    0.17508
#     Total Mole Fraction butene    dimensionless   0.042481 2.6976e-09   0.050422
#     Total Mole Fraction pentene   dimensionless   0.018612 1.1818e-09   0.022090
#     Total Mole Fraction hexene    dimensionless  0.0078479 4.9834e-10  0.0093148
#     Total Mole Fraction heptene   dimensionless  0.0025076 1.5924e-10  0.0029763
#     Total Mole Fraction octene    dimensionless  0.0012792 8.1227e-11  0.0015183
#     Total Mole Fraction nonene    dimensionless  0.0010770 6.8393e-11  0.0012784
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.3214e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     478.23     478.23
#     Total Mole Fraction hydrogen  dimensionless    0.77980    0.77980
#     Total Mole Fraction methane   dimensionless   0.072870   0.072870
#     Total Mole Fraction ethane    dimensionless   0.056323   0.056323
#     Total Mole Fraction ethylene  dimensionless   0.091007   0.091007
#     Temperature                          kelvin     473.00     329.91
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.2125e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2558.6     2558.6
#     Total Mole Fraction hydrogen  dimensionless    0.10745    0.10745
#     Total Mole Fraction methane   dimensionless    0.16384    0.16384
#     Total Mole Fraction ethane    dimensionless    0.12663    0.12663
#     Total Mole Fraction propane   dimensionless   0.029080   0.029080
#     Total Mole Fraction nbutane   dimensionless   0.012566   0.012566
#     Total Mole Fraction ibutane   dimensionless   0.070835   0.070835
#     Total Mole Fraction pentane   dimensionless   0.019164   0.019164
#     Total Mole Fraction hexane    dimensionless  0.0022709  0.0022709
#     Total Mole Fraction heptane   dimensionless 0.00062222 0.00062222
#     Total Mole Fraction octane    dimensionless 0.00025089 0.00025089
#     Total Mole Fraction ethylene  dimensionless    0.20462    0.20462
#     Total Mole Fraction propene   dimensionless    0.17508    0.17508
#     Total Mole Fraction butene    dimensionless   0.050422   0.050422
#     Total Mole Fraction pentene   dimensionless   0.022090   0.022090
#     Total Mole Fraction hexene    dimensionless  0.0093148  0.0093148
#     Total Mole Fraction heptene   dimensionless  0.0029763  0.0029763
#     Total Mole Fraction octene    dimensionless  0.0015183  0.0015183
#     Total Mole Fraction nonene    dimensionless  0.0012784  0.0012784
#     Temperature                          kelvin     473.00     573.00
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2558.6     2359.4
#     Total Mole Fraction hydrogen  dimensionless    0.10745    0.11652
#     Total Mole Fraction methane   dimensionless    0.16384    0.17767
#     Total Mole Fraction ethane    dimensionless    0.12663    0.13733
#     Total Mole Fraction propane   dimensionless   0.029080   0.031535
#     Total Mole Fraction nbutane   dimensionless   0.012566   0.013627
#     Total Mole Fraction ibutane   dimensionless   0.070835   0.076816
#     Total Mole Fraction pentane   dimensionless   0.019164   0.020782
#     Total Mole Fraction hexane    dimensionless  0.0022709  0.0024627
#     Total Mole Fraction heptane   dimensionless 0.00062222 0.00067475
#     Total Mole Fraction octane    dimensionless 0.00025089 0.00027208
#     Total Mole Fraction ethylene  dimensionless    0.20462    0.15980
#     Total Mole Fraction propene   dimensionless    0.17508    0.13140
#     Total Mole Fraction butene    dimensionless   0.050422   0.043524
#     Total Mole Fraction pentene   dimensionless   0.022090   0.029653
#     Total Mole Fraction hexene    dimensionless  0.0093148   0.018741
#     Total Mole Fraction heptene   dimensionless  0.0029763   0.013311
#     Total Mole Fraction octene    dimensionless  0.0015183   0.014052
#     Total Mole Fraction nonene    dimensionless  0.0012784   0.011831
#     Temperature                          kelvin     573.00     573.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.1725e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2359.4     2359.4
#     Total Mole Fraction hydrogen  dimensionless    0.11652    0.11652
#     Total Mole Fraction methane   dimensionless    0.17767    0.17767
#     Total Mole Fraction ethane    dimensionless    0.13733    0.13733
#     Total Mole Fraction propane   dimensionless   0.031535   0.031535
#     Total Mole Fraction nbutane   dimensionless   0.013627   0.013627
#     Total Mole Fraction ibutane   dimensionless   0.076816   0.076816
#     Total Mole Fraction pentane   dimensionless   0.020782   0.020782
#     Total Mole Fraction hexane    dimensionless  0.0024627  0.0024627
#     Total Mole Fraction heptane   dimensionless 0.00067475 0.00067475
#     Total Mole Fraction octane    dimensionless 0.00027208 0.00027208
#     Total Mole Fraction ethylene  dimensionless    0.15980    0.15980
#     Total Mole Fraction propene   dimensionless    0.13140    0.13140
#     Total Mole Fraction butene    dimensionless   0.043524   0.043524
#     Total Mole Fraction pentene   dimensionless   0.029653   0.029653
#     Total Mole Fraction hexene    dimensionless   0.018741   0.018741
#     Total Mole Fraction heptene   dimensionless   0.013311   0.013311
#     Total Mole Fraction octene    dimensionless   0.014052   0.014052
#     Total Mole Fraction nonene    dimensionless   0.011831   0.011831
#     Temperature                          kelvin     573.00     308.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     478.23     478.23
#     Total Mole Fraction hydrogen  dimensionless    0.77980    0.77980
#     Total Mole Fraction methane   dimensionless   0.072870   0.072870
#     Total Mole Fraction ethane    dimensionless   0.056323   0.056323
#     Total Mole Fraction propane   dimensionless 1.5558e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.7229e-10          -
#     Total Mole Fraction ibutane   dimensionless 3.7897e-09          -
#     Total Mole Fraction pentane   dimensionless 1.0253e-09          -
#     Total Mole Fraction hexane    dimensionless 1.2150e-10          -
#     Total Mole Fraction heptane   dimensionless 3.3289e-11          -
#     Total Mole Fraction octane    dimensionless 1.3423e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.091007   0.091007
#     Total Mole Fraction propene   dimensionless 9.3667e-09          -
#     Total Mole Fraction butene    dimensionless 2.6976e-09          -
#     Total Mole Fraction pentene   dimensionless 1.1818e-09          -
#     Total Mole Fraction hexene    dimensionless 4.9834e-10          -
#     Total Mole Fraction heptene   dimensionless 1.5924e-10          -
#     Total Mole Fraction octene    dimensionless 8.1227e-11          -
#     Total Mole Fraction nonene    dimensionless 6.8393e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.1636e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     3.6853
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     2.6877
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     3.5185
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     14.743
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     13.592
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     3.0857
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2280
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.58154
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     2.9589
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     9.7496
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     9.5971
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     14.910
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     21.553
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     24.271
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     29.508
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     24.845
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     274.91     274.91
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     324.00     320.31
#     Molar Flowrate ('Vap', 'propane')   mole / second     74.402     71.714
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     32.151     28.633
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     181.24     166.49
#     Molar Flowrate ('Vap', 'pentane')   mole / second     49.032     35.440
#     Molar Flowrate ('Vap', 'hexane')    mole / second     5.8103     2.7247
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.5920    0.36402
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.64193   0.060388
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     377.03     374.08
#     Molar Flowrate ('Vap', 'propene')   mole / second     310.03     300.28
#     Molar Flowrate ('Vap', 'butene')    mole / second     102.69     93.092
#     Molar Flowrate ('Vap', 'pentene')   mole / second     69.963     55.053
#     Molar Flowrate ('Vap', 'hexene')    mole / second     44.216     22.663
#     Molar Flowrate ('Vap', 'heptene')   mole / second     31.405     7.1345
#     Molar Flowrate ('Vap', 'octene')    mole / second     33.154     3.6454
#     Molar Flowrate ('Vap', 'nonene')    mole / second     27.914     3.0693
#     Temperature                                kelvin     308.00     307.93
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -62660. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     3.6853            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.6877            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     3.5185            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     14.743            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     13.592            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     3.0857            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2280            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.58154            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     2.9589            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     9.7496            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     9.5971            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     14.910            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     21.553            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     24.271            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     29.508            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     24.845            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     274.91            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     320.31            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     71.714            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     28.633            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     166.49            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     35.440            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     2.7247            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.36402            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.060388            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     374.08            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     300.28            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     93.092            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     55.053            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     22.663            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     7.1345            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     3.6454            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second     3.0693            -             -
#     Temperature                                     kelvin     307.93            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        3.1209
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.3222
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        3.1200
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        12.967
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.469
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9384
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2034
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57761
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.4915
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        8.4037
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        8.4738
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        13.527
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        20.404
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        23.790
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        29.267
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        24.642
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       274.91    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       320.88    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       72.080    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       29.031    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       168.27    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       36.563    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       2.8719    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.38855    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.064317    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       374.54    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       301.62    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       94.216    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       56.436    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       23.812    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       7.6157    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       3.8871    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -       3.2728    1.0000e-08
#     temperature                                     kelvin          -       305.96        305.96
#     pressure                                        pascal          -   4.3734e+05    4.3734e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.2585e+05 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     3.1209     1.7791
#     Molar Flowrate ('Liq', 'propane')   mole / second     2.3222     1.9140
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     3.1200     2.9441
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     12.967     11.952
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.469     12.253
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9384     2.9223
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2034     1.2014
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57761    0.57729
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.4915     1.1723
#     Molar Flowrate ('Liq', 'propene')   mole / second     8.4037     6.7320
#     Molar Flowrate ('Liq', 'butene')    mole / second     8.4738     7.9040
#     Molar Flowrate ('Liq', 'pentene')   mole / second     13.527     13.190
#     Molar Flowrate ('Liq', 'hexene')    mole / second     20.404     20.269
#     Molar Flowrate ('Liq', 'heptene')   mole / second     23.790     23.749
#     Molar Flowrate ('Liq', 'octene')    mole / second     29.267     29.247
#     Molar Flowrate ('Liq', 'nonene')    mole / second     24.642     24.625
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     1.3417
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.40817
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.17588
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     1.0153
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.21605
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.016134
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0020560
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00032034
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.3191
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     1.6716
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08    0.56976
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.33742
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.13512
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.040262
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.019566
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.016474
#     Temperature                                kelvin     305.96     298.00
#     Pressure                                   pascal 4.3734e+05 1.7905e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -41715. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     1.7791            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     1.9140            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     2.9441            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     11.952            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.253            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9223            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2014            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57729            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     1.1723            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     6.7320            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     7.9040            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     13.190            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     20.269            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     23.749            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     29.247            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     24.625            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     1.3417            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.40817            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.17588            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     1.0153            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.21605            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.016134            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0020560            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00032034            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.3191            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     1.6716            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second    0.56976            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.33742            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.13512            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.040262            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.019566            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.016474            -             -
#     Temperature                                     kelvin     298.00            -             -
#     Pressure                                        pascal 1.7905e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        1.2005
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        1.6107
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        2.7839
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        11.055
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.050
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9074
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.1995
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57702
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.73189
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        5.5451
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        7.3931
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        12.873
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        20.144
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        23.714
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        29.230
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        24.611
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       1.9203    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -      0.71149    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.33610    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       1.9118    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.41934    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.030977    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0038720    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -   0.00059068    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       1.7596    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       2.8586    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       1.0807    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -      0.65416    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.26015    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -     0.075836    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.036204    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.030483    1.0000e-08
#     temperature                                     kelvin          -       295.06        295.06
#     pressure                                        pascal          -   1.3734e+05    1.3734e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2359.4          -
#     Total Mole Fraction hydrogen        dimensionless    0.11652          -
#     Total Mole Fraction methane         dimensionless    0.17767          -
#     Total Mole Fraction ethane          dimensionless    0.13733          -
#     Total Mole Fraction propane         dimensionless   0.031535          -
#     Total Mole Fraction nbutane         dimensionless   0.013627          -
#     Total Mole Fraction ibutane         dimensionless   0.076816          -
#     Total Mole Fraction pentane         dimensionless   0.020782          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     274.91
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     324.00
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     74.402
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     32.151
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     181.24
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     49.032
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     5.8103
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.5920
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.64193
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     377.03
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     310.03
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     102.69
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     69.963
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     44.216
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     31.405
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     33.154
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     27.914
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     274.91          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     320.88          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     72.080          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     29.031          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     168.27          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     36.563          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     2.8719          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.38855          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.064317          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     374.54          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     301.62          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     94.216          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     56.436          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     23.812          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     7.6157          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     3.8871          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second     3.2728          -
#     Temperature                                kelvin     305.96     305.96
#     Pressure                                   pascal 4.3734e+05 4.3734e+05
#     Total Molar Flowrate                mole / second          -     2189.6
#     Total Mole Fraction hydrogen        dimensionless          -    0.12555
#     Total Mole Fraction methane         dimensionless          -    0.19144
#     Total Mole Fraction ethane          dimensionless          -    0.14654
#     Total Mole Fraction propane         dimensionless          -   0.032919
#     Total Mole Fraction nbutane         dimensionless          -   0.013258
#     Total Mole Fraction ibutane         dimensionless          -   0.076848
#     Total Mole Fraction pentane         dimensionless          -   0.016698
#     Total Mole Fraction hexane          dimensionless          -  0.0013116
#     Total Mole Fraction heptane         dimensionless          - 0.00017745
#     Total Mole Fraction octane          dimensionless          - 2.9373e-05
#     Total Mole Fraction ethylene        dimensionless          -    0.17105
#     Total Mole Fraction propene         dimensionless          -    0.13775
#     Total Mole Fraction butene          dimensionless          -   0.043028
#     Total Mole Fraction pentene         dimensionless          -   0.025774
#     Total Mole Fraction hexene          dimensionless          -   0.010875
#     Total Mole Fraction heptene         dimensionless          -  0.0034781
#     Total Mole Fraction octene          dimensionless          -  0.0017752
#     Total Mole Fraction nonene          dimensionless          -  0.0014947
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     43062. :          watt : False : (None, None)
#           Pressure Change : 3.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     3.1844 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     12.090     12.090
#     Total Mole Fraction ethane    dimensionless    0.15883    0.15883
#     Total Mole Fraction propane   dimensionless   0.058848   0.058848
#     Total Mole Fraction nbutane   dimensionless   0.027799   0.027799
#     Total Mole Fraction ibutane   dimensionless    0.15813    0.15813
#     Total Mole Fraction pentane   dimensionless   0.034684   0.034684
#     Total Mole Fraction hexane    dimensionless  0.0025622  0.0025622
#     Total Mole Fraction heptane   dimensionless 0.00032026 0.00032026
#     Total Mole Fraction octane    dimensionless 4.8856e-05 4.8856e-05
#     Total Mole Fraction ethylene  dimensionless    0.14554    0.14554
#     Total Mole Fraction propene   dimensionless    0.23644    0.23644
#     Total Mole Fraction butene    dimensionless   0.089387   0.089387
#     Total Mole Fraction pentene   dimensionless   0.054106   0.054106
#     Total Mole Fraction hexene    dimensionless   0.021517   0.021517
#     Total Mole Fraction heptene   dimensionless  0.0062725  0.0062725
#     Total Mole Fraction octene    dimensionless  0.0029945  0.0029945
#     Total Mole Fraction nonene    dimensionless  0.0025213  0.0025213
#     Temperature                          kelvin     295.06     340.28
#     Pressure                             pascal 1.3734e+05 4.3734e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          2189.6              12.090         2201.7
#     Total Mole Fraction hydrogen  dimensionless         0.12555          1.0000e-08        0.12486
#     Total Mole Fraction methane   dimensionless         0.19144          1.0000e-08        0.19039
#     Total Mole Fraction ethane    dimensionless         0.14654             0.15883        0.14661
#     Total Mole Fraction propane   dimensionless        0.032919            0.058848       0.033061
#     Total Mole Fraction nbutane   dimensionless        0.013258            0.027799       0.013338
#     Total Mole Fraction ibutane   dimensionless        0.076848             0.15813       0.077294
#     Total Mole Fraction pentane   dimensionless        0.016698            0.034684       0.016797
#     Total Mole Fraction hexane    dimensionless       0.0013116           0.0025622      0.0013185
#     Total Mole Fraction heptane   dimensionless      0.00017745          0.00032026     0.00017823
#     Total Mole Fraction octane    dimensionless      2.9373e-05          4.8856e-05     2.9480e-05
#     Total Mole Fraction ethylene  dimensionless         0.17105             0.14554        0.17091
#     Total Mole Fraction propene   dimensionless         0.13775             0.23644        0.13829
#     Total Mole Fraction butene    dimensionless        0.043028            0.089387       0.043282
#     Total Mole Fraction pentene   dimensionless        0.025774            0.054106       0.025930
#     Total Mole Fraction hexene    dimensionless        0.010875            0.021517       0.010933
#     Total Mole Fraction heptene   dimensionless       0.0034781           0.0062725      0.0034934
#     Total Mole Fraction octene    dimensionless       0.0017752           0.0029945      0.0017819
#     Total Mole Fraction nonene    dimensionless       0.0014947           0.0025213      0.0015003
#     Temperature                          kelvin          305.96              340.28         306.22
#     Pressure                             pascal      4.3734e+05          4.3734e+05     4.3734e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     2201.7     22.017     2179.7
#     Total Mole Fraction hydrogen  dimensionless    0.12486    0.12486    0.12486
#     Total Mole Fraction methane   dimensionless    0.19039    0.19039    0.19039
#     Total Mole Fraction ethane    dimensionless    0.14661    0.14661    0.14661
#     Total Mole Fraction propane   dimensionless   0.033061   0.033061   0.033061
#     Total Mole Fraction nbutane   dimensionless   0.013338   0.013338   0.013338
#     Total Mole Fraction ibutane   dimensionless   0.077294   0.077294   0.077294
#     Total Mole Fraction pentane   dimensionless   0.016797   0.016797   0.016797
#     Total Mole Fraction hexane    dimensionless  0.0013185  0.0013185  0.0013185
#     Total Mole Fraction heptane   dimensionless 0.00017823 0.00017823 0.00017823
#     Total Mole Fraction octane    dimensionless 2.9480e-05 2.9480e-05 2.9480e-05
#     Total Mole Fraction ethylene  dimensionless    0.17091    0.17091    0.17091
#     Total Mole Fraction propene   dimensionless    0.13829    0.13829    0.13829
#     Total Mole Fraction butene    dimensionless   0.043282   0.043282   0.043282
#     Total Mole Fraction pentene   dimensionless   0.025930   0.025930   0.025930
#     Total Mole Fraction hexene    dimensionless   0.010933   0.010933   0.010933
#     Total Mole Fraction heptene   dimensionless  0.0034934  0.0034934  0.0034934
#     Total Mole Fraction octene    dimensionless  0.0017819  0.0017819  0.0017819
#     Total Mole Fraction nonene    dimensionless  0.0015003  0.0015003  0.0015003
#     Temperature                          kelvin     306.22     306.22     306.22
#     Pressure                             pascal 4.3734e+05 4.3734e+05 4.3734e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 3.1753e+06 :          watt : False : (None, None)
#           Pressure Change : 2.6266e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.6006 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2179.7     2179.7
#     Total Mole Fraction hydrogen  dimensionless    0.12486    0.12486
#     Total Mole Fraction methane   dimensionless    0.19039    0.19039
#     Total Mole Fraction ethane    dimensionless    0.14661    0.14661
#     Total Mole Fraction propane   dimensionless   0.033061   0.033061
#     Total Mole Fraction nbutane   dimensionless   0.013338   0.013338
#     Total Mole Fraction ibutane   dimensionless   0.077294   0.077294
#     Total Mole Fraction pentane   dimensionless   0.016797   0.016797
#     Total Mole Fraction hexane    dimensionless  0.0013185  0.0013185
#     Total Mole Fraction heptane   dimensionless 0.00017823 0.00017823
#     Total Mole Fraction octane    dimensionless 2.9480e-05 2.9480e-05
#     Total Mole Fraction ethylene  dimensionless    0.17091    0.17091
#     Total Mole Fraction propene   dimensionless    0.13829    0.13829
#     Total Mole Fraction butene    dimensionless   0.043282   0.043282
#     Total Mole Fraction pentene   dimensionless   0.025930   0.025930
#     Total Mole Fraction hexene    dimensionless   0.010933   0.010933
#     Total Mole Fraction heptene   dimensionless  0.0034934  0.0034934
#     Total Mole Fraction octene    dimensionless  0.0017819  0.0017819
#     Total Mole Fraction nonene    dimensionless  0.0015003  0.0015003
#     Temperature                          kelvin     306.22     330.65
#     Pressure                             pascal 4.3734e+05 7.0000e+05
# ====================================================================================
