# %% [markdown]
# # Flowsheet initialization
# ## ROK model = M2

# %%
# simulation case specifications
model_code = 2
case_name = 'Bakken'

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                define_models, \
                                define_arcs, \
                                set_unit_model_variables, \
                                initialize_flowsheet, \
                                set_scaling_factors,\
                                update_model_after_initialization,\
                                vapor_only_to_vapor_liquid_reformulate,\
                                H106_inlet_vapor_reformulate

# %% [markdown]
# ## Define flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188,
#                      'ibutane':0.5188,
                    }

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Sequence for initialization

# %%
from pyomo.network import SequentialDecomposition
seq = SequentialDecomposition()
seq.options.select_tear_method = "heuristic"
seq.options.tear_method = "Wegstein"
seq.options.iterLim = 5

# Using the SD tool
G = seq.create_graph(m)
heuristic_tear_set = seq.tear_set_arcs(G, method="heuristic")
order = seq.calculation_order(G)

for o in heuristic_tear_set:
    print(o.name)
print("Order of initialization")
for o in order:
    print(o[0].name)    
    
def function(unit):
    unit.initialize(outlvl=idaeslog.INFO_HIGH)
# Out:
# fs.s01
# Order of initialization
# fs.H101
# fs.R101
# fs.H102
# fs.S101
# fs.H103
# fs.R102
# fs.H104
# fs.T102
# fs.H105
# fs.F101
# fs.H106
# fs.F102
# fs.T104
# fs.C101
# fs.T105
# fs.M102
# fs.S102
# fs.C102
# fs.M101

# %% [markdown]
# ## Initialize Flowsheet

# %%
inlet_flow_guess = inlet_flow_rate
tear_guesses = {"flow_mol": inlet_flow_guess,
        "temperature": 308.0,
        "pressure": 700000.0,
        "mole_frac_comp": inlet_composition_dict,
        }

# %%
initialize_flowsheet(m,tear_guesses = tear_guesses)

# %%
# Fix H105 DoFs: outlet T
m.fs.H105.outlet.temperature.fix()

# Fix F101 DoF: pressure drop
m.fs.F101.deltaP.fix()

# Fix H106 DoFs: outlet T and P
m.fs.H106.outlet.pressure.fix()
# m.fs.H106.outlet.temperature.fix()

# Fix F102 DoF: pressure drop
m.fs.F102.deltaP.fix()

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))
# Out:
# The final DOF of initialized flowsheet is 4

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code))
# Out:
# {'etime_load_file': 0.05980205535888672,
#  'etime_read_dict': 0.20212244987487793,
#  'etime_read_suffixes': 0.01567220687866211}

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %% [markdown]
# # Flowsheet convergence

# %% [markdown]
# ## Unfix purge fraction for optimization

# %%
m.fs.C102.inlet.flow_mol.unfix()
m.fs.M101.recycle.flow_mol.unfix()

for k,v in inlet_composition_dict.items():
    m.fs.C102.inlet.mole_frac_comp[0, k].unfix()
    m.fs.M101.recycle.mole_frac_comp[0, k].unfix()
m.fs.S102.split_fraction[0, "purge"].unfix()
def recycle_converge(blk):
    return blk.M101.recycle.flow_mol[0] - blk.S102.inlet.flow_mol[0]*0.99 == 0.0

m.fs.recycle_converge_constraint = Constraint(rule=recycle_converge)

# %%
DOF_initial = degrees_of_freedom(m)
print("The final DOF of initialized flowsheet is {0}".format(DOF_initial))

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':100
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32673
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16873
#
# Total number of variables............................:     5473
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5473
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 4.08e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.30e+04 1.86e+10  -1.0 5.99e+08    -  1.92e-06 1.92e-01h  1
#    2  0.0000000e+00 1.32e+04 9.66e+09  -1.0 6.99e+07    -  1.55e-01 6.01e-01h  1
#    3  0.0000000e+00 1.22e+01 5.06e+09  -1.0 3.92e+07    -  4.95e-01 1.00e+00h  1
#    4  0.0000000e+00 2.13e+00 4.21e+08  -1.0 7.90e+06    -  7.69e-01 1.00e+00h  1
#    5  0.0000000e+00 1.54e-02 5.99e+05  -1.0 1.88e+05    -  9.89e-01 1.00e+00h  1
#    6  0.0000000e+00 9.00e-05 2.40e+02  -1.0 7.87e+01    -  9.90e-01 1.00e+00h  1
#    7  0.0000000e+00 5.86e-09 1.06e+00  -1.0 7.99e-01    -  9.90e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 7
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   9.9999999999990016e+06    9.9999999999990016e+06
# Constraint violation....:   5.8567066418720157e-09    5.8567066418720157e-09
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.8567066418720157e-09    9.9999999999990016e+06
#
#
# Number of objective function evaluations             = 8
# Number of objective gradient evaluations             = 8
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 8
# Number of equality constraint Jacobian evaluations   = 8
# Number of inequality constraint Jacobian evaluations = 8
# Number of Lagrangian Hessian evaluations             = 7
# Total CPU secs in IPOPT (w/o function evaluations)   =     98.471
# Total CPU secs in NLP function evaluations           =    664.212
#
# EXIT: Optimal Solution Found.

# %%
# for i in large_residuals_set(m):
#     print(i,'\t',i())

# %% [markdown]
# ## Fix purge fraction to 0.01 and re-solve

# %%
m.fs.S102.split_fraction[0, "purge"].unfix()
m.fs.S102.split_fraction[0, "purge"].fix(0.01)
m.fs.del_component(m.fs.recycle_converge_constraint)

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter':500
                 }
solve_status = solver.solve(m, tee=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    32652
# Number of nonzeros in inequality constraint Jacobian.:      130
# Number of nonzeros in Lagrangian Hessian.............:    16854
#
# Total number of variables............................:     5472
#                      variables with only lower bounds:      133
#                 variables with lower and upper bounds:     3141
#                      variables with only upper bounds:       68
# Total number of equality constraints.................:     5472
# Total number of inequality constraints...............:       61
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       41
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 5.86e-09 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.8567066418720157e-09    5.8567066418720157e-09
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.8567066418720157e-09    5.8567066418720157e-09
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 1
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 1
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =    106.334
# Total CPU secs in NLP function evaluations           =      3.409
#
# EXIT: Optimal Solution Found.

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     2256.0     2737.4
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.12085   0.099599
#     Total Mole Fraction methane   dimensionless   0.081100    0.18395    0.16586
#     Total Mole Fraction ethane    dimensionless    0.46920    0.14208    0.19960
#     Total Mole Fraction propane   dimensionless    0.30920   0.032118   0.080844
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.012944   0.024454
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.078690   0.069512
#     Total Mole Fraction pentane   dimensionless   0.025800   0.015688   0.017466
#     Total Mole Fraction hexane    dimensionless  0.0061000  0.0012036  0.0020647
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00016101 0.00057234
#     Total Mole Fraction octane    dimensionless  0.0012000 2.6461e-05 0.00023283
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06    0.13922    0.11474
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.15329    0.12633
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.082388   0.067900
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.021803   0.017969
#     Total Mole Fraction hexene    dimensionless 1.0000e-06  0.0086371  0.0071184
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0043863  0.0036152
#     Total Mole Fraction octene    dimensionless 1.0000e-06  0.0012888  0.0010623
#     Total Mole Fraction nonene    dimensionless 1.0000e-06  0.0012734  0.0010496
#     Temperature                          kelvin     308.00     328.91     324.94
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.2767e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2737.4     2737.4
#     Total Mole Fraction hydrogen  dimensionless   0.099599   0.099599
#     Total Mole Fraction methane   dimensionless    0.16586    0.16586
#     Total Mole Fraction ethane    dimensionless    0.19960    0.19960
#     Total Mole Fraction propane   dimensionless   0.080844   0.080844
#     Total Mole Fraction nbutane   dimensionless   0.024454   0.024454
#     Total Mole Fraction ibutane   dimensionless   0.069512   0.069512
#     Total Mole Fraction pentane   dimensionless   0.017466   0.017466
#     Total Mole Fraction hexane    dimensionless  0.0020647  0.0020647
#     Total Mole Fraction heptane   dimensionless 0.00057234 0.00057234
#     Total Mole Fraction octane    dimensionless 0.00023283 0.00023283
#     Total Mole Fraction ethylene  dimensionless    0.11474    0.11474
#     Total Mole Fraction propene   dimensionless    0.12633    0.12633
#     Total Mole Fraction butene    dimensionless   0.067900   0.067900
#     Total Mole Fraction pentene   dimensionless   0.017969   0.017969
#     Total Mole Fraction hexene    dimensionless  0.0071184  0.0071184
#     Total Mole Fraction heptene   dimensionless  0.0036152  0.0036152
#     Total Mole Fraction octene    dimensionless  0.0010623  0.0010623
#     Total Mole Fraction nonene    dimensionless  0.0010496  0.0010496
#     Temperature                          kelvin     324.94     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.2331e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     194.85 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     146.77 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     34.730 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2737.4     3113.8
#     Total Mole Fraction hydrogen  dimensionless   0.099599    0.20843
#     Total Mole Fraction methane   dimensionless    0.16586    0.14582
#     Total Mole Fraction ethane    dimensionless    0.19960    0.11290
#     Total Mole Fraction propane   dimensionless   0.080844   0.023937
#     Total Mole Fraction nbutane   dimensionless   0.024454   0.010345
#     Total Mole Fraction ibutane   dimensionless   0.069512   0.061111
#     Total Mole Fraction pentane   dimensionless   0.017466   0.015355
#     Total Mole Fraction hexane    dimensionless  0.0020647  0.0018151
#     Total Mole Fraction heptane   dimensionless 0.00057234 0.00050316
#     Total Mole Fraction octane    dimensionless 0.00023283 0.00020469
#     Total Mole Fraction ethylene  dimensionless    0.11474    0.16345
#     Total Mole Fraction propene   dimensionless    0.12633    0.15820
#     Total Mole Fraction butene    dimensionless   0.067900   0.070847
#     Total Mole Fraction pentene   dimensionless   0.017969   0.015797
#     Total Mole Fraction hexene    dimensionless  0.0071184  0.0062580
#     Total Mole Fraction heptene   dimensionless  0.0036152  0.0031782
#     Total Mole Fraction octene    dimensionless  0.0010623 0.00093393
#     Total Mole Fraction nonene    dimensionless  0.0010496 0.00092275
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.9312e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     3113.8     3113.8
#     Total Mole Fraction hydrogen  dimensionless    0.20843    0.20843
#     Total Mole Fraction methane   dimensionless    0.14582    0.14582
#     Total Mole Fraction ethane    dimensionless    0.11290    0.11290
#     Total Mole Fraction propane   dimensionless   0.023937   0.023937
#     Total Mole Fraction nbutane   dimensionless   0.010345   0.010345
#     Total Mole Fraction ibutane   dimensionless   0.061111   0.061111
#     Total Mole Fraction pentane   dimensionless   0.015355   0.015355
#     Total Mole Fraction hexane    dimensionless  0.0018151  0.0018151
#     Total Mole Fraction heptane   dimensionless 0.00050316 0.00050316
#     Total Mole Fraction octane    dimensionless 0.00020469 0.00020469
#     Total Mole Fraction ethylene  dimensionless    0.16345    0.16345
#     Total Mole Fraction propene   dimensionless    0.15820    0.15820
#     Total Mole Fraction butene    dimensionless   0.070847   0.070847
#     Total Mole Fraction pentene   dimensionless   0.015797   0.015797
#     Total Mole Fraction hexene    dimensionless  0.0062580  0.0062580
#     Total Mole Fraction heptene   dimensionless  0.0031782  0.0031782
#     Total Mole Fraction octene    dimensionless 0.00093393 0.00093393
#     Total Mole Fraction nonene    dimensionless 0.00092275 0.00092275
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     3113.8     474.48     2639.3
#     Total Mole Fraction hydrogen  dimensionless    0.20843    0.78736    0.10435
#     Total Mole Fraction methane   dimensionless    0.14582   0.073445    0.15883
#     Total Mole Fraction ethane    dimensionless    0.11290   0.056867    0.12298
#     Total Mole Fraction propane   dimensionless   0.023937 1.5709e-09   0.028241
#     Total Mole Fraction nbutane   dimensionless   0.010345 6.7889e-10   0.012205
#     Total Mole Fraction ibutane   dimensionless   0.061111 4.0103e-09   0.072097
#     Total Mole Fraction pentane   dimensionless   0.015355 1.0077e-09   0.018116
#     Total Mole Fraction hexane    dimensionless  0.0018151 1.1912e-10  0.0021414
#     Total Mole Fraction heptane   dimensionless 0.00050316 3.3019e-11 0.00059362
#     Total Mole Fraction octane    dimensionless 0.00020469 1.3433e-11 0.00024149
#     Total Mole Fraction ethylene  dimensionless    0.16345   0.082327    0.17803
#     Total Mole Fraction propene   dimensionless    0.15820 1.0382e-08    0.18664
#     Total Mole Fraction butene    dimensionless   0.070847 4.6492e-09   0.083583
#     Total Mole Fraction pentene   dimensionless   0.015797 1.0367e-09   0.018638
#     Total Mole Fraction hexene    dimensionless  0.0062580 4.1067e-10  0.0073830
#     Total Mole Fraction heptene   dimensionless  0.0031782 2.0857e-10  0.0037496
#     Total Mole Fraction octene    dimensionless 0.00093393 6.1288e-11  0.0011018
#     Total Mole Fraction nonene    dimensionless 0.00092275 6.0555e-11  0.0010886
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.3003e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     474.48     474.48
#     Total Mole Fraction hydrogen  dimensionless    0.78736    0.78736
#     Total Mole Fraction methane   dimensionless   0.073445   0.073445
#     Total Mole Fraction ethane    dimensionless   0.056867   0.056867
#     Total Mole Fraction ethylene  dimensionless   0.082327   0.082327
#     Temperature                          kelvin     473.00     329.23
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.3364e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2639.3     2639.3
#     Total Mole Fraction hydrogen  dimensionless    0.10435    0.10435
#     Total Mole Fraction methane   dimensionless    0.15883    0.15883
#     Total Mole Fraction ethane    dimensionless    0.12298    0.12298
#     Total Mole Fraction propane   dimensionless   0.028241   0.028241
#     Total Mole Fraction nbutane   dimensionless   0.012205   0.012205
#     Total Mole Fraction ibutane   dimensionless   0.072097   0.072097
#     Total Mole Fraction pentane   dimensionless   0.018116   0.018116
#     Total Mole Fraction hexane    dimensionless  0.0021414  0.0021414
#     Total Mole Fraction heptane   dimensionless 0.00059362 0.00059362
#     Total Mole Fraction octane    dimensionless 0.00024149 0.00024149
#     Total Mole Fraction ethylene  dimensionless    0.17803    0.17803
#     Total Mole Fraction propene   dimensionless    0.18664    0.18664
#     Total Mole Fraction butene    dimensionless   0.083583   0.083583
#     Total Mole Fraction pentene   dimensionless   0.018638   0.018638
#     Total Mole Fraction hexene    dimensionless  0.0073830  0.0073830
#     Total Mole Fraction heptene   dimensionless  0.0037496  0.0037496
#     Total Mole Fraction octene    dimensionless  0.0011018  0.0011018
#     Total Mole Fraction nonene    dimensionless  0.0010886  0.0010886
#     Temperature                          kelvin     473.00     573.00
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2639.3     2439.4
#     Total Mole Fraction hydrogen  dimensionless    0.10435    0.11290
#     Total Mole Fraction methane   dimensionless    0.15883    0.17184
#     Total Mole Fraction ethane    dimensionless    0.12298    0.13305
#     Total Mole Fraction propane   dimensionless   0.028241   0.030555
#     Total Mole Fraction nbutane   dimensionless   0.012205   0.013205
#     Total Mole Fraction ibutane   dimensionless   0.072097   0.078004
#     Total Mole Fraction pentane   dimensionless   0.018116   0.019600
#     Total Mole Fraction hexane    dimensionless  0.0021414  0.0023169
#     Total Mole Fraction heptane   dimensionless 0.00059362 0.00064226
#     Total Mole Fraction octane    dimensionless 0.00024149 0.00026128
#     Total Mole Fraction ethylene  dimensionless    0.17803    0.13022
#     Total Mole Fraction propene   dimensionless    0.18664    0.14531
#     Total Mole Fraction butene    dimensionless   0.083583   0.082667
#     Total Mole Fraction pentene   dimensionless   0.018638   0.025050
#     Total Mole Fraction hexene    dimensionless  0.0073830   0.015196
#     Total Mole Fraction heptene   dimensionless  0.0037496   0.017641
#     Total Mole Fraction octene    dimensionless  0.0011018   0.010840
#     Total Mole Fraction nonene    dimensionless  0.0010886   0.010710
#     Temperature                          kelvin     573.00     573.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.4603e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2439.4     2439.4
#     Total Mole Fraction hydrogen  dimensionless    0.11290    0.11290
#     Total Mole Fraction methane   dimensionless    0.17184    0.17184
#     Total Mole Fraction ethane    dimensionless    0.13305    0.13305
#     Total Mole Fraction propane   dimensionless   0.030555   0.030555
#     Total Mole Fraction nbutane   dimensionless   0.013205   0.013205
#     Total Mole Fraction ibutane   dimensionless   0.078004   0.078004
#     Total Mole Fraction pentane   dimensionless   0.019600   0.019600
#     Total Mole Fraction hexane    dimensionless  0.0023169  0.0023169
#     Total Mole Fraction heptane   dimensionless 0.00064226 0.00064226
#     Total Mole Fraction octane    dimensionless 0.00026128 0.00026128
#     Total Mole Fraction ethylene  dimensionless    0.13022    0.13022
#     Total Mole Fraction propene   dimensionless    0.14531    0.14531
#     Total Mole Fraction butene    dimensionless   0.082667   0.082667
#     Total Mole Fraction pentene   dimensionless   0.025050   0.025050
#     Total Mole Fraction hexene    dimensionless   0.015196   0.015196
#     Total Mole Fraction heptene   dimensionless   0.017641   0.017641
#     Total Mole Fraction octene    dimensionless   0.010840   0.010840
#     Total Mole Fraction nonene    dimensionless   0.010710   0.010710
#     Temperature                          kelvin     573.00     308.00
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     474.48     474.48
#     Total Mole Fraction hydrogen  dimensionless    0.78736    0.78736
#     Total Mole Fraction methane   dimensionless   0.073445   0.073445
#     Total Mole Fraction ethane    dimensionless   0.056867   0.056867
#     Total Mole Fraction propane   dimensionless 1.5709e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.7889e-10          -
#     Total Mole Fraction ibutane   dimensionless 4.0103e-09          -
#     Total Mole Fraction pentane   dimensionless 1.0077e-09          -
#     Total Mole Fraction hexane    dimensionless 1.1912e-10          -
#     Total Mole Fraction heptane   dimensionless 3.3019e-11          -
#     Total Mole Fraction octane    dimensionless 1.3433e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.082327   0.082327
#     Total Mole Fraction propene   dimensionless 1.0382e-08          -
#     Total Mole Fraction butene    dimensionless 4.6492e-09          -
#     Total Mole Fraction pentene   dimensionless 1.0367e-09          -
#     Total Mole Fraction hexene    dimensionless 4.1067e-10          -
#     Total Mole Fraction heptene   dimensionless 2.0857e-10          -
#     Total Mole Fraction octene    dimensionless 6.1288e-11          -
#     Total Mole Fraction nonene    dimensionless 6.0555e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.5333e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     3.9032
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     2.8488
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     3.7216
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     16.374
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     13.877
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     3.0959
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2277
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.58133
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     2.6349
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     11.787
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     19.900
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     13.657
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     18.681
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     33.796
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     23.719
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     23.435
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.40     275.40
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     324.57     320.67
#     Molar Flowrate ('Vap', 'propane')   mole / second     74.535     71.687
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     32.213     28.491
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     190.28     173.91
#     Molar Flowrate ('Vap', 'pentane')   mole / second     47.812     33.935
#     Molar Flowrate ('Vap', 'hexane')    mole / second     5.6518     2.5560
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.5667    0.33907
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.63736   0.056032
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     317.65     315.02
#     Molar Flowrate ('Vap', 'propene')   mole / second     354.46     342.67
#     Molar Flowrate ('Vap', 'butene')    mole / second     201.66     181.76
#     Molar Flowrate ('Vap', 'pentene')   mole / second     61.108     47.450
#     Molar Flowrate ('Vap', 'hexene')    mole / second     37.069     18.388
#     Molar Flowrate ('Vap', 'heptene')   mole / second     43.033     9.2365
#     Molar Flowrate ('Vap', 'octene')    mole / second     26.443     2.7245
#     Molar Flowrate ('Vap', 'nonene')    mole / second     26.127     2.6919
#     Temperature                                kelvin     308.00     307.01
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -59182. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     3.9032            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.8488            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     3.7216            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     16.374            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     13.877            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     3.0959            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2277            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.58133            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     2.6349            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     11.787            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     19.900            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     13.657            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     18.681            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     33.796            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     23.719            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     23.435            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     275.40            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     320.67            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     71.687            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     28.491            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     173.91            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     33.935            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     2.5560            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.33907            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.056032            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     315.02            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     342.67            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     181.76            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     47.450            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     18.388            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     9.2365            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     2.7245            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second     2.6919            -             -
#     Temperature                                     kelvin     307.01            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        3.3298
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.4794
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        3.3240
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        14.506
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.817
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9631
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2064
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57803
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.2351
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        10.234
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        17.698
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        12.476
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        17.780
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        33.215
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        23.554
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        23.273
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       275.40    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       321.24    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       72.056    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       28.889    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       175.78    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       34.996    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       2.6887    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.36037    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.059330    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       315.42    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       344.23    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       183.96    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       48.632    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       19.288    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       9.8172    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       2.8888    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -       2.8542    1.0000e-08
#     temperature                                     kelvin          -       305.06        305.06
#     pressure                                        pascal          -   4.4082e+05    4.4082e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units : Fixed : Bounds
#     Heat Duty : -66185. :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     3.3298     1.7604
#     Molar Flowrate ('Liq', 'propane')   mole / second     2.4794     1.9789
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     3.3240     3.1035
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     14.506     13.177
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.817     12.553
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9631     2.9437
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2064     1.2039
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57803    0.57765
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.2351    0.95984
#     Molar Flowrate ('Liq', 'propene')   mole / second     10.234     7.9051
#     Molar Flowrate ('Liq', 'butene')    mole / second     17.698     16.300
#     Molar Flowrate ('Liq', 'pentene')   mole / second     12.476     12.106
#     Molar Flowrate ('Liq', 'hexene')    mole / second     17.780     17.640
#     Molar Flowrate ('Liq', 'heptene')   mole / second     33.215     33.148
#     Molar Flowrate ('Liq', 'octene')    mole / second     23.554     23.536
#     Molar Flowrate ('Liq', 'nonene')    mole / second     23.273     23.254
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     1.5694
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.50047
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.22055
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     1.3290
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.26391
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.019419
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0024660
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00038412
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.2752
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     2.3289
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08     1.3981
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.37003
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.14055
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.067107
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.018888
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.018661
#     Temperature                                kelvin     305.06     298.00
#     Pressure                                   pascal 4.4082e+05 1.8589e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -75483. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     1.7604            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     1.9789            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     3.1035            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     13.177            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.553            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9437            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2039            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57765            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second    0.95984            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     7.9051            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     16.300            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     12.106            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     17.640            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     33.148            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     23.536            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     23.254            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     1.5694            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.50047            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.22055            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     1.3290            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.26391            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.019419            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0024660            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00038412            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.2752            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     2.3289            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     1.3981            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.37003            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.14055            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.067107            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.018888            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.018661            -             -
#     Temperature                                     kelvin     298.00            -             -
#     Pressure                                        pascal 1.8589e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08       0.80207
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        1.3441
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        2.7164
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        10.964
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.062
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9090
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.1998
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57706
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.38669
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        5.1448
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        13.912
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        11.422
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        17.387
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        33.037
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        23.506
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        23.225
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       2.5277    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       1.1352    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.60765    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       3.5426    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.75417    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.054065    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0065531    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -   0.00097021    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       1.8484    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       5.0892    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       3.7866    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       1.0542    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.39396    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -      0.17842    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.048106    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.047530    1.0000e-08
#     temperature                                     kelvin          -       290.79        290.79
#     pressure                                        pascal          -   1.1040e+05    1.1040e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2439.4          -
#     Total Mole Fraction hydrogen        dimensionless    0.11290          -
#     Total Mole Fraction methane         dimensionless    0.17184          -
#     Total Mole Fraction ethane          dimensionless    0.13305          -
#     Total Mole Fraction propane         dimensionless   0.030555          -
#     Total Mole Fraction nbutane         dimensionless   0.013205          -
#     Total Mole Fraction ibutane         dimensionless   0.078004          -
#     Total Mole Fraction pentane         dimensionless   0.019600          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     275.40
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     324.57
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     74.535
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     32.213
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     190.28
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     47.812
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     5.6518
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.5667
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.63736
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     317.65
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     354.46
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     201.66
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     61.108
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     37.069
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     43.033
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     26.443
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     26.127
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     275.40          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     321.24          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     72.056          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     28.889          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     175.78          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     34.996          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     2.6887          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.36037          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.059330          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     315.42          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     344.23          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     183.96          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     48.632          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     19.288          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     9.8172          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     2.8888          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second     2.8542          -
#     Temperature                                kelvin     305.06     305.06
#     Pressure                                   pascal 4.4082e+05 4.4082e+05
#     Total Molar Flowrate                mole / second          -     2257.7
#     Total Mole Fraction hydrogen        dimensionless          -    0.12198
#     Total Mole Fraction methane         dimensionless          -    0.18567
#     Total Mole Fraction ethane          dimensionless          -    0.14228
#     Total Mole Fraction propane         dimensionless          -   0.031915
#     Total Mole Fraction nbutane         dimensionless          -   0.012795
#     Total Mole Fraction ibutane         dimensionless          -   0.077856
#     Total Mole Fraction pentane         dimensionless          -   0.015500
#     Total Mole Fraction hexane          dimensionless          -  0.0011909
#     Total Mole Fraction heptane         dimensionless          - 0.00015961
#     Total Mole Fraction octane          dimensionless          - 2.6279e-05
#     Total Mole Fraction ethylene        dimensionless          -    0.13971
#     Total Mole Fraction propene         dimensionless          -    0.15246
#     Total Mole Fraction butene          dimensionless          -   0.081480
#     Total Mole Fraction pentene         dimensionless          -   0.021540
#     Total Mole Fraction hexene          dimensionless          -  0.0085432
#     Total Mole Fraction heptene         dimensionless          -  0.0043483
#     Total Mole Fraction octene          dimensionless          -  0.0012795
#     Total Mole Fraction nonene          dimensionless          -  0.0012642
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     89277. :          watt : False : (None, None)
#           Pressure Change : 3.3042e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     3.9928 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     21.075     21.075
#     Total Mole Fraction ethane    dimensionless    0.11994    0.11994
#     Total Mole Fraction propane   dimensionless   0.053865   0.053865
#     Total Mole Fraction nbutane   dimensionless   0.028832   0.028832
#     Total Mole Fraction ibutane   dimensionless    0.16809    0.16809
#     Total Mole Fraction pentane   dimensionless   0.035784   0.035784
#     Total Mole Fraction hexane    dimensionless  0.0025653  0.0025653
#     Total Mole Fraction heptane   dimensionless 0.00031094 0.00031094
#     Total Mole Fraction octane    dimensionless 4.6035e-05 4.6035e-05
#     Total Mole Fraction ethylene  dimensionless   0.087702   0.087702
#     Total Mole Fraction propene   dimensionless    0.24148    0.24148
#     Total Mole Fraction butene    dimensionless    0.17967    0.17967
#     Total Mole Fraction pentene   dimensionless   0.050022   0.050022
#     Total Mole Fraction hexene    dimensionless   0.018693   0.018693
#     Total Mole Fraction heptene   dimensionless  0.0084656  0.0084656
#     Total Mole Fraction octene    dimensionless  0.0022826  0.0022826
#     Total Mole Fraction nonene    dimensionless  0.0022552  0.0022552
#     Temperature                          kelvin     290.79     342.26
#     Pressure                             pascal 1.1040e+05 4.4082e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          2257.7              21.075         2278.8
#     Total Mole Fraction hydrogen  dimensionless         0.12198          1.0000e-08        0.12085
#     Total Mole Fraction methane   dimensionless         0.18567          1.0000e-08        0.18395
#     Total Mole Fraction ethane    dimensionless         0.14228             0.11994        0.14208
#     Total Mole Fraction propane   dimensionless        0.031915            0.053865       0.032118
#     Total Mole Fraction nbutane   dimensionless        0.012795            0.028832       0.012944
#     Total Mole Fraction ibutane   dimensionless        0.077856             0.16809       0.078690
#     Total Mole Fraction pentane   dimensionless        0.015500            0.035784       0.015688
#     Total Mole Fraction hexane    dimensionless       0.0011909           0.0025653      0.0012036
#     Total Mole Fraction heptane   dimensionless      0.00015961          0.00031094     0.00016101
#     Total Mole Fraction octane    dimensionless      2.6279e-05          4.6035e-05     2.6461e-05
#     Total Mole Fraction ethylene  dimensionless         0.13971            0.087702        0.13922
#     Total Mole Fraction propene   dimensionless         0.15246             0.24148        0.15329
#     Total Mole Fraction butene    dimensionless        0.081480             0.17967       0.082388
#     Total Mole Fraction pentene   dimensionless        0.021540            0.050022       0.021803
#     Total Mole Fraction hexene    dimensionless       0.0085432            0.018693      0.0086371
#     Total Mole Fraction heptene   dimensionless       0.0043483           0.0084656      0.0043863
#     Total Mole Fraction octene    dimensionless       0.0012795           0.0022826      0.0012888
#     Total Mole Fraction nonene    dimensionless       0.0012642           0.0022552      0.0012734
#     Temperature                          kelvin          305.06              342.26         305.54
#     Pressure                             pascal      4.4082e+05          4.4082e+05     4.4082e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     2278.8     22.788     2256.0
#     Total Mole Fraction hydrogen  dimensionless    0.12085    0.12085    0.12085
#     Total Mole Fraction methane   dimensionless    0.18395    0.18395    0.18395
#     Total Mole Fraction ethane    dimensionless    0.14208    0.14208    0.14208
#     Total Mole Fraction propane   dimensionless   0.032118   0.032118   0.032118
#     Total Mole Fraction nbutane   dimensionless   0.012944   0.012944   0.012944
#     Total Mole Fraction ibutane   dimensionless   0.078690   0.078690   0.078690
#     Total Mole Fraction pentane   dimensionless   0.015688   0.015688   0.015688
#     Total Mole Fraction hexane    dimensionless  0.0012036  0.0012036  0.0012036
#     Total Mole Fraction heptane   dimensionless 0.00016101 0.00016101 0.00016101
#     Total Mole Fraction octane    dimensionless 2.6461e-05 2.6461e-05 2.6461e-05
#     Total Mole Fraction ethylene  dimensionless    0.13922    0.13922    0.13922
#     Total Mole Fraction propene   dimensionless    0.15329    0.15329    0.15329
#     Total Mole Fraction butene    dimensionless   0.082388   0.082388   0.082388
#     Total Mole Fraction pentene   dimensionless   0.021803   0.021803   0.021803
#     Total Mole Fraction hexene    dimensionless  0.0086371  0.0086371  0.0086371
#     Total Mole Fraction heptene   dimensionless  0.0043863  0.0043863  0.0043863
#     Total Mole Fraction octene    dimensionless  0.0012888  0.0012888  0.0012888
#     Total Mole Fraction nonene    dimensionless  0.0012734  0.0012734  0.0012734
#     Temperature                          kelvin     305.54     305.54     305.54
#     Pressure                             pascal 4.4082e+05 4.4082e+05 4.4082e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 3.2196e+06 :          watt : False : (None, None)
#           Pressure Change : 2.5918e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.5880 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2256.0     2256.0
#     Total Mole Fraction hydrogen  dimensionless    0.12085    0.12085
#     Total Mole Fraction methane   dimensionless    0.18395    0.18395
#     Total Mole Fraction ethane    dimensionless    0.14208    0.14208
#     Total Mole Fraction propane   dimensionless   0.032118   0.032118
#     Total Mole Fraction nbutane   dimensionless   0.012944   0.012944
#     Total Mole Fraction ibutane   dimensionless   0.078690   0.078690
#     Total Mole Fraction pentane   dimensionless   0.015688   0.015688
#     Total Mole Fraction hexane    dimensionless  0.0012036  0.0012036
#     Total Mole Fraction heptane   dimensionless 0.00016101 0.00016101
#     Total Mole Fraction octane    dimensionless 2.6461e-05 2.6461e-05
#     Total Mole Fraction ethylene  dimensionless    0.13922    0.13922
#     Total Mole Fraction propene   dimensionless    0.15329    0.15329
#     Total Mole Fraction butene    dimensionless   0.082388   0.082388
#     Total Mole Fraction pentene   dimensionless   0.021803   0.021803
#     Total Mole Fraction hexene    dimensionless  0.0086371  0.0086371
#     Total Mole Fraction heptene   dimensionless  0.0043863  0.0043863
#     Total Mole Fraction octene    dimensionless  0.0012888  0.0012888
#     Total Mole Fraction nonene    dimensionless  0.0012734  0.0012734
#     Temperature                          kelvin     305.54     328.91
#     Pressure                             pascal 4.4082e+05 7.0000e+05
# ====================================================================================
