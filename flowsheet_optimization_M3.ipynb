# %% [markdown]
# # Flowsheet optimization
# ## ROK model: M3; Region: Bakken; CO$_2$ tax rate: USD 45/tonne CO$_2$e

# %%
# simulation case specifications
model_code = 3
case_name = 'Bakken'
c_tax_rate = 4.5e-2

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                    define_models, \
                                    define_arcs, \
                                    set_unit_model_variables, \
                                    initialize_flowsheet, \
                                    set_scaling_factors,\
                                    update_model_after_initialization,\
                                    vapor_only_to_vapor_liquid_reformulate,\
                                    update_model_for_optimization, \
                                    unfix_DOFs_pre_optimization, \
                                    fix_DOFs_post_optimization

# %% [markdown]
# ## Create flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

inlet_composition_dict

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188}

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Read-in initialization data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code)
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.05484414100646973,
#  'etime_read_dict': 0.1909956932067871,
#  'etime_read_suffixes': 0.0059833526611328125}

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %% [markdown]
# ## Read-in flowsheet convergence data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3))
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.08705401420593262,
#  'etime_read_dict': 0.17519044876098633,
#  'etime_read_suffixes': 0.0}

# %% [markdown]
# ## Costing

# %%
from src.emissions_calculations import calc_lhv_values, calculate_stream_energies, calculate_emissions, create_ghg_objective
from src.costing_function import add_costing,calculate_costs_for_objective
from src.utility_minimization_1d import (
    min_utility,
    PinchDataClass,
    heat_ex_data,
    gen_curves,
    print_HX_results,
    generate_curves,
    heat_data,
    pinch_calc,
    return_data
)

# %% [markdown]
# ### Equipment costing

# %%
add_costing(m)

# %% [markdown]
# ### Heat integration

# %%
### Heat Exchangers and reactors
min_utility(
    m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102], 10.0
)
m.fs.Qs.fix()

# %% [markdown]
# ### Emissions calculation

# %%
calc_lhv_values(m,case_name,'./LHV.xlsx','NGL_compositions.csv','NGL_fraction.csv')
calculate_stream_energies(m)
calculate_emissions(m,case_name,'emissions_factor_by_region.csv')
create_ghg_objective(m)
calculate_costs_for_objective(m,c_tax_flag=True, c_tax_val = c_tax_rate)

# %% [markdown]
# ## Read-in costing-initialized flowsheet data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_solve_with_costing_{}_C_tax_{}_M{}_purge_{}.json.gz".format(case_name,m.fs.c_tax_rate(), model_code,round(m.fs.S102.split_fraction[0, "purge"](),3))
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.0558011531829834,
#  'etime_read_dict': 0.15869641304016113,
#  'etime_read_suffixes': 0.015619993209838867}

# %% [markdown]
# ## Flowsheet optimization with 8 DOFs

# %%
update_model_for_optimization(m)
unfix_DOFs_pre_optimization(m)
# Out:
# Model updates:
#
#
# Constraint added for recycle ratio <= 8.0.
#
# fs.H103 temperature lower and upper bounds added.
#
# fs.R102 isothermal operation constraint added.
#
# fs.H106 temperature lower bound updated.
#
# fs.F102 temperature lower bound updated.
#
# Objective function added.

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter': 500,
                 }

# %%
DOF_initial = degrees_of_freedom(m)
print("The initial DOF is {0}".format(DOF_initial))
# Out:
# The initial DOF is 8

# %%
solve_status = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    34098
# Number of nonzeros in inequality constraint Jacobian.:      178
# Number of nonzeros in Lagrangian Hessian.............:    17881
#
# Total number of variables............................:     5555
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:     3166
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     5547
# Total number of inequality constraints...............:       71
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       51
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1184956e+01 5.96e-08 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1185449e+01 9.35e-03 2.99e+05  -1.0 3.47e+02    -  9.70e-01 1.00e+00f  1
#    2  1.1199954e+01 9.21e+00 5.13e+03  -1.0 1.16e+04    -  9.89e-01 1.00e+00f  1
#    3  1.1468371e+01 1.53e+04 9.23e+04  -1.0 9.31e+05    -  3.13e-01 1.00e+00f  1
#    4  1.1855718e+01 2.69e+04 1.31e+04  -1.0 1.03e+06    -  8.32e-01 1.00e+00h  1
#    5  1.2046810e+01 7.22e+04 1.84e+05  -1.0 4.40e+06    -  8.31e-01 1.00e+00f  1
#    6  1.2025714e+01 1.58e+04 3.34e+05  -1.0 1.63e+07    -  9.25e-01 8.22e-01H  1
#    7  1.1985106e+01 2.73e+04 2.92e+05  -1.0 3.31e+07    -  2.51e-01 6.20e-01h  1
#    8  1.1983826e+01 2.06e+04 6.80e+04  -1.0 9.60e+05    -  9.90e-01 2.50e-01h  1
#    9  1.1988264e+01 1.69e+03 6.86e+03  -1.0 4.69e+05    -  9.93e-01 9.35e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1988378e+01 9.49e+00 7.33e+01  -1.0 3.14e+05    -  1.00e+00 1.00e+00h  1
#   11  1.1988377e+01 4.47e-04 2.10e-03  -1.0 1.71e+03    -  1.00e+00 1.00e+00h  1
#   12  1.1183826e+01 7.58e+02 2.64e+06  -5.7 3.91e+04    -  9.90e-01 7.26e-01f  1
#   13  1.1183790e+01 4.77e-02 1.31e+03  -5.7 3.22e+01  -4.0 9.87e-01 1.00e+00h  1
#   14  1.1183788e+01 5.39e-02 4.40e-01  -5.7 3.50e+00  -4.5 1.00e+00 1.00e+00h  1
#   15  1.1183788e+01 2.08e-04 8.93e-04  -5.7 2.02e+00  -5.0 1.00e+00 1.00e+00h  1
#   16  1.1183788e+01 2.05e-04 8.38e-05  -5.7 1.60e+00  -5.4 1.00e+00 1.00e+00h  1
#   17  1.1183788e+01 2.30e-07 9.64e-07  -5.7 3.85e-02  -5.9 1.00e+00 1.00e+00h  1
#   18  1.1183786e+01 1.79e-07 3.22e-05  -7.0 1.38e-01  -6.4 1.00e+00 1.00e+00h  1
#   19  1.1183786e+01 2.56e-06 5.69e-08  -7.0 4.15e-01  -6.9 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1183786191462614e+01    1.1183786191462614e+01
# Dual infeasibility......:   5.6911934164725997e-08    5.6911934164725997e-08
# Constraint violation....:   2.1420419216156006e-08    2.5629997253417969e-06
# Complementarity.........:   9.0909099956208928e-08    9.0909099956208928e-08
# Overall NLP error.......:   9.0909099956208928e-08    2.5629997253417969e-06
#
#
# Number of objective function evaluations             = 20
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 21
# Number of inequality constraint evaluations          = 21
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 20
# Number of Lagrangian Hessian evaluations             = 19
# Total CPU secs in IPOPT (w/o function evaluations)   =     39.758
# Total CPU secs in NLP function evaluations           =    669.838
#
# EXIT: Optimal Solution Found.

# %%
fix_DOFs_post_optimization(m)

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_optimal_solution_{}_C_tax_{}_M{}_purge_{}.json.gz".format(case_name,m.fs.c_tax_rate(), model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))

# %% [markdown]
# ## Save and display results

# %%
CDs = heat_ex_data(m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102])
generate_curves(CDs)

# %%
m.fs.min_sell_price() # $/GJ fuel
# Out:
# 11.183786191462614

# %%
m.fs.downstream_emissions() # kg CO2e/GJ fuel
# Out:
# 8.901408160828788

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     2052.4     2533.8
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.13167    0.10666
#     Total Mole Fraction methane   dimensionless   0.081100    0.20220    0.17919
#     Total Mole Fraction ethane    dimensionless    0.46920    0.15514    0.21481
#     Total Mole Fraction propane   dimensionless    0.30920   0.034496   0.086686
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.012860   0.025312
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.052923   0.047903
#     Total Mole Fraction pentane   dimensionless   0.025800   0.010414   0.013337
#     Total Mole Fraction hexane    dimensionless  0.0061000 0.00078276  0.0017930
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00010192 0.00055752
#     Total Mole Fraction octane    dimensionless  0.0012000 1.6286e-05 0.00024117
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06    0.12387    0.10034
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.14546    0.11782
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.092482   0.074912
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.025885   0.020968
#     Total Mole Fraction hexene    dimensionless 1.0000e-06  0.0078412  0.0063516
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0028524  0.0023106
#     Total Mole Fraction octene    dimensionless 1.0000e-06 0.00056865 0.00046081
#     Total Mole Fraction nonene    dimensionless 1.0000e-06 0.00044080 0.00035725
#     Temperature                          kelvin     308.00     317.36     315.38
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.0812e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2533.8     2533.8
#     Total Mole Fraction hydrogen  dimensionless    0.10666    0.10666
#     Total Mole Fraction methane   dimensionless    0.17919    0.17919
#     Total Mole Fraction ethane    dimensionless    0.21481    0.21481
#     Total Mole Fraction propane   dimensionless   0.086686   0.086686
#     Total Mole Fraction nbutane   dimensionless   0.025312   0.025312
#     Total Mole Fraction ibutane   dimensionless   0.047903   0.047903
#     Total Mole Fraction pentane   dimensionless   0.013337   0.013337
#     Total Mole Fraction hexane    dimensionless  0.0017930  0.0017930
#     Total Mole Fraction heptane   dimensionless 0.00055752 0.00055752
#     Total Mole Fraction octane    dimensionless 0.00024117 0.00024117
#     Total Mole Fraction ethylene  dimensionless    0.10034    0.10034
#     Total Mole Fraction propene   dimensionless    0.11782    0.11782
#     Total Mole Fraction butene    dimensionless   0.074912   0.074912
#     Total Mole Fraction pentene   dimensionless   0.020968   0.020968
#     Total Mole Fraction hexene    dimensionless  0.0063516  0.0063516
#     Total Mole Fraction heptene   dimensionless  0.0023106  0.0023106
#     Total Mole Fraction octene    dimensionless 0.00046081 0.00046081
#     Total Mole Fraction nonene    dimensionless 0.00035725 0.00035725
#     Temperature                          kelvin     315.38     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.1505e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     194.09 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     145.67 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     33.274 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2533.8     2906.9
#     Total Mole Fraction hydrogen  dimensionless    0.10666    0.22130
#     Total Mole Fraction methane   dimensionless    0.17919    0.15619
#     Total Mole Fraction ethane    dimensionless    0.21481    0.12047
#     Total Mole Fraction propane   dimensionless   0.086686   0.025449
#     Total Mole Fraction nbutane   dimensionless   0.025312   0.010617
#     Total Mole Fraction ibutane   dimensionless   0.047903   0.041756
#     Total Mole Fraction pentane   dimensionless   0.013337   0.011625
#     Total Mole Fraction hexane    dimensionless  0.0017930  0.0015629
#     Total Mole Fraction heptane   dimensionless 0.00055752 0.00048597
#     Total Mole Fraction octane    dimensionless 0.00024117 0.00021022
#     Total Mole Fraction ethylene  dimensionless    0.10034    0.15423
#     Total Mole Fraction propene   dimensionless    0.11782    0.15282
#     Total Mole Fraction butene    dimensionless   0.074912   0.076745
#     Total Mole Fraction pentene   dimensionless   0.020968   0.018277
#     Total Mole Fraction hexene    dimensionless  0.0063516  0.0055366
#     Total Mole Fraction heptene   dimensionless  0.0023106  0.0020141
#     Total Mole Fraction octene    dimensionless 0.00046081 0.00040167
#     Total Mole Fraction nonene    dimensionless 0.00035725 0.00031140
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.7497e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2906.9     2906.9
#     Total Mole Fraction hydrogen  dimensionless    0.22130    0.22130
#     Total Mole Fraction methane   dimensionless    0.15619    0.15619
#     Total Mole Fraction ethane    dimensionless    0.12047    0.12047
#     Total Mole Fraction propane   dimensionless   0.025449   0.025449
#     Total Mole Fraction nbutane   dimensionless   0.010617   0.010617
#     Total Mole Fraction ibutane   dimensionless   0.041756   0.041756
#     Total Mole Fraction pentane   dimensionless   0.011625   0.011625
#     Total Mole Fraction hexane    dimensionless  0.0015629  0.0015629
#     Total Mole Fraction heptane   dimensionless 0.00048597 0.00048597
#     Total Mole Fraction octane    dimensionless 0.00021022 0.00021022
#     Total Mole Fraction ethylene  dimensionless    0.15423    0.15423
#     Total Mole Fraction propene   dimensionless    0.15282    0.15282
#     Total Mole Fraction butene    dimensionless   0.076745   0.076745
#     Total Mole Fraction pentene   dimensionless   0.018277   0.018277
#     Total Mole Fraction hexene    dimensionless  0.0055366  0.0055366
#     Total Mole Fraction heptene   dimensionless  0.0020141  0.0020141
#     Total Mole Fraction octene    dimensionless 0.00040167 0.00040167
#     Total Mole Fraction nonene    dimensionless 0.00031140 0.00031140
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     2906.9     466.44     2440.4
#     Total Mole Fraction hydrogen  dimensionless    0.22130    0.79389    0.11186
#     Total Mole Fraction methane   dimensionless    0.15619   0.074712    0.17177
#     Total Mole Fraction ethane    dimensionless    0.12047   0.057624    0.13248
#     Total Mole Fraction propane   dimensionless   0.025449 1.5860e-09   0.030313
#     Total Mole Fraction nbutane   dimensionless   0.010617 6.6165e-10   0.012646
#     Total Mole Fraction ibutane   dimensionless   0.041756 2.6022e-09   0.049736
#     Total Mole Fraction pentane   dimensionless   0.011625 7.2449e-10   0.013847
#     Total Mole Fraction hexane    dimensionless  0.0015629 9.7398e-11  0.0018616
#     Total Mole Fraction heptane   dimensionless 0.00048597 3.0286e-11 0.00057886
#     Total Mole Fraction octane    dimensionless 0.00021022 1.3101e-11 0.00025040
#     Total Mole Fraction ethylene  dimensionless    0.15423   0.073772    0.16961
#     Total Mole Fraction propene   dimensionless    0.15282 9.5235e-09    0.18202
#     Total Mole Fraction butene    dimensionless   0.076745 4.7828e-09   0.091414
#     Total Mole Fraction pentene   dimensionless   0.018277 1.1390e-09   0.021770
#     Total Mole Fraction hexene    dimensionless  0.0055366 3.4504e-10  0.0065948
#     Total Mole Fraction heptene   dimensionless  0.0020141 1.2552e-10  0.0023991
#     Total Mole Fraction octene    dimensionless 0.00040167 2.5032e-11 0.00047844
#     Total Mole Fraction nonene    dimensionless 0.00031140 1.9407e-11 0.00037092
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.2588e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     466.44     466.44
#     Total Mole Fraction hydrogen  dimensionless    0.79389    0.79389
#     Total Mole Fraction methane   dimensionless   0.074712   0.074712
#     Total Mole Fraction ethane    dimensionless   0.057624   0.057624
#     Total Mole Fraction ethylene  dimensionless   0.073772   0.073772
#     Temperature                          kelvin     473.00     328.63
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.6823e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2440.4     2440.4
#     Total Mole Fraction hydrogen  dimensionless    0.11186    0.11186
#     Total Mole Fraction methane   dimensionless    0.17177    0.17177
#     Total Mole Fraction ethane    dimensionless    0.13248    0.13248
#     Total Mole Fraction propane   dimensionless   0.030313   0.030313
#     Total Mole Fraction nbutane   dimensionless   0.012646   0.012646
#     Total Mole Fraction ibutane   dimensionless   0.049736   0.049736
#     Total Mole Fraction pentane   dimensionless   0.013847   0.013847
#     Total Mole Fraction hexane    dimensionless  0.0018616  0.0018616
#     Total Mole Fraction heptane   dimensionless 0.00057886 0.00057886
#     Total Mole Fraction octane    dimensionless 0.00025040 0.00025040
#     Total Mole Fraction ethylene  dimensionless    0.16961    0.16961
#     Total Mole Fraction propene   dimensionless    0.18202    0.18202
#     Total Mole Fraction butene    dimensionless   0.091414   0.091414
#     Total Mole Fraction pentene   dimensionless   0.021770   0.021770
#     Total Mole Fraction hexene    dimensionless  0.0065948  0.0065948
#     Total Mole Fraction heptene   dimensionless  0.0023991  0.0023991
#     Total Mole Fraction octene    dimensionless 0.00047844 0.00047844
#     Total Mole Fraction nonene    dimensionless 0.00037092 0.00037092
#     Temperature                          kelvin     473.00     598.48
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2440.4     2252.5
#     Total Mole Fraction hydrogen  dimensionless    0.11186    0.12119
#     Total Mole Fraction methane   dimensionless    0.17177    0.18610
#     Total Mole Fraction ethane    dimensionless    0.13248    0.14353
#     Total Mole Fraction propane   dimensionless   0.030313   0.032842
#     Total Mole Fraction nbutane   dimensionless   0.012646   0.013701
#     Total Mole Fraction ibutane   dimensionless   0.049736   0.053885
#     Total Mole Fraction pentane   dimensionless   0.013847   0.015002
#     Total Mole Fraction hexane    dimensionless  0.0018616  0.0020169
#     Total Mole Fraction heptane   dimensionless 0.00057886 0.00062714
#     Total Mole Fraction octane    dimensionless 0.00025040 0.00027129
#     Total Mole Fraction ethylene  dimensionless    0.16961    0.11431
#     Total Mole Fraction propene   dimensionless    0.18202    0.13763
#     Total Mole Fraction butene    dimensionless   0.091414   0.096010
#     Total Mole Fraction pentene   dimensionless   0.021770   0.033036
#     Total Mole Fraction hexene    dimensionless  0.0065948   0.017998
#     Total Mole Fraction heptene   dimensionless  0.0023991   0.017691
#     Total Mole Fraction octene    dimensionless 0.00047844  0.0079789
#     Total Mole Fraction nonene    dimensionless 0.00037092  0.0061850
#     Temperature                          kelvin     598.48     598.48
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.6157e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2252.5     2252.5
#     Total Mole Fraction hydrogen  dimensionless    0.12119    0.12119
#     Total Mole Fraction methane   dimensionless    0.18610    0.18610
#     Total Mole Fraction ethane    dimensionless    0.14353    0.14353
#     Total Mole Fraction propane   dimensionless   0.032842   0.032842
#     Total Mole Fraction nbutane   dimensionless   0.013701   0.013701
#     Total Mole Fraction ibutane   dimensionless   0.053885   0.053885
#     Total Mole Fraction pentane   dimensionless   0.015002   0.015002
#     Total Mole Fraction hexane    dimensionless  0.0020169  0.0020169
#     Total Mole Fraction heptane   dimensionless 0.00062714 0.00062714
#     Total Mole Fraction octane    dimensionless 0.00027129 0.00027129
#     Total Mole Fraction ethylene  dimensionless    0.11431    0.11431
#     Total Mole Fraction propene   dimensionless    0.13763    0.13763
#     Total Mole Fraction butene    dimensionless   0.096010   0.096010
#     Total Mole Fraction pentene   dimensionless   0.033036   0.033036
#     Total Mole Fraction hexene    dimensionless   0.017998   0.017998
#     Total Mole Fraction heptene   dimensionless   0.017691   0.017691
#     Total Mole Fraction octene    dimensionless  0.0079789  0.0079789
#     Total Mole Fraction nonene    dimensionless  0.0061850  0.0061850
#     Temperature                          kelvin     598.48     300.11
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     466.44     466.44
#     Total Mole Fraction hydrogen  dimensionless    0.79389    0.79389
#     Total Mole Fraction methane   dimensionless   0.074712   0.074712
#     Total Mole Fraction ethane    dimensionless   0.057624   0.057624
#     Total Mole Fraction propane   dimensionless 1.5860e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.6165e-10          -
#     Total Mole Fraction ibutane   dimensionless 2.6022e-09          -
#     Total Mole Fraction pentane   dimensionless 7.2449e-10          -
#     Total Mole Fraction hexane    dimensionless 9.7398e-11          -
#     Total Mole Fraction heptane   dimensionless 3.0286e-11          -
#     Total Mole Fraction octane    dimensionless 1.3101e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.073772   0.073772
#     Total Mole Fraction propene   dimensionless 9.5235e-09          -
#     Total Mole Fraction butene    dimensionless 4.7828e-09          -
#     Total Mole Fraction pentene   dimensionless 1.1390e-09          -
#     Total Mole Fraction hexene    dimensionless 3.4504e-10          -
#     Total Mole Fraction heptene   dimensionless 1.2552e-10          -
#     Total Mole Fraction octene    dimensionless 2.5032e-11          -
#     Total Mole Fraction nonene    dimensionless 1.9407e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.4366e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     4.9192
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     3.7166
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     4.7679
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     13.934
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     12.670
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     2.9538
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2054
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.57791
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     2.6657
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     13.520
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     28.559
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     21.911
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     24.624
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     34.048
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     16.814
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     13.034
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     272.98     272.98
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     323.31     318.39
#     Molar Flowrate ('Vap', 'propane')   mole / second     73.977     70.261
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     30.862     26.094
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     121.38     107.44
#     Molar Flowrate ('Vap', 'pentane')   mole / second     33.793     21.124
#     Molar Flowrate ('Vap', 'hexane')    mole / second     4.5430     1.5893
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.4127    0.20727
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.61109   0.033181
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     257.48     254.82
#     Molar Flowrate ('Vap', 'propene')   mole / second     310.02     296.50
#     Molar Flowrate ('Vap', 'butene')    mole / second     216.26     187.70
#     Molar Flowrate ('Vap', 'pentene')   mole / second     74.415     52.503
#     Molar Flowrate ('Vap', 'hexene')    mole / second     40.540     15.917
#     Molar Flowrate ('Vap', 'heptene')   mole / second     39.848     5.8007
#     Molar Flowrate ('Vap', 'octene')    mole / second     17.973     1.1582
#     Molar Flowrate ('Vap', 'nonene')    mole / second     13.932    0.89779
#     Temperature                                kelvin     300.11     299.34
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -1791.3 : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     4.9192            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     3.7166            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     4.7679            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     13.934            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.670            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9538            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2054            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57791            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     2.6657            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     13.520            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     28.559            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     21.911            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     24.624            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     34.048            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     16.814            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     13.034            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     272.98            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     318.39            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     70.261            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     26.094            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     107.44            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     21.124            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     1.5893            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.20727            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.033181            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     254.82            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     296.50            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     187.70            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     52.503            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     15.917            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     5.8007            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     1.1582            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second    0.89779            -             -
#     Temperature                                     kelvin     299.34            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        4.8980
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        3.7030
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        4.7545
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        13.891
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.648
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9514
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2051
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57787
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.6537
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        13.470
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        28.475
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        21.866
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        24.601
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        34.039
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        16.813
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        13.033
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       272.98    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       318.41    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       70.274    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       26.108    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       107.49    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       21.146    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       1.5916    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.20758    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.033221    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       254.83    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       296.55    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       187.79    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       52.549    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       15.940    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       5.8095    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       1.1597    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -      0.89893    1.0000e-08
#     temperature                                     kelvin          -       299.28        299.28
#     pressure                                        pascal          -   4.9821e+05    4.9821e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units : Fixed : Bounds
#     Heat Duty : -6170.4 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     4.8980     2.3267
#     Molar Flowrate ('Liq', 'propane')   mole / second     3.7030     2.8467
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     4.7545     4.3984
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     13.891     12.443
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.648     12.363
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9514     2.9311
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2051     1.2026
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57787    0.57750
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.6537    0.99460
#     Molar Flowrate ('Liq', 'propene')   mole / second     13.470     9.9656
#     Molar Flowrate ('Liq', 'butene')    mole / second     28.475     25.928
#     Molar Flowrate ('Liq', 'pentene')   mole / second     21.866     21.152
#     Molar Flowrate ('Liq', 'hexene')    mole / second     24.601     24.395
#     Molar Flowrate ('Liq', 'heptene')   mole / second     34.039     33.969
#     Molar Flowrate ('Liq', 'octene')    mole / second     16.813     16.800
#     Molar Flowrate ('Liq', 'nonene')    mole / second     13.033     13.023
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     2.5713
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.85630
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.35607
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     1.4489
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.28413
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.020323
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0024880
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00037326
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.6591
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     3.5040
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08     2.5476
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.71368
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.20566
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.069550
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.013179
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.010216
#     Temperature                                kelvin     299.28     291.66
#     Pressure                                   pascal 4.9821e+05 1.8791e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -38451. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     2.3267            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     2.8467            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     4.3984            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     12.443            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.363            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9311            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2026            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57750            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second    0.99460            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     9.9656            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     25.928            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     21.152            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     24.395            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     33.969            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     16.800            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     13.023            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     2.5713            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.85630            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.35607            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     1.4489            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.28413            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.020323            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0024880            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00037326            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.6591            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     3.5040            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     2.5476            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.71368            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.20566            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.069550            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.013179            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.010216            -             -
#     Temperature                                     kelvin     291.66            -             -
#     Pressure                                        pascal 1.8791e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        1.6828
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.4603
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        4.2006
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        11.660
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.204
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9202
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2014
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57733
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.67865
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        8.4608
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        24.533
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        20.750
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        24.284
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        33.935
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        16.794
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        13.018
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       3.2152    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       1.2427    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.55388    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       2.2319    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.44366    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.031152    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0037174    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -   0.00054308    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       1.9750    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       5.0088    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       3.9425    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       1.1161    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.31649    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -      0.10395    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.019257    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.014928    1.0000e-08
#     temperature                                     kelvin          -       288.09        288.09
#     pressure                                        pascal          -   1.4946e+05    1.4946e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2252.5          -
#     Total Mole Fraction hydrogen        dimensionless    0.12119          -
#     Total Mole Fraction methane         dimensionless    0.18610          -
#     Total Mole Fraction ethane          dimensionless    0.14353          -
#     Total Mole Fraction propane         dimensionless   0.032842          -
#     Total Mole Fraction nbutane         dimensionless   0.013701          -
#     Total Mole Fraction ibutane         dimensionless   0.053885          -
#     Total Mole Fraction pentane         dimensionless   0.015002          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     272.98
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     323.31
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     73.977
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     30.862
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     121.38
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     33.793
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     4.5430
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.4127
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.61109
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     257.48
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     310.02
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     216.26
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     74.415
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     40.540
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     39.848
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     17.973
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     13.932
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     272.98          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     318.41          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     70.274          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     26.108          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     107.49          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     21.146          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     1.5916          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.20758          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.033221          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     254.83          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     296.55          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     187.79          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     52.549          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     15.940          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     5.8095          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     1.1597          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second    0.89893          -
#     Temperature                                kelvin     299.28     299.28
#     Pressure                                   pascal 4.9821e+05 4.9821e+05
#     Total Molar Flowrate                mole / second          -     2052.9
#     Total Mole Fraction hydrogen        dimensionless          -    0.13297
#     Total Mole Fraction methane         dimensionless          -    0.20419
#     Total Mole Fraction ethane          dimensionless          -    0.15510
#     Total Mole Fraction propane         dimensionless          -   0.034231
#     Total Mole Fraction nbutane         dimensionless          -   0.012717
#     Total Mole Fraction ibutane         dimensionless          -   0.052357
#     Total Mole Fraction pentane         dimensionless          -   0.010300
#     Total Mole Fraction hexane          dimensionless          - 0.00077529
#     Total Mole Fraction heptane         dimensionless          - 0.00010111
#     Total Mole Fraction octane          dimensionless          - 1.6182e-05
#     Total Mole Fraction ethylene        dimensionless          -    0.12413
#     Total Mole Fraction propene         dimensionless          -    0.14445
#     Total Mole Fraction butene          dimensionless          -   0.091473
#     Total Mole Fraction pentene         dimensionless          -   0.025597
#     Total Mole Fraction hexene          dimensionless          -  0.0077642
#     Total Mole Fraction heptene         dimensionless          -  0.0028298
#     Total Mole Fraction octene          dimensionless          - 0.00056487
#     Total Mole Fraction nonene          dimensionless          - 0.00043787
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     73346. :          watt : False : (None, None)
#           Pressure Change : 3.4875e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     3.3334 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     20.220     20.220
#     Total Mole Fraction ethane    dimensionless    0.15901    0.15901
#     Total Mole Fraction propane   dimensionless   0.061458   0.061458
#     Total Mole Fraction nbutane   dimensionless   0.027393   0.027393
#     Total Mole Fraction ibutane   dimensionless    0.11038    0.11038
#     Total Mole Fraction pentane   dimensionless   0.021942   0.021942
#     Total Mole Fraction hexane    dimensionless  0.0015407  0.0015407
#     Total Mole Fraction heptane   dimensionless 0.00018385 0.00018385
#     Total Mole Fraction octane    dimensionless 2.6859e-05 2.6859e-05
#     Total Mole Fraction ethylene  dimensionless   0.097679   0.097679
#     Total Mole Fraction propene   dimensionless    0.24772    0.24772
#     Total Mole Fraction butene    dimensionless    0.19498    0.19498
#     Total Mole Fraction pentene   dimensionless   0.055198   0.055198
#     Total Mole Fraction hexene    dimensionless   0.015653   0.015653
#     Total Mole Fraction heptene   dimensionless  0.0051411  0.0051411
#     Total Mole Fraction octene    dimensionless 0.00095241 0.00095241
#     Total Mole Fraction nonene    dimensionless 0.00073828 0.00073828
#     Temperature                          kelvin     288.09     334.71
#     Pressure                             pascal 1.4946e+05 4.9821e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          2052.9              20.220         2073.2
#     Total Mole Fraction hydrogen  dimensionless         0.13297          1.0000e-08        0.13167
#     Total Mole Fraction methane   dimensionless         0.20419          1.0000e-08        0.20220
#     Total Mole Fraction ethane    dimensionless         0.15510             0.15901        0.15514
#     Total Mole Fraction propane   dimensionless        0.034231            0.061458       0.034496
#     Total Mole Fraction nbutane   dimensionless        0.012717            0.027393       0.012860
#     Total Mole Fraction ibutane   dimensionless        0.052357             0.11038       0.052923
#     Total Mole Fraction pentane   dimensionless        0.010300            0.021942       0.010414
#     Total Mole Fraction hexane    dimensionless      0.00077529           0.0015407     0.00078276
#     Total Mole Fraction heptane   dimensionless      0.00010111          0.00018385     0.00010192
#     Total Mole Fraction octane    dimensionless      1.6182e-05          2.6859e-05     1.6286e-05
#     Total Mole Fraction ethylene  dimensionless         0.12413            0.097679        0.12387
#     Total Mole Fraction propene   dimensionless         0.14445             0.24772        0.14546
#     Total Mole Fraction butene    dimensionless        0.091473             0.19498       0.092482
#     Total Mole Fraction pentene   dimensionless        0.025597            0.055198       0.025885
#     Total Mole Fraction hexene    dimensionless       0.0077642            0.015653      0.0078412
#     Total Mole Fraction heptene   dimensionless       0.0028298           0.0051411      0.0028524
#     Total Mole Fraction octene    dimensionless      0.00056487          0.00095241     0.00056865
#     Total Mole Fraction nonene    dimensionless      0.00043787          0.00073828     0.00044080
#     Temperature                          kelvin          299.28              334.71         299.76
#     Pressure                             pascal      4.9821e+05          4.9821e+05     4.9821e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     2073.2     20.732     2052.4
#     Total Mole Fraction hydrogen  dimensionless    0.13167    0.13167    0.13167
#     Total Mole Fraction methane   dimensionless    0.20220    0.20220    0.20220
#     Total Mole Fraction ethane    dimensionless    0.15514    0.15514    0.15514
#     Total Mole Fraction propane   dimensionless   0.034496   0.034496   0.034496
#     Total Mole Fraction nbutane   dimensionless   0.012860   0.012860   0.012860
#     Total Mole Fraction ibutane   dimensionless   0.052923   0.052923   0.052923
#     Total Mole Fraction pentane   dimensionless   0.010414   0.010414   0.010414
#     Total Mole Fraction hexane    dimensionless 0.00078276 0.00078276 0.00078276
#     Total Mole Fraction heptane   dimensionless 0.00010192 0.00010192 0.00010192
#     Total Mole Fraction octane    dimensionless 1.6286e-05 1.6286e-05 1.6286e-05
#     Total Mole Fraction ethylene  dimensionless    0.12387    0.12387    0.12387
#     Total Mole Fraction propene   dimensionless    0.14546    0.14546    0.14546
#     Total Mole Fraction butene    dimensionless   0.092482   0.092482   0.092482
#     Total Mole Fraction pentene   dimensionless   0.025885   0.025885   0.025885
#     Total Mole Fraction hexene    dimensionless  0.0078412  0.0078412  0.0078412
#     Total Mole Fraction heptene   dimensionless  0.0028524  0.0028524  0.0028524
#     Total Mole Fraction octene    dimensionless 0.00056865 0.00056865 0.00056865
#     Total Mole Fraction nonene    dimensionless 0.00044080 0.00044080 0.00044080
#     Temperature                          kelvin     299.76     299.76     299.76
#     Pressure                             pascal 4.9821e+05 4.9821e+05 4.9821e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 2.0976e+06 :          watt : False : (None, None)
#           Pressure Change : 2.0179e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.4050 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2052.4     2052.4
#     Total Mole Fraction hydrogen  dimensionless    0.13167    0.13167
#     Total Mole Fraction methane   dimensionless    0.20220    0.20220
#     Total Mole Fraction ethane    dimensionless    0.15514    0.15514
#     Total Mole Fraction propane   dimensionless   0.034496   0.034496
#     Total Mole Fraction nbutane   dimensionless   0.012860   0.012860
#     Total Mole Fraction ibutane   dimensionless   0.052923   0.052923
#     Total Mole Fraction pentane   dimensionless   0.010414   0.010414
#     Total Mole Fraction hexane    dimensionless 0.00078276 0.00078276
#     Total Mole Fraction heptane   dimensionless 0.00010192 0.00010192
#     Total Mole Fraction octane    dimensionless 1.6286e-05 1.6286e-05
#     Total Mole Fraction ethylene  dimensionless    0.12387    0.12387
#     Total Mole Fraction propene   dimensionless    0.14546    0.14546
#     Total Mole Fraction butene    dimensionless   0.092482   0.092482
#     Total Mole Fraction pentene   dimensionless   0.025885   0.025885
#     Total Mole Fraction hexene    dimensionless  0.0078412  0.0078412
#     Total Mole Fraction heptene   dimensionless  0.0028524  0.0028524
#     Total Mole Fraction octene    dimensionless 0.00056865 0.00056865
#     Total Mole Fraction nonene    dimensionless 0.00044080 0.00044080
#     Temperature                          kelvin     299.76     317.36
#     Pressure                             pascal 4.9821e+05 7.0000e+05
# ====================================================================================

# %%
# xlocs = np.arange(len(locs))
# fig1, ax1 = plt.subplots(figsize=(8,6))
# plt.rcParams.update({'font.size': 20})

# bar = ax1.bar(xlocs, C_taxes, align='center')#,color=colors[4])#, edgecolor='black')


# ax1.set_ylabel('Process CO2 emissions \n [g CO2e/MJ fuel]',fontsize=24)
# ax1.set_xlabel('Case',fontsize=24)
# ax1.set_xticks(xlocs)
# ax1.set_xticklabels(('w/o ROK model', 'w/ ROK model', 'Optimal \n w/ ROK model'),
#                    fontsize=14)
# ax1.tick_params(axis='y', labelsize= 14)

# ax1.bar_label(bar, label_type='edge')
# plt.ylim([0,16])

# plt.savefig('CO2_emissions_comparison.pdf',bbox_inches='tight',dpi=200)
# plt.show()

# %%
# sell_prices = [0.0281,0.0296,0.0085,0.014]
# products = ['gasoline','diesel','NGL','CISTAR liquids']

# %%
# xlocs = np.arange(len(products))
# fig1, ax1 = plt.subplots(figsize=(8,6))
# plt.rcParams.update({'font.size': 20})

# bar = ax1.bar(xlocs, sell_prices, align='center')#,color=colors[4])#, edgecolor='black')


# ax1.set_ylabel('Sell price \n [$/MJ fuel]',fontsize=24)
# ax1.set_xlabel('Product',fontsize=24)
# ax1.set_xticks(xlocs)
# ax1.set_xticklabels(('gasoline','diesel','NGL','CISTAR liquids'),
#                    fontsize=14)
# ax1.tick_params(axis='y', labelsize= 14)

# ax1.bar_label(bar, label_type='edge')
# plt.ylim([0,0.035])

# plt.savefig('product_price_comparison.pdf',bbox_inches='tight',dpi=200)
# plt.show()
