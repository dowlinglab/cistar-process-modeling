# %% [markdown]
# # Flowsheet optimization
# ## ROK model: M2; Region: Bakken; CO$_2$ tax rate: USD 45/tonne CO$_2$e

# %%
# simulation case specifications
model_code = 2
case_name = 'Bakken'
c_tax_rate = 4.5e-2

# %%
from idaes.core.util.model_statistics import degrees_of_freedom, large_residuals_set

# Import idaes model serializer to store initialized model
from idaes.core.util import model_serializer as ms

from pyomo.environ import (Constraint,
                           ConstraintList,
                           Var,
                           ConcreteModel,
                           Expression,
                           Param,
                           Set,
                           Objective,
                           SolverFactory,
                           TransformationFactory,
                           value,
                           minimize)

from src.unit_initialization import create_flowsheet, \
                                    define_models, \
                                    define_arcs, \
                                    set_unit_model_variables, \
                                    initialize_flowsheet, \
                                    set_scaling_factors,\
                                    update_model_after_initialization,\
                                    vapor_only_to_vapor_liquid_reformulate,\
                                    update_model_for_optimization, \
                                    unfix_DOFs_pre_optimization, \
                                    fix_DOFs_post_optimization

# %% [markdown]
# ## Create flowsheet

# %%
m = create_flowsheet(model_code)

# %%
M_catalyst = 1167.003367 # kg

# %% [markdown]
# ## Define equipment and connections

# %%
# define unit models
define_models(m, catalyst_mass = M_catalyst)
#define connections
define_arcs(m)

# %% [markdown]
# ## Define inlet compositions

# %%
import pandas as pd

inlet_df = pd.read_csv('NGL_compositions.csv')

inlet_composition_dict = {}

for col in inlet_df.columns:
    if col == case_name:
        for i,r in inlet_df.iterrows():
            if r[col] == 0.0:
                inlet_composition_dict[r['Species']] = 1e-6
            else:
                inlet_composition_dict[r['Species']] = round(r[col],4)

inlet_flow_rate = 481.3888889

inlet_composition_dict

dehydro_conv_dict = {'ethane':0.3566,
                     'propane':0.6632,
                     'nbutane':0.5188}

# %% [markdown]
# ## Define constraints and set-points for equipment

# %%
set_unit_model_variables(m, model_code=model_code, feed_flow_rate = inlet_flow_rate, 
                         feed_temp = 308.0, feed_pressure = 700000.0,
                         inlet_composition_dict = inlet_composition_dict,
                         dehydro_conv_dict = dehydro_conv_dict)

# %% [markdown]
# ## Scale model components

# %%
if model_code == 2 or model_code == 3:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-2, inlet_composition_dict = inlet_composition_dict)
elif model_code == 4 or model_code == 5:
    set_scaling_factors(m,flow_mol_scaling_factor = 1e-3, inlet_composition_dict = inlet_composition_dict)
else:
    pass

# %% [markdown]
# ## Read-in initialization data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_unit_initialization_{}_M{}.json.gz".format(case_name, model_code)
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.06385111808776855,
#  'etime_read_dict': 0.28844594955444336,
#  'etime_read_suffixes': 0.005982637405395508}

# %% [markdown]
# ## Add post-initialization constraints

# %%
update_model_after_initialization(m)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
vapor_only_to_vapor_liquid_reformulate(m.fs.T102)
# Out:
# Liquid phase flow is zero. Translator block fs.T102 liquid phase composition equations are being modified...
#
# Degenerate constraints removed and liquid phase composition values set to 1e-8
#
# Translator block fs.T102 liquid phase composition equations already modified, no degenerate constraints remaining.

# %% [markdown]
# ## Read-in flowsheet convergence data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_solve_constrained_{}_M{}_purge_{}.json.gz".format(case_name, model_code,round(m.fs.S102.split_fraction[0, "purge"](),3))
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.048841238021850586,
#  'etime_read_dict': 0.28204774856567383,
#  'etime_read_suffixes': 0.00422215461730957}

# %% [markdown]
# ## Costing

# %%
from src.emissions_calculations import calc_lhv_values, calculate_stream_energies, calculate_emissions, create_ghg_objective
from src.costing_function import add_costing,calculate_costs_for_objective
from src.utility_minimization_1d import (
    min_utility,
    PinchDataClass,
    heat_ex_data,
    gen_curves,
    print_HX_results,
    generate_curves,
    heat_data,
    pinch_calc,
    return_data
)

# %% [markdown]
# ### Equipment costing

# %%
add_costing(m)

# %% [markdown]
# ### Heat integration

# %%
### Heat Exchangers and reactors
min_utility(
    m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102], 10.0
)
m.fs.Qs.fix()

# %% [markdown]
# ### Emissions calculation

# %%
calc_lhv_values(m,case_name,'./LHV.xlsx','NGL_compositions.csv','NGL_fraction.csv')
calculate_stream_energies(m)
calculate_emissions(m,case_name,'emissions_factor_by_region.csv')
create_ghg_objective(m)
calculate_costs_for_objective(m,c_tax_flag=True, c_tax_val = c_tax_rate)

# %% [markdown]
# ## Read-in costing-initialized flowsheet data from .json file

# %%
init_file_name = "./initialization_files/CISTAR_solve_with_costing_{}_C_tax_{}_M{}_purge_{}.json.gz".format(case_name,m.fs.c_tax_rate(), model_code,round(m.fs.S102.split_fraction[0, "purge"](),3))
ms.from_json(m, fname=init_file_name)
# Out:
# {'etime_load_file': 0.052084922790527344,
#  'etime_read_dict': 0.17612767219543457,
#  'etime_read_suffixes': 0.0}

# %% [markdown]
# ## Flowsheet optimization with 8 DOFs

# %%
update_model_for_optimization(m)
unfix_DOFs_pre_optimization(m)
# Out:
# Model updates:
#
#
# Constraint added for recycle ratio <= 8.0.
#
# fs.H103 temperature lower and upper bounds added.
#
# fs.R102 isothermal operation constraint added.
#
# fs.H106 temperature lower bound updated.
#
# fs.F102 temperature lower bound updated.
#
# Objective function added.

# %%
solver = SolverFactory('ipopt')
solver.options = {'tol': 1e-6,
                  'bound_push': 1e-8,
                  'max_iter': 500,
                 }

# %%
## Special case: perturbation of initial point for solve convergence
m.fs.H103.outlet.temperature.fix(590.0)
m.fs.H103.outlet.temperature.unfix()

# %%
DOF_initial = degrees_of_freedom(m)
print("The initial DOF is {0}".format(DOF_initial))
# Out:
# The initial DOF is 8

# %%
solve_status = solver.solve(m, tee=True, symbolic_solver_labels=True)
# Out:
# Ipopt 3.13.2: tol=1e-06
# bound_push=1e-08
# max_iter=500
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:    34098
# Number of nonzeros in inequality constraint Jacobian.:      178
# Number of nonzeros in Lagrangian Hessian.............:    17881
#
# Total number of variables............................:     5555
#                      variables with only lower bounds:      189
#                 variables with lower and upper bounds:     3166
#                      variables with only upper bounds:       70
# Total number of equality constraints.................:     5547
# Total number of inequality constraints...............:       71
#         inequality constraints with only lower bounds:       20
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       51
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1364877e+01 4.28e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1367482e+01 2.37e+01 1.41e+06  -1.0 9.25e+04    -  8.59e-01 1.00e+00h  1
#    2  1.1368450e+01 8.25e+00 1.67e+04  -1.0 8.93e+04    -  9.88e-01 1.00e+00h  1
#    3  1.1586017e+01 1.94e+03 8.41e+03  -1.0 1.46e+05    -  5.99e-01 1.00e+00f  1
#    4  1.1785334e+01 4.15e+03 4.47e+03  -1.0 3.18e+05    -  7.28e-01 1.00e+00h  1
#    5  1.2078358e+01 1.98e+04 2.26e+04  -1.0 8.94e+05    -  8.17e-01 1.00e+00f  1
#    6  1.2184525e+01 3.57e+04 2.23e+05  -1.0 3.70e+06    -  8.50e-01 1.00e+00f  1
#    7  1.2132111e+01 1.61e+04 2.29e+05  -1.0 1.37e+07    -  9.28e-01 6.76e-01h  1
#    8  1.2081534e+01 2.14e+04 3.28e+05  -1.0 2.20e+07    -  3.21e-01 9.18e-01h  1
#    9  1.2085818e+01 1.31e+04 1.07e+05  -1.0 6.23e+06    -  9.58e-01 3.97e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.2080286e+01 7.19e+01 1.32e+03  -1.0 2.14e+05    -  9.91e-01 1.00e+00h  1
#   11  1.2078230e+01 3.59e+00 2.58e+02  -1.0 4.39e+05    -  1.00e+00 1.00e+00h  1
#   12  1.2078048e+01 2.56e-02 5.70e+00  -1.0 3.71e+04    -  1.00e+00 1.00e+00h  1
#   13  1.1273885e+01 4.73e+02 2.64e+06  -3.8 3.58e+04    -  9.91e-01 7.26e-01f  1
#   14  1.1274033e+01 1.07e-03 5.62e+01  -3.8 2.44e+01  -4.0 1.00e+00 1.00e+00h  1
#   15  1.1273895e+01 5.44e-04 6.35e-03  -3.8 3.03e-02  -4.5 1.00e+00 1.00e+00h  1
#   16  1.1273741e+01 2.38e-07 5.96e-04  -5.7 3.34e-02  -5.0 1.00e+00 1.00e+00h  1
#   17  1.1273743e+01 3.46e-06 4.85e-08  -5.7 8.24e-03  -5.4 1.00e+00 1.00e+00h  1
#   18  1.1273741e+01 4.66e-09 5.44e-06  -7.0 2.47e-02  -5.9 1.00e+00 1.00e+00h  1
#   19  1.1273741e+01 5.96e-08 3.05e-08  -7.0 7.41e-02  -6.4 1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1273741080072405e+01    1.1273741080072405e+01
# Dual infeasibility......:   3.0500949418014171e-08    3.0500949418014171e-08
# Constraint violation....:   1.3969838619232178e-08    5.9604644775390625e-08
# Complementarity.........:   9.0909094228403474e-08    9.0909094228403474e-08
# Overall NLP error.......:   9.0909094228403474e-08    9.0909094228403474e-08
#
#
# Number of objective function evaluations             = 20
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 20
# Number of inequality constraint evaluations          = 20
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 20
# Number of Lagrangian Hessian evaluations             = 19
# Total CPU secs in IPOPT (w/o function evaluations)   =     39.700
# Total CPU secs in NLP function evaluations           =    667.997
#
# EXIT: Optimal Solution Found.

# %%
fix_DOFs_post_optimization(m)

# %%
ms.to_json(m, fname="./initialization_files/CISTAR_optimal_solution_{}_C_tax_{}_M{}_purge_{}.json.gz".format(case_name,m.fs.c_tax_rate(), model_code,round(m.fs.S102.split_fraction[0, "purge"](),3)))

# %% [markdown]
# ## Save and display results

# %%
CDs = heat_ex_data(m.fs, [m.fs.H101, m.fs.H103, m.fs.R101], [m.fs.H102, m.fs.H104, m.fs.H105, m.fs.H106, m.fs.R102])
generate_curves(CDs)

# %%
m.fs.min_sell_price() # $/GJ fuel
# Out:
# 11.273741080072405

# %%
m.fs.downstream_emissions() # kg CO2e/GJ fuel
# Out:
# 8.875602530916817

# %%
m.fs.M101.report()
m.fs.H101.report()
m.fs.R101.report()
m.fs.H102.report()
m.fs.S101.report()
m.fs.E101.report()
m.fs.H103.report()
m.fs.R102.report()
m.fs.H104.report()
m.fs.T101.report()
m.fs.H105.report()
m.fs.F101.report()
m.fs.H106.report()
m.fs.F102.report()
m.fs.T102.report()
m.fs.T103.report()
m.fs.C101.report()
m.fs.M102.report()
m.fs.S102.report()
m.fs.C102.report()
# Out:
# ====================================================================================
# Unit : fs.M101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         feed      recycle    Outlet
#     Total Molar Flowrate          mole / second     481.39     1905.7     2387.1
#     Total Mole Fraction hydrogen  dimensionless 1.0000e-06    0.14158    0.11302
#     Total Mole Fraction methane   dimensionless   0.081100    0.21777    0.19021
#     Total Mole Fraction ethane    dimensionless    0.46920    0.16687    0.22784
#     Total Mole Fraction propane   dimensionless    0.30920   0.036987   0.091883
#     Total Mole Fraction nbutane   dimensionless   0.078400   0.013585   0.026656
#     Total Mole Fraction ibutane   dimensionless   0.026500   0.052858   0.047542
#     Total Mole Fraction pentane   dimensionless   0.025800   0.010359   0.013473
#     Total Mole Fraction hexane    dimensionless  0.0061000 0.00077632  0.0018499
#     Total Mole Fraction heptane   dimensionless  0.0025000 0.00010076 0.00058461
#     Total Mole Fraction octane    dimensionless  0.0012000 1.6052e-05 0.00025481
#     Total Mole Fraction ethylene  dimensionless 1.0000e-06   0.097691   0.077990
#     Total Mole Fraction propene   dimensionless 1.0000e-06    0.13515    0.10790
#     Total Mole Fraction butene    dimensionless 1.0000e-06   0.093610   0.074732
#     Total Mole Fraction pentene   dimensionless 1.0000e-06   0.022337   0.017833
#     Total Mole Fraction hexene    dimensionless 1.0000e-06  0.0062732  0.0050083
#     Total Mole Fraction heptene   dimensionless 1.0000e-06  0.0028475  0.0022735
#     Total Mole Fraction octene    dimensionless 1.0000e-06 0.00063479 0.00050697
#     Total Mole Fraction nonene    dimensionless 1.0000e-06 0.00056036 0.00044755
#     Temperature                          kelvin     308.00     317.22     315.13
#     Pressure                             pascal 7.0000e+05 7.0000e+05 7.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 1.9548e+08 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2387.1     2387.1
#     Total Mole Fraction hydrogen  dimensionless    0.11302    0.11302
#     Total Mole Fraction methane   dimensionless    0.19021    0.19021
#     Total Mole Fraction ethane    dimensionless    0.22784    0.22784
#     Total Mole Fraction propane   dimensionless   0.091883   0.091883
#     Total Mole Fraction nbutane   dimensionless   0.026656   0.026656
#     Total Mole Fraction ibutane   dimensionless   0.047542   0.047542
#     Total Mole Fraction pentane   dimensionless   0.013473   0.013473
#     Total Mole Fraction hexane    dimensionless  0.0018499  0.0018499
#     Total Mole Fraction heptane   dimensionless 0.00058461 0.00058461
#     Total Mole Fraction octane    dimensionless 0.00025481 0.00025481
#     Total Mole Fraction ethylene  dimensionless   0.077990   0.077990
#     Total Mole Fraction propene   dimensionless    0.10790    0.10790
#     Total Mole Fraction butene    dimensionless   0.074732   0.074732
#     Total Mole Fraction pentene   dimensionless   0.017833   0.017833
#     Total Mole Fraction hexene    dimensionless  0.0050083  0.0050083
#     Total Mole Fraction heptene   dimensionless  0.0022735  0.0022735
#     Total Mole Fraction octene    dimensionless 0.00050697 0.00050697
#     Total Mole Fraction nonene    dimensionless 0.00044755 0.00044755
#     Temperature                          kelvin     315.13     1073.0
#     Pressure                             pascal 7.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                  : Value      : Units         : Fixed : Bounds
#                Heat Duty : 9.1350e+07 :          watt : False : (None, None)
#     Reaction Extent [R1] :     193.94 : mole / second : False : (None, None)
#     Reaction Extent [R2] :     145.46 : mole / second : False : (None, None)
#     Reaction Extent [R3] :     33.011 : mole / second : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2387.1     2759.5
#     Total Mole Fraction hydrogen  dimensionless    0.11302    0.23273
#     Total Mole Fraction methane   dimensionless    0.19021    0.16454
#     Total Mole Fraction ethane    dimensionless    0.22784    0.12681
#     Total Mole Fraction propane   dimensionless   0.091883   0.026770
#     Total Mole Fraction nbutane   dimensionless   0.026656   0.011096
#     Total Mole Fraction ibutane   dimensionless   0.047542   0.041126
#     Total Mole Fraction pentane   dimensionless   0.013473   0.011654
#     Total Mole Fraction hexane    dimensionless  0.0018499  0.0016003
#     Total Mole Fraction heptane   dimensionless 0.00058461 0.00050571
#     Total Mole Fraction octane    dimensionless 0.00025481 0.00022043
#     Total Mole Fraction ethylene  dimensionless   0.077990    0.13775
#     Total Mole Fraction propene   dimensionless    0.10790    0.14605
#     Total Mole Fraction butene    dimensionless   0.074732   0.076609
#     Total Mole Fraction pentene   dimensionless   0.017833   0.015426
#     Total Mole Fraction hexene    dimensionless  0.0050083  0.0043324
#     Total Mole Fraction heptene   dimensionless  0.0022735  0.0019666
#     Total Mole Fraction octene    dimensionless 0.00050697 0.00043855
#     Total Mole Fraction nonene    dimensionless 0.00044755 0.00038715
#     Temperature                          kelvin     1073.0     1073.0
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -1.6413e+08 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2759.5     2759.5
#     Total Mole Fraction hydrogen  dimensionless    0.23273    0.23273
#     Total Mole Fraction methane   dimensionless    0.16454    0.16454
#     Total Mole Fraction ethane    dimensionless    0.12681    0.12681
#     Total Mole Fraction propane   dimensionless   0.026770   0.026770
#     Total Mole Fraction nbutane   dimensionless   0.011096   0.011096
#     Total Mole Fraction ibutane   dimensionless   0.041126   0.041126
#     Total Mole Fraction pentane   dimensionless   0.011654   0.011654
#     Total Mole Fraction hexane    dimensionless  0.0016003  0.0016003
#     Total Mole Fraction heptane   dimensionless 0.00050571 0.00050571
#     Total Mole Fraction octane    dimensionless 0.00022043 0.00022043
#     Total Mole Fraction ethylene  dimensionless    0.13775    0.13775
#     Total Mole Fraction propene   dimensionless    0.14605    0.14605
#     Total Mole Fraction butene    dimensionless   0.076609   0.076609
#     Total Mole Fraction pentene   dimensionless   0.015426   0.015426
#     Total Mole Fraction hexene    dimensionless  0.0043324  0.0043324
#     Total Mole Fraction heptene   dimensionless  0.0019666  0.0019666
#     Total Mole Fraction octene    dimensionless 0.00043855 0.00043855
#     Total Mole Fraction nonene    dimensionless 0.00038715 0.00038715
#     Temperature                          kelvin     1073.0     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                                       : Value      : Units         : Fixed : Bounds
#       Split Fraction [('H2_purge', 'butene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'ethane')] :   0.076753 : dimensionless : False : (None, None)
#     Split Fraction [('H2_purge', 'ethylene')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'heptane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'heptene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'hexene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#     Split Fraction [('H2_purge', 'hydrogen')] :    0.57565 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'ibutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'methane')] :   0.076753 : dimensionless : False : (None, None)
#      Split Fraction [('H2_purge', 'nbutane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'nonene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#       Split Fraction [('H2_purge', 'octene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'pentene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propane')] : 1.0000e-08 : dimensionless :  True : (None, None)
#      Split Fraction [('H2_purge', 'propene')] : 1.0000e-08 : dimensionless :  True : (None, None)
#         Split Fraction [('outlet', 'butene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'ethane')] :    0.92325 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'ethylene')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'heptene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'hexene')] :     1.0000 : dimensionless : False : (None, None)
#       Split Fraction [('outlet', 'hydrogen')] :    0.42435 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'ibutane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'methane')] :    0.92325 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'nbutane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'nonene')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octane')] :     1.0000 : dimensionless : False : (None, None)
#         Split Fraction [('outlet', 'octene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'pentene')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propane')] :     1.0000 : dimensionless : False : (None, None)
#        Split Fraction [('outlet', 'propene')] :     1.0000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet    H2_purge    outlet
#     Total Molar Flowrate          mole / second     2759.5     460.57     2298.9
#     Total Mole Fraction hydrogen  dimensionless    0.23273    0.80268    0.11854
#     Total Mole Fraction methane   dimensionless    0.16454   0.075665    0.18234
#     Total Mole Fraction ethane    dimensionless    0.12681   0.058314    0.14053
#     Total Mole Fraction propane   dimensionless   0.026770 1.6039e-09   0.032133
#     Total Mole Fraction nbutane   dimensionless   0.011096 6.6480e-10   0.013319
#     Total Mole Fraction ibutane   dimensionless   0.041126 2.4640e-09   0.049365
#     Total Mole Fraction pentane   dimensionless   0.011654 6.9826e-10   0.013989
#     Total Mole Fraction hexane    dimensionless  0.0016003 9.5879e-11  0.0019209
#     Total Mole Fraction heptane   dimensionless 0.00050571 3.0299e-11 0.00060703
#     Total Mole Fraction octane    dimensionless 0.00022043 1.3207e-11 0.00026459
#     Total Mole Fraction ethylene  dimensionless    0.13775   0.063344    0.15265
#     Total Mole Fraction propene   dimensionless    0.14605 8.7503e-09    0.17531
#     Total Mole Fraction butene    dimensionless   0.076609 4.5900e-09   0.091957
#     Total Mole Fraction pentene   dimensionless   0.015426 9.2424e-10   0.018516
#     Total Mole Fraction hexene    dimensionless  0.0043324 2.5957e-10  0.0052003
#     Total Mole Fraction heptene   dimensionless  0.0019666 1.1783e-10  0.0023606
#     Total Mole Fraction octene    dimensionless 0.00043855 2.6276e-11 0.00052642
#     Total Mole Fraction nonene    dimensionless 0.00038715 2.3196e-11 0.00046472
#     Temperature                          kelvin     473.00     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.E101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value       : Units         : Fixed : Bounds
#     Isentropic Efficiency :     0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : -2.2270e+06 :          watt : False : (None, None)
#           Pressure Change : -5.0000e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     0.16667 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     460.57     460.57
#     Total Mole Fraction hydrogen  dimensionless    0.80268    0.80268
#     Total Mole Fraction methane   dimensionless   0.075665   0.075665
#     Total Mole Fraction ethane    dimensionless   0.058314   0.058314
#     Total Mole Fraction ethylene  dimensionless   0.063344   0.063344
#     Temperature                          kelvin     473.00     327.82
#     Pressure                             pascal 6.0000e+05 1.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value      : Units : Fixed : Bounds
#     Heat Duty : 2.3972e+07 :  watt : False : (0.0, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2298.9     2298.9
#     Total Mole Fraction hydrogen  dimensionless    0.11854    0.11854
#     Total Mole Fraction methane   dimensionless    0.18234    0.18234
#     Total Mole Fraction ethane    dimensionless    0.14053    0.14053
#     Total Mole Fraction propane   dimensionless   0.032133   0.032133
#     Total Mole Fraction nbutane   dimensionless   0.013319   0.013319
#     Total Mole Fraction ibutane   dimensionless   0.049365   0.049365
#     Total Mole Fraction pentane   dimensionless   0.013989   0.013989
#     Total Mole Fraction hexane    dimensionless  0.0019209  0.0019209
#     Total Mole Fraction heptane   dimensionless 0.00060703 0.00060703
#     Total Mole Fraction octane    dimensionless 0.00026459 0.00026459
#     Total Mole Fraction ethylene  dimensionless    0.15265    0.15265
#     Total Mole Fraction propene   dimensionless    0.17531    0.17531
#     Total Mole Fraction butene    dimensionless   0.091957   0.091957
#     Total Mole Fraction pentene   dimensionless   0.018516   0.018516
#     Total Mole Fraction hexene    dimensionless  0.0052003  0.0052003
#     Total Mole Fraction heptene   dimensionless  0.0023606  0.0023606
#     Total Mole Fraction octene    dimensionless 0.00052642 0.00052642
#     Total Mole Fraction nonene    dimensionless 0.00046472 0.00046472
#     Temperature                          kelvin     473.00     593.50
#     Pressure                             pascal 6.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.R102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key  : Value  : Units      : Fixed : Bounds
#     Area : 1.6208 : meter ** 2 : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2298.9     2103.8
#     Total Mole Fraction hydrogen  dimensionless    0.11854    0.12954
#     Total Mole Fraction methane   dimensionless    0.18234    0.19925
#     Total Mole Fraction ethane    dimensionless    0.14053    0.15356
#     Total Mole Fraction propane   dimensionless   0.032133   0.035113
#     Total Mole Fraction nbutane   dimensionless   0.013319   0.014554
#     Total Mole Fraction ibutane   dimensionless   0.049365   0.053944
#     Total Mole Fraction pentane   dimensionless   0.013989   0.015287
#     Total Mole Fraction hexane    dimensionless  0.0019209  0.0020990
#     Total Mole Fraction heptane   dimensionless 0.00060703 0.00066333
#     Total Mole Fraction octane    dimensionless 0.00026459 0.00028912
#     Total Mole Fraction ethylene  dimensionless    0.15265   0.089646
#     Total Mole Fraction propene   dimensionless    0.17531    0.12745
#     Total Mole Fraction butene    dimensionless   0.091957   0.097541
#     Total Mole Fraction pentene   dimensionless   0.018516   0.029002
#     Total Mole Fraction hexene    dimensionless  0.0052003   0.015051
#     Total Mole Fraction heptene   dimensionless  0.0023606   0.018898
#     Total Mole Fraction octene    dimensionless 0.00052642  0.0096168
#     Total Mole Fraction nonene    dimensionless 0.00046472  0.0084892
#     Temperature                          kelvin     593.50     593.50
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H104                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.1396e+07 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     2103.8     2103.8
#     Total Mole Fraction hydrogen  dimensionless    0.12954    0.12954
#     Total Mole Fraction methane   dimensionless    0.19925    0.19925
#     Total Mole Fraction ethane    dimensionless    0.15356    0.15356
#     Total Mole Fraction propane   dimensionless   0.035113   0.035113
#     Total Mole Fraction nbutane   dimensionless   0.014554   0.014554
#     Total Mole Fraction ibutane   dimensionless   0.053944   0.053944
#     Total Mole Fraction pentane   dimensionless   0.015287   0.015287
#     Total Mole Fraction hexane    dimensionless  0.0020990  0.0020990
#     Total Mole Fraction heptane   dimensionless 0.00066333 0.00066333
#     Total Mole Fraction octane    dimensionless 0.00028912 0.00028912
#     Total Mole Fraction ethylene  dimensionless   0.089646   0.089646
#     Total Mole Fraction propene   dimensionless    0.12745    0.12745
#     Total Mole Fraction butene    dimensionless   0.097541   0.097541
#     Total Mole Fraction pentene   dimensionless   0.029002   0.029002
#     Total Mole Fraction hexene    dimensionless   0.015051   0.015051
#     Total Mole Fraction heptene   dimensionless   0.018898   0.018898
#     Total Mole Fraction octene    dimensionless  0.0096168  0.0096168
#     Total Mole Fraction nonene    dimensionless  0.0084892  0.0084892
#     Temperature                          kelvin     593.50     299.76
#     Pressure                             pascal 5.0000e+05 5.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     460.57     460.57
#     Total Mole Fraction hydrogen  dimensionless    0.80268    0.80268
#     Total Mole Fraction methane   dimensionless   0.075665   0.075665
#     Total Mole Fraction ethane    dimensionless   0.058314   0.058314
#     Total Mole Fraction propane   dimensionless 1.6039e-09          -
#     Total Mole Fraction nbutane   dimensionless 6.6480e-10          -
#     Total Mole Fraction ibutane   dimensionless 2.4640e-09          -
#     Total Mole Fraction pentane   dimensionless 6.9826e-10          -
#     Total Mole Fraction hexane    dimensionless 9.5879e-11          -
#     Total Mole Fraction heptane   dimensionless 3.0299e-11          -
#     Total Mole Fraction octane    dimensionless 1.3207e-11          -
#     Total Mole Fraction ethylene  dimensionless   0.063344   0.063344
#     Total Mole Fraction propene   dimensionless 8.7503e-09          -
#     Total Mole Fraction butene    dimensionless 4.5900e-09          -
#     Total Mole Fraction pentene   dimensionless 9.2424e-10          -
#     Total Mole Fraction hexene    dimensionless 2.5957e-10          -
#     Total Mole Fraction heptene   dimensionless 1.1783e-10          -
#     Total Mole Fraction octene    dimensionless 2.6276e-11          -
#     Total Mole Fraction nonene    dimensionless 2.3196e-11          -
#     Temperature                          kelvin     473.00     473.00
#     Pressure                             pascal 6.0000e+05 6.0000e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H105                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value       : Units : Fixed : Bounds
#     Heat Duty : -5.4646e+06 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08     5.2712
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08     3.9813
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08     5.0479
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08     13.937
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08     12.670
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08     2.9539
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08     1.2054
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08    0.57792
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08     2.0926
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08     12.546
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08     28.958
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08     18.987
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08     19.853
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08     34.386
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08     19.032
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08     16.801
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     272.52     272.52
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second     323.06     317.79
#     Molar Flowrate ('Vap', 'propane')   mole / second     73.870     69.889
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     30.619     25.571
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     113.49     99.550
#     Molar Flowrate ('Vap', 'pentane')   mole / second     32.160     19.490
#     Molar Flowrate ('Vap', 'hexane')    mole / second     4.4159     1.4620
#     Molar Flowrate ('Vap', 'heptane')   mole / second     1.3955    0.19008
#     Molar Flowrate ('Vap', 'octane')    mole / second    0.60826   0.030337
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     188.60     186.50
#     Molar Flowrate ('Vap', 'propene')   mole / second     268.13     255.59
#     Molar Flowrate ('Vap', 'butene')    mole / second     205.21     176.25
#     Molar Flowrate ('Vap', 'pentene')   mole / second     61.013     42.026
#     Molar Flowrate ('Vap', 'hexene')    mole / second     31.664     11.811
#     Molar Flowrate ('Vap', 'heptene')   mole / second     39.758     5.3714
#     Molar Flowrate ('Vap', 'octene')    mole / second     20.232     1.1993
#     Molar Flowrate ('Vap', 'nonene')    mole / second     17.859     1.0587
#     Temperature                                kelvin     299.76     298.98
#     Pressure                                   pascal 5.0000e+05 5.0000e+05
# ====================================================================================
# ====================================================================================
# Unit : fs.F101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -1961.3 : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     5.2712            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     3.9813            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     5.0479            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     13.937            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.670            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9539            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2054            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57792            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second     2.0926            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     12.546            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     28.958            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     18.987            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     19.853            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     34.386            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     19.032            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     16.801            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second     272.52            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second     419.19            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     317.79            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second     69.889            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second     25.571            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     99.550            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second     19.490            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second     1.4620            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second    0.19008            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second   0.030337            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     186.50            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     255.59            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     176.25            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second     42.026            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second     11.811            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second     5.3714            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second     1.1993            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second     1.0587            -             -
#     Temperature                                     kelvin     298.98            -             -
#     Pressure                                        pascal 5.0000e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        5.2467
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        3.9657
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        5.0329
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        13.891
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.647
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9515
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2051
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57788
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08        2.0825
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        12.496
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        28.867
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        18.946
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        19.834
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        34.378
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        19.031
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        16.799
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -       272.52    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -       419.19    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       317.82    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       69.905    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -       25.586    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       99.595    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -       19.513    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -       1.4644    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -      0.19039    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -     0.030376    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       186.51    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       255.64    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       176.34    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -       42.067    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -       11.830    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -       5.3802    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -       1.2009    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -       1.0601    1.0000e-08
#     temperature                                     kelvin          -       298.92        298.92
#     pressure                                        pascal          -   4.9804e+05    4.9804e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.H106                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key       : Value   : Units : Fixed : Bounds
#     Heat Duty : -9262.4 :  watt : False : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units         Inlet     Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second     5.2467     2.5372
#     Molar Flowrate ('Liq', 'propane')   mole / second     3.9657     3.0729
#     Molar Flowrate ('Liq', 'nbutane')   mole / second     5.0329     4.6680
#     Molar Flowrate ('Liq', 'ibutane')   mole / second     13.891     12.487
#     Molar Flowrate ('Liq', 'pentane')   mole / second     12.647     12.372
#     Molar Flowrate ('Liq', 'hexane')    mole / second     2.9515     2.9319
#     Molar Flowrate ('Liq', 'heptane')   mole / second     1.2051     1.2027
#     Molar Flowrate ('Liq', 'octane')    mole / second    0.57788    0.57752
#     Molar Flowrate ('Liq', 'ethylene')  mole / second     2.0825    0.79724
#     Molar Flowrate ('Liq', 'propene')   mole / second     12.496     9.3274
#     Molar Flowrate ('Liq', 'butene')    mole / second     28.867     26.366
#     Molar Flowrate ('Liq', 'pentene')   mole / second     18.946     18.349
#     Molar Flowrate ('Liq', 'hexene')    mole / second     19.834     19.674
#     Molar Flowrate ('Liq', 'heptene')   mole / second     34.378     34.310
#     Molar Flowrate ('Liq', 'octene')    mole / second     19.031     19.016
#     Molar Flowrate ('Liq', 'nonene')    mole / second     16.799     16.787
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'methane')   mole / second 1.0000e-08 1.0000e-08
#     Molar Flowrate ('Vap', 'ethane')    mole / second 1.0000e-08     2.7095
#     Molar Flowrate ('Vap', 'propane')   mole / second 1.0000e-08    0.89284
#     Molar Flowrate ('Vap', 'nbutane')   mole / second 1.0000e-08    0.36485
#     Molar Flowrate ('Vap', 'ibutane')   mole / second 1.0000e-08     1.4039
#     Molar Flowrate ('Vap', 'pentane')   mole / second 1.0000e-08    0.27436
#     Molar Flowrate ('Vap', 'hexane')    mole / second 1.0000e-08   0.019605
#     Molar Flowrate ('Vap', 'heptane')   mole / second 1.0000e-08  0.0023982
#     Molar Flowrate ('Vap', 'octane')    mole / second 1.0000e-08 0.00035953
#     Molar Flowrate ('Vap', 'ethylene')  mole / second 1.0000e-08     1.2853
#     Molar Flowrate ('Vap', 'propene')   mole / second 1.0000e-08     3.1684
#     Molar Flowrate ('Vap', 'butene')    mole / second 1.0000e-08     2.5016
#     Molar Flowrate ('Vap', 'pentene')   mole / second 1.0000e-08    0.59775
#     Molar Flowrate ('Vap', 'hexene')    mole / second 1.0000e-08    0.15998
#     Molar Flowrate ('Vap', 'heptene')   mole / second 1.0000e-08   0.067679
#     Molar Flowrate ('Vap', 'octene')    mole / second 1.0000e-08   0.014373
#     Molar Flowrate ('Vap', 'nonene')    mole / second 1.0000e-08   0.012688
#     Temperature                                kelvin     298.92     291.65
#     Pressure                                   pascal 4.9804e+05 1.8448e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.F102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key             : Value   : Units  : Fixed : Bounds
#           Heat Duty :  0.0000 :   watt :  True : (None, None)
#     Pressure Change : -35871. : pascal :  True : (None, 0.0)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                                 Units         Inlet    Vapor Outlet  Liquid Outlet
#     Molar Flowrate ('Liq', 'ethane')         mole / second     2.5372            -             -
#     Molar Flowrate ('Liq', 'propane')        mole / second     3.0729            -             -
#     Molar Flowrate ('Liq', 'nbutane')        mole / second     4.6680            -             -
#     Molar Flowrate ('Liq', 'ibutane')        mole / second     12.487            -             -
#     Molar Flowrate ('Liq', 'pentane')        mole / second     12.372            -             -
#     Molar Flowrate ('Liq', 'hexane')         mole / second     2.9319            -             -
#     Molar Flowrate ('Liq', 'heptane')        mole / second     1.2027            -             -
#     Molar Flowrate ('Liq', 'octane')         mole / second    0.57752            -             -
#     Molar Flowrate ('Liq', 'ethylene')       mole / second    0.79724            -             -
#     Molar Flowrate ('Liq', 'propene')        mole / second     9.3274            -             -
#     Molar Flowrate ('Liq', 'butene')         mole / second     26.366            -             -
#     Molar Flowrate ('Liq', 'pentene')        mole / second     18.349            -             -
#     Molar Flowrate ('Liq', 'hexene')         mole / second     19.674            -             -
#     Molar Flowrate ('Liq', 'heptene')        mole / second     34.310            -             -
#     Molar Flowrate ('Liq', 'octene')         mole / second     19.016            -             -
#     Molar Flowrate ('Liq', 'nonene')         mole / second     16.787            -             -
#     Molar Flowrate ('Vap', 'hydrogen')       mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'methane')        mole / second 1.0000e-08            -             -
#     Molar Flowrate ('Vap', 'ethane')         mole / second     2.7095            -             -
#     Molar Flowrate ('Vap', 'propane')        mole / second    0.89284            -             -
#     Molar Flowrate ('Vap', 'nbutane')        mole / second    0.36485            -             -
#     Molar Flowrate ('Vap', 'ibutane')        mole / second     1.4039            -             -
#     Molar Flowrate ('Vap', 'pentane')        mole / second    0.27436            -             -
#     Molar Flowrate ('Vap', 'hexane')         mole / second   0.019605            -             -
#     Molar Flowrate ('Vap', 'heptane')        mole / second  0.0023982            -             -
#     Molar Flowrate ('Vap', 'octane')         mole / second 0.00035953            -             -
#     Molar Flowrate ('Vap', 'ethylene')       mole / second     1.2853            -             -
#     Molar Flowrate ('Vap', 'propene')        mole / second     3.1684            -             -
#     Molar Flowrate ('Vap', 'butene')         mole / second     2.5016            -             -
#     Molar Flowrate ('Vap', 'pentene')        mole / second    0.59775            -             -
#     Molar Flowrate ('Vap', 'hexene')         mole / second    0.15998            -             -
#     Molar Flowrate ('Vap', 'heptene')        mole / second   0.067679            -             -
#     Molar Flowrate ('Vap', 'octene')         mole / second   0.014373            -             -
#     Molar Flowrate ('Vap', 'nonene')         mole / second   0.012688            -             -
#     Temperature                                     kelvin     291.65            -             -
#     Pressure                                        pascal 1.8448e+05            -             -
#     flow_mol_phase_comp ('Liq', 'ethane')    mole / second          -   1.0000e-08        1.8573
#     flow_mol_phase_comp ('Liq', 'propane')   mole / second          -   1.0000e-08        2.6738
#     flow_mol_phase_comp ('Liq', 'nbutane')   mole / second          -   1.0000e-08        4.4683
#     flow_mol_phase_comp ('Liq', 'ibutane')   mole / second          -   1.0000e-08        11.739
#     flow_mol_phase_comp ('Liq', 'pentane')   mole / second          -   1.0000e-08        12.220
#     flow_mol_phase_comp ('Liq', 'hexane')    mole / second          -   1.0000e-08        2.9215
#     flow_mol_phase_comp ('Liq', 'heptane')   mole / second          -   1.0000e-08        1.2015
#     flow_mol_phase_comp ('Liq', 'octane')    mole / second          -   1.0000e-08       0.57736
#     flow_mol_phase_comp ('Liq', 'ethylene')  mole / second          -   1.0000e-08       0.55119
#     flow_mol_phase_comp ('Liq', 'propene')   mole / second          -   1.0000e-08        7.9777
#     flow_mol_phase_comp ('Liq', 'butene')    mole / second          -   1.0000e-08        25.015
#     flow_mol_phase_comp ('Liq', 'pentene')   mole / second          -   1.0000e-08        18.016
#     flow_mol_phase_comp ('Liq', 'hexene')    mole / second          -   1.0000e-08        19.588
#     flow_mol_phase_comp ('Liq', 'heptene')   mole / second          -   1.0000e-08        34.277
#     flow_mol_phase_comp ('Liq', 'octene')    mole / second          -   1.0000e-08        19.010
#     flow_mol_phase_comp ('Liq', 'nonene')    mole / second          -   1.0000e-08        16.781
#     flow_mol_phase_comp ('Vap', 'hydrogen')  mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'methane')   mole / second          -   1.0000e-08    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethane')    mole / second          -       3.3894    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propane')   mole / second          -       1.2919    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nbutane')   mole / second          -      0.56457    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ibutane')   mole / second          -       2.1517    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentane')   mole / second          -      0.42633    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexane')    mole / second          -     0.029949    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptane')   mole / second          -    0.0035776    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octane')    mole / second          -   0.00052324    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'ethylene')  mole / second          -       1.5313    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'propene')   mole / second          -       4.5181    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'butene')    mole / second          -       3.8518    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'pentene')   mole / second          -      0.93007    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'hexene')    mole / second          -      0.24529    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'heptene')   mole / second          -      0.10099    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'octene')    mole / second          -     0.021002    1.0000e-08
#     flow_mol_phase_comp ('Vap', 'nonene')    mole / second          -     0.018539    1.0000e-08
#     temperature                                     kelvin          -       288.32        288.32
#     pressure                                        pascal          -   1.4861e+05    1.4861e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Total Molar Flowrate                mole / second     2103.8          -
#     Total Mole Fraction hydrogen        dimensionless    0.12954          -
#     Total Mole Fraction methane         dimensionless    0.19925          -
#     Total Mole Fraction ethane          dimensionless    0.15356          -
#     Total Mole Fraction propane         dimensionless   0.035113          -
#     Total Mole Fraction nbutane         dimensionless   0.014554          -
#     Total Mole Fraction ibutane         dimensionless   0.053944          -
#     Total Mole Fraction pentane         dimensionless   0.015287          -
# ...
#     Molar Flowrate ('Liq', 'octene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Liq', 'nonene')    mole / second          - 1.0000e-08
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second          -     272.52
#     Molar Flowrate ('Vap', 'methane')   mole / second          -     419.19
#     Molar Flowrate ('Vap', 'ethane')    mole / second          -     323.06
#     Molar Flowrate ('Vap', 'propane')   mole / second          -     73.870
#     Molar Flowrate ('Vap', 'nbutane')   mole / second          -     30.619
#     Molar Flowrate ('Vap', 'ibutane')   mole / second          -     113.49
#     Molar Flowrate ('Vap', 'pentane')   mole / second          -     32.160
#     Molar Flowrate ('Vap', 'hexane')    mole / second          -     4.4159
#     Molar Flowrate ('Vap', 'heptane')   mole / second          -     1.3955
#     Molar Flowrate ('Vap', 'octane')    mole / second          -    0.60826
#     Molar Flowrate ('Vap', 'ethylene')  mole / second          -     188.60
#     Molar Flowrate ('Vap', 'propene')   mole / second          -     268.13
#     Molar Flowrate ('Vap', 'butene')    mole / second          -     205.21
#     Molar Flowrate ('Vap', 'pentene')   mole / second          -     61.013
#     Molar Flowrate ('Vap', 'hexene')    mole / second          -     31.664
#     Molar Flowrate ('Vap', 'heptene')   mole / second          -     39.758
#     Molar Flowrate ('Vap', 'octene')    mole / second          -     20.232
#     Molar Flowrate ('Vap', 'nonene')    mole / second          -     17.859
# ====================================================================================
#
# ====================================================================================
# Unit : fs.T103                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                            Units        Inlet      Outlet
#     Molar Flowrate ('Liq', 'ethane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nbutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ibutane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptane')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octane')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'ethylene')  mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'propene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'butene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'pentene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'hexene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'heptene')   mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'octene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Liq', 'nonene')    mole / second 1.0000e-08          -
#     Molar Flowrate ('Vap', 'hydrogen')  mole / second     272.52          -
#     Molar Flowrate ('Vap', 'methane')   mole / second     419.19          -
#     Molar Flowrate ('Vap', 'ethane')    mole / second     317.82          -
#     Molar Flowrate ('Vap', 'propane')   mole / second     69.905          -
#     Molar Flowrate ('Vap', 'nbutane')   mole / second     25.586          -
#     Molar Flowrate ('Vap', 'ibutane')   mole / second     99.595          -
#     Molar Flowrate ('Vap', 'pentane')   mole / second     19.513          -
#     Molar Flowrate ('Vap', 'hexane')    mole / second     1.4644          -
#     Molar Flowrate ('Vap', 'heptane')   mole / second    0.19039          -
#     Molar Flowrate ('Vap', 'octane')    mole / second   0.030376          -
#     Molar Flowrate ('Vap', 'ethylene')  mole / second     186.51          -
#     Molar Flowrate ('Vap', 'propene')   mole / second     255.64          -
#     Molar Flowrate ('Vap', 'butene')    mole / second     176.34          -
#     Molar Flowrate ('Vap', 'pentene')   mole / second     42.067          -
#     Molar Flowrate ('Vap', 'hexene')    mole / second     11.830          -
#     Molar Flowrate ('Vap', 'heptene')   mole / second     5.3802          -
#     Molar Flowrate ('Vap', 'octene')    mole / second     1.2009          -
#     Molar Flowrate ('Vap', 'nonene')    mole / second     1.0601          -
#     Temperature                                kelvin     298.92     298.92
#     Pressure                                   pascal 4.9804e+05 4.9804e+05
#     Total Molar Flowrate                mole / second          -     1905.8
#     Total Mole Fraction hydrogen        dimensionless          -    0.14299
#     Total Mole Fraction methane         dimensionless          -    0.21995
#     Total Mole Fraction ethane          dimensionless          -    0.16676
#     Total Mole Fraction propane         dimensionless          -   0.036679
#     Total Mole Fraction nbutane         dimensionless          -   0.013425
#     Total Mole Fraction ibutane         dimensionless          -   0.052258
#     Total Mole Fraction pentane         dimensionless          -   0.010239
#     Total Mole Fraction hexane          dimensionless          - 0.00076838
#     Total Mole Fraction heptane         dimensionless          - 9.9896e-05
#     Total Mole Fraction octane          dimensionless          - 1.5938e-05
#     Total Mole Fraction ethylene        dimensionless          -   0.097865
#     Total Mole Fraction propene         dimensionless          -    0.13413
#     Total Mole Fraction butene          dimensionless          -   0.092526
#     Total Mole Fraction pentene         dimensionless          -   0.022073
#     Total Mole Fraction hexene          dimensionless          -  0.0062073
#     Total Mole Fraction heptene         dimensionless          -  0.0028230
#     Total Mole Fraction octene          dimensionless          - 0.00063012
#     Total Mole Fraction nonene          dimensionless          - 0.00055624
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C101                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work :     69566. :          watt : False : (None, None)
#           Pressure Change : 3.4943e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     3.3513 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     19.075     19.075
#     Total Mole Fraction ethane    dimensionless    0.17769    0.17769
#     Total Mole Fraction propane   dimensionless   0.067728   0.067728
#     Total Mole Fraction nbutane   dimensionless   0.029597   0.029597
#     Total Mole Fraction ibutane   dimensionless    0.11280    0.11280
#     Total Mole Fraction pentane   dimensionless   0.022350   0.022350
#     Total Mole Fraction hexane    dimensionless  0.0015701  0.0015701
#     Total Mole Fraction heptane   dimensionless 0.00018755 0.00018755
#     Total Mole Fraction octane    dimensionless 2.7430e-05 2.7430e-05
#     Total Mole Fraction ethylene  dimensionless   0.080278   0.080278
#     Total Mole Fraction propene   dimensionless    0.23686    0.23686
#     Total Mole Fraction butene    dimensionless    0.20193    0.20193
#     Total Mole Fraction pentene   dimensionless   0.048758   0.048758
#     Total Mole Fraction hexene    dimensionless   0.012859   0.012859
#     Total Mole Fraction heptene   dimensionless  0.0052944  0.0052944
#     Total Mole Fraction octene    dimensionless  0.0011010  0.0011010
#     Total Mole Fraction nonene    dimensionless 0.00097191 0.00097191
#     Temperature                          kelvin     288.32     335.06
#     Pressure                             pascal 1.4861e+05 4.9804e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.M102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units       vapor_recycle_F101  vapor_recycle_F102   Outlet
#     Total Molar Flowrate          mole / second          1905.8              19.075         1924.9
#     Total Mole Fraction hydrogen  dimensionless         0.14299          1.0000e-08        0.14158
#     Total Mole Fraction methane   dimensionless         0.21995          1.0000e-08        0.21777
#     Total Mole Fraction ethane    dimensionless         0.16676             0.17769        0.16687
#     Total Mole Fraction propane   dimensionless        0.036679            0.067728       0.036987
#     Total Mole Fraction nbutane   dimensionless        0.013425            0.029597       0.013585
#     Total Mole Fraction ibutane   dimensionless        0.052258             0.11280       0.052858
#     Total Mole Fraction pentane   dimensionless        0.010239            0.022350       0.010359
#     Total Mole Fraction hexane    dimensionless      0.00076838           0.0015701     0.00077632
#     Total Mole Fraction heptane   dimensionless      9.9896e-05          0.00018755     0.00010076
#     Total Mole Fraction octane    dimensionless      1.5938e-05          2.7430e-05     1.6052e-05
#     Total Mole Fraction ethylene  dimensionless        0.097865            0.080278       0.097691
#     Total Mole Fraction propene   dimensionless         0.13413             0.23686        0.13515
#     Total Mole Fraction butene    dimensionless        0.092526             0.20193       0.093610
#     Total Mole Fraction pentene   dimensionless        0.022073            0.048758       0.022337
#     Total Mole Fraction hexene    dimensionless       0.0062073            0.012859      0.0062732
#     Total Mole Fraction heptene   dimensionless       0.0028230           0.0052944      0.0028475
#     Total Mole Fraction octene    dimensionless      0.00063012           0.0011010     0.00063479
#     Total Mole Fraction nonene    dimensionless      0.00055624          0.00097191     0.00056036
#     Temperature                          kelvin          298.92              335.06         299.42
#     Pressure                             pascal      4.9804e+05          4.9804e+05     4.9804e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.S102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                           : Value    : Units         : Fixed : Bounds
#       Split Fraction [('purge',)] : 0.010000 : dimensionless :  True : (None, None)
#     Split Fraction [('recycle',)] :  0.99000 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet      purge     recycle
#     Total Molar Flowrate          mole / second     1924.9     19.249     1905.7
#     Total Mole Fraction hydrogen  dimensionless    0.14158    0.14158    0.14158
#     Total Mole Fraction methane   dimensionless    0.21777    0.21777    0.21777
#     Total Mole Fraction ethane    dimensionless    0.16687    0.16687    0.16687
#     Total Mole Fraction propane   dimensionless   0.036987   0.036987   0.036987
#     Total Mole Fraction nbutane   dimensionless   0.013585   0.013585   0.013585
#     Total Mole Fraction ibutane   dimensionless   0.052858   0.052858   0.052858
#     Total Mole Fraction pentane   dimensionless   0.010359   0.010359   0.010359
#     Total Mole Fraction hexane    dimensionless 0.00077632 0.00077632 0.00077632
#     Total Mole Fraction heptane   dimensionless 0.00010076 0.00010076 0.00010076
#     Total Mole Fraction octane    dimensionless 1.6052e-05 1.6052e-05 1.6052e-05
#     Total Mole Fraction ethylene  dimensionless   0.097691   0.097691   0.097691
#     Total Mole Fraction propene   dimensionless    0.13515    0.13515    0.13515
#     Total Mole Fraction butene    dimensionless   0.093610   0.093610   0.093610
#     Total Mole Fraction pentene   dimensionless   0.022337   0.022337   0.022337
#     Total Mole Fraction hexene    dimensionless  0.0062732  0.0062732  0.0062732
#     Total Mole Fraction heptene   dimensionless  0.0028475  0.0028475  0.0028475
#     Total Mole Fraction octene    dimensionless 0.00063479 0.00063479 0.00063479
#     Total Mole Fraction nonene    dimensionless 0.00056036 0.00056036 0.00056036
#     Temperature                          kelvin     299.42     299.42     299.42
#     Pressure                             pascal 4.9804e+05 4.9804e+05 4.9804e+05
# ====================================================================================
#
# ====================================================================================
# Unit : fs.C102                                                             Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#     Variables:
#
#     Key                   : Value      : Units         : Fixed : Bounds
#     Isentropic Efficiency :    0.85000 : dimensionless :  True : (None, None)
#           Mechanical Work : 1.9480e+06 :          watt : False : (None, None)
#           Pressure Change : 2.0196e+05 :        pascal : False : (None, None)
#            Pressure Ratio :     1.4055 : dimensionless : False : (None, None)
#
# ------------------------------------------------------------------------------------
#     Stream Table
#                                      Units         Inlet     Outlet
#     Total Molar Flowrate          mole / second     1905.7     1905.7
#     Total Mole Fraction hydrogen  dimensionless    0.14158    0.14158
#     Total Mole Fraction methane   dimensionless    0.21777    0.21777
#     Total Mole Fraction ethane    dimensionless    0.16687    0.16687
#     Total Mole Fraction propane   dimensionless   0.036987   0.036987
#     Total Mole Fraction nbutane   dimensionless   0.013585   0.013585
#     Total Mole Fraction ibutane   dimensionless   0.052858   0.052858
#     Total Mole Fraction pentane   dimensionless   0.010359   0.010359
#     Total Mole Fraction hexane    dimensionless 0.00077632 0.00077632
#     Total Mole Fraction heptane   dimensionless 0.00010076 0.00010076
#     Total Mole Fraction octane    dimensionless 1.6052e-05 1.6052e-05
#     Total Mole Fraction ethylene  dimensionless   0.097691   0.097691
#     Total Mole Fraction propene   dimensionless    0.13515    0.13515
#     Total Mole Fraction butene    dimensionless   0.093610   0.093610
#     Total Mole Fraction pentene   dimensionless   0.022337   0.022337
#     Total Mole Fraction hexene    dimensionless  0.0062732  0.0062732
#     Total Mole Fraction heptene   dimensionless  0.0028475  0.0028475
#     Total Mole Fraction octene    dimensionless 0.00063479 0.00063479
#     Total Mole Fraction nonene    dimensionless 0.00056036 0.00056036
#     Temperature                          kelvin     299.42     317.22
#     Pressure                             pascal 4.9804e+05 7.0000e+05
# ====================================================================================
